# %%
from src.preprocessing.utils import quality_filter, normalize_by_speaker
from src.preprocessing.cleaning import drop_all
from src.preprocessing.loading import load_df
from src.preprocessing.aggregating import simple_aggregation, advanced_aggregation

# %% [markdown]
# # 0. LOADING AND CLEANING THE DATA

# %%
df = load_df()
df = drop_all(df)
df = quality_filter(df)
# Out:
# ===== Loading Data
# ===== Dropping unnecessary features
# ===== Start Filtering for Confidence
# Before filtering: 23369 frames
# After filtering: 23123 frames
# ===== Finished Filtering

# %%
df = df.drop(columns=["confidence", "success", "duration"])

# %% [markdown]
# # 1. COMBINING DATA INTO ONE DATAFRAME

# %%
df
# Out:
#        AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  AU07_r  AU09_r  AU12_r  \
# 0        0.00    0.00    0.00    0.00    0.87    0.16    0.00     0.0
# 1        0.00    0.00    0.00    0.00    1.10    0.42    0.00     0.0
# 2        0.00    0.00    0.00    0.00    1.31    0.62    0.00     0.0
# 3        0.00    0.00    0.00    0.00    1.54    1.06    0.00     0.0
# 4        0.04    0.00    0.00    0.00    1.67    1.25    0.00     0.0
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 23364    0.33    0.38    0.81    0.23    0.01    1.34    0.05     0.0
# 23365    0.23    0.24    0.90    0.23    0.02    1.35    0.14     0.0
# 23366    0.12    0.12    0.90    0.27    0.06    1.54    0.19     0.0
# 23367    0.02    0.05    0.86    0.17    0.14    1.56    0.22     0.0
# 23368    0.00    0.00    0.77    0.03    0.25    1.32    0.17     0.0
#
#          clip_id  label source_id     appraisal
# 0        Art6_S2      1      Art6  Appreciation
# 1        Art6_S2      1      Art6  Appreciation
# 2        Art6_S2      1      Art6  Appreciation
# 3        Art6_S2      1      Art6  Appreciation
# 4        Art6_S2      1      Art6  Appreciation
# ...          ...    ...       ...           ...
# 23364  Tech21_S6      0    Tech21           NaN
# 23365  Tech21_S6      0    Tech21           NaN
# 23366  Tech21_S6      0    Tech21           NaN
# 23367  Tech21_S6      0    Tech21           NaN
# 23368  Tech21_S6      0    Tech21           NaN
#
# [23123 rows x 12 columns]

# %%
df.to_csv("../data/processed/combined.csv")

# %% [markdown]
# # 2. AGGREGATING DATA PER CLIP-ID (SIMPLE AGGREGATION)

# %%
df_simAgg = simple_aggregation(df)

# %%
df_simAgg
# Out:
#               AU01_r    AU02_r    AU04_r    AU05_r    AU06_r    AU07_r  \
# clip_id
# Art6_S2     0.217560  0.179464  0.253452  0.069881  0.721845  0.590000
# Art6_S32    0.281684  0.111053  0.234947  0.057789  0.586105  0.775158
# Art6_S36    0.176599  0.135476  0.436905  0.053095  1.178333  0.830884
# Art6_S43    0.339930  0.103427  0.470839  0.049790  0.508322  0.835664
# Art6_S6     0.076600  0.071600  0.618600  0.021800  0.602000  1.872200
# ...              ...       ...       ...       ...       ...       ...
# Tech21_S32  0.278000  0.060800  0.060400  0.006000  0.275600  1.212800
# Tech21_S33  0.122174  0.056957  0.358551  0.024783  0.287681  1.130145
# Tech21_S4   0.070357  0.037857  0.059286  0.017857  0.406429  1.712143
# Tech21_S5   0.100690  0.027931  0.045862  0.017586  0.403103  2.010690
# Tech21_S6   0.148816  0.070526  0.383158  0.038947  0.200921  1.521053
#
#               AU09_r    AU12_r  label source_id
# clip_id
# Art6_S2     0.089345  0.144940      1      Art6
# Art6_S32    0.103263  0.019263      1      Art6
# Art6_S36    0.092177  0.035816      1      Art6
# Art6_S43    0.061049  0.000420      0      Art6
# Art6_S6     0.036400  0.000000      0      Art6
# ...              ...       ...    ...       ...
# Tech21_S32  0.028400  0.653200      0    Tech21
# Tech21_S33  0.097826  0.367826      0    Tech21
# Tech21_S4   0.027857  0.203571      0    Tech21
# Tech21_S5   0.027586  0.237241      0    Tech21
# Tech21_S6   0.019868  0.093158      0    Tech21
#
# [134 rows x 10 columns]

# %%
df_simAgg.to_csv("../data/aggregated/simAgg.csv")

# %% [markdown]
# # 3. AGGREGATING DATA PER CLIP-ID (ADVANCED AGGREGATION)

# %%
df_advAgg = advanced_aggregation(df)

# %%
df_advAgg
# Out:
#             AU01_r_mean  AU01_r_std  AU01_r_q95  AU02_r_mean  AU02_r_std  \
# clip_id
# Art6_S2        0.217560    0.346387      1.0600     0.179464    0.466050
# Art6_S32       0.281684    0.438944      1.1990     0.111053    0.264034
# Art6_S36       0.176599    0.260498      0.7735     0.135476    0.332685
# Art6_S43       0.339930    0.533242      1.3790     0.103427    0.217347
# Art6_S6        0.076600    0.136361      0.3710     0.071600    0.156014
# ...                 ...         ...         ...          ...         ...
# Tech21_S32     0.278000    0.361813      0.9420     0.060800    0.115575
# Tech21_S33     0.122174    0.182530      0.5120     0.056957    0.108048
# Tech21_S4      0.070357    0.094418      0.2730     0.037857    0.082971
# Tech21_S5      0.100690    0.152689      0.4600     0.027931    0.051919
# Tech21_S6      0.148816    0.232276      0.7075     0.070526    0.160066
#
#             AU02_r_q95  AU04_r_mean  AU04_r_std  AU04_r_q95  AU05_r_mean  ...  \
# clip_id                                                                   ...
# Art6_S2         1.0245     0.253452    0.364526      1.1665     0.069881  ...
# Art6_S32        0.5700     0.234947    0.280425      0.7430     0.057789  ...
# Art6_S36        1.0700     0.436905    0.333330      1.1235     0.053095  ...
# Art6_S43        0.6300     0.470839    0.472517      1.2100     0.049790  ...
# Art6_S6         0.4110     0.618600    0.406523      1.3645     0.021800  ...
# ...                ...          ...         ...         ...          ...  ...
# Tech21_S32      0.3300     0.060400    0.066551      0.1820     0.006000  ...
# Tech21_S33      0.2960     0.358551    0.324324      0.9140     0.024783  ...
# Tech21_S4       0.2015     0.059286    0.099552      0.2600     0.017857  ...
# Tech21_S5       0.1100     0.045862    0.097816      0.2300     0.017586  ...
# Tech21_S6       0.4300     0.383158    0.327517      0.8925     0.038947  ...
#
#             AU07_r_std  AU07_r_q95  AU09_r_mean  AU09_r_std  AU09_r_q95  \
# clip_id
# Art6_S2       0.594709      1.9840     0.089345    0.163360      0.4860
# Art6_S32      0.733305      1.8960     0.103263    0.189329      0.5860
# Art6_S36      0.676368      2.1480     0.092177    0.164926      0.4800
# Art6_S43      0.557414      1.7370     0.061049    0.106584      0.3100
# Art6_S6       0.670334      3.1185     0.036400    0.049683      0.1255
# ...                ...         ...          ...         ...         ...
# Tech21_S32    0.200510      1.4580     0.028400    0.048017      0.1400
# Tech21_S33    0.405446      1.6700     0.097826    0.174127      0.5400
# Tech21_S4     0.365466      2.2995     0.027857    0.039661      0.0995
# Tech21_S5     0.269854      2.4640     0.027586    0.051036      0.1600
# Tech21_S6     0.321345      2.2525     0.019868    0.042599      0.0950
#
#             AU12_r_mean  AU12_r_std  AU12_r_q95  label  source_id
# clip_id
# Art6_S2        0.144940    0.445952       1.539      1       Art6
# Art6_S32       0.019263    0.081870       0.103      1       Art6
# Art6_S36       0.035816    0.143095       0.207      1       Art6
# Art6_S43       0.000420    0.002876       0.000      0       Art6
# Art6_S6        0.000000    0.000000       0.000      0       Art6
# ...                 ...         ...         ...    ...        ...
# Tech21_S32     0.653200    0.423101       1.306      0     Tech21
# Tech21_S33     0.367826    0.354014       1.136      0     Tech21
# Tech21_S4      0.203571    0.125114       0.393      0     Tech21
# Tech21_S5      0.237241    0.145820       0.470      0     Tech21
# Tech21_S6      0.093158    0.149231       0.440      0     Tech21
#
# [134 rows x 26 columns]

# %%
df_advAgg.to_csv("../data/aggregated/advAgg.csv")
