# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/combined.csv")

# %% [markdown]
# # ALL AU's

# %%
from src.MILArchitecture.full_pipelines import attention_based_mil
from src.utils.data import au_cols

_ = attention_based_mil(df, au_cols)
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6651 | Val Avg. Loss: 0.5791
# Epoch [1/25] | Train Bal. Acc: 0.5157 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6476 | Val Avg. Loss: 0.5318
# Epoch [2/25] | Train Bal. Acc: 0.5714 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6407 | Val Avg. Loss: 0.5539
# Epoch [3/25] | Train Bal. Acc: 0.5595 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6311 | Val Avg. Loss: 0.5787
# Epoch [4/25] | Train Bal. Acc: 0.5338 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6404 | Val Avg. Loss: 0.6150
# Epoch [5/25] | Train Bal. Acc: 0.5670 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6286 | Val Avg. Loss: 0.5719
# Epoch [6/25] | Train Bal. Acc: 0.6003 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6229 | Val Avg. Loss: 0.5327
# Epoch [7/25] | Train Bal. Acc: 0.5758 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6192 | Val Avg. Loss: 0.5334
# Epoch [8/25] | Train Bal. Acc: 0.5370 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6129 | Val Avg. Loss: 0.5510
# Epoch [9/25] | Train Bal. Acc: 0.5639 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6084 | Val Avg. Loss: 0.5688
# Epoch [10/25] | Train Bal. Acc: 0.5758 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5974 | Val Avg. Loss: 0.5635
# Epoch [11/25] | Train Bal. Acc: 0.5639 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5975 | Val Avg. Loss: 0.5770
# Epoch [12/25] | Train Bal. Acc: 0.5670 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5875 | Val Avg. Loss: 0.6035
# Epoch [13/25] | Train Bal. Acc: 0.6385 | Val Bal. Acc: 0.5559
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5881 | Val Avg. Loss: 0.5393
# Epoch [14/25] | Train Bal. Acc: 0.6623 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5826 | Val Avg. Loss: 0.5361
# Epoch [15/25] | Train Bal. Acc: 0.6472 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5609 | Val Avg. Loss: 0.5641
# Epoch [16/25] | Train Bal. Acc: 0.6685 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5579 | Val Avg. Loss: 0.5195
# Epoch [17/25] | Train Bal. Acc: 0.6836 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5921 | Val Avg. Loss: 0.4758
# Epoch [18/25] | Train Bal. Acc: 0.6535 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5627 | Val Avg. Loss: 0.5287
# Epoch [19/25] | Train Bal. Acc: 0.6416 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5608 | Val Avg. Loss: 0.5990
# Epoch [20/25] | Train Bal. Acc: 0.7312 | Val Bal. Acc: 0.5921
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5604 | Val Avg. Loss: 0.5996
# Epoch [21/25] | Train Bal. Acc: 0.7168 | Val Bal. Acc: 0.5921
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5403 | Val Avg. Loss: 0.5283
# Epoch [22/25] | Train Bal. Acc: 0.7256 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5397 | Val Avg. Loss: 0.5123
# Epoch [23/25] | Train Bal. Acc: 0.7043 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5399 | Val Avg. Loss: 0.5597
# Epoch [24/25] | Train Bal. Acc: 0.7281 | Val Bal. Acc: 0.7072
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5363 | Val Avg. Loss: 0.5372
# Epoch [25/25] | Train Bal. Acc: 0.7193 | Val Bal. Acc: 0.6086
# --------------------
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7016 | Val Avg. Loss: 0.6337
# Epoch [1/25] | Train Bal. Acc: 0.5238 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6854 | Val Avg. Loss: 0.6305
# Epoch [2/25] | Train Bal. Acc: 0.5238 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6666 | Val Avg. Loss: 0.6172
# Epoch [3/25] | Train Bal. Acc: 0.5476 | Val Bal. Acc: 0.6111
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6576 | Val Avg. Loss: 0.5933
# Epoch [4/25] | Train Bal. Acc: 0.5611 | Val Bal. Acc: 0.6768
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6445 | Val Avg. Loss: 0.5838
# Epoch [5/25] | Train Bal. Acc: 0.6214 | Val Bal. Acc: 0.6641
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6292 | Val Avg. Loss: 0.6042
# Epoch [6/25] | Train Bal. Acc: 0.6698 | Val Bal. Acc: 0.7626
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6214 | Val Avg. Loss: 0.6279
# Epoch [7/25] | Train Bal. Acc: 0.6976 | Val Bal. Acc: 0.6944
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6050 | Val Avg. Loss: 0.6435
# Epoch [8/25] | Train Bal. Acc: 0.7254 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5919 | Val Avg. Loss: 0.6439
# Epoch [9/25] | Train Bal. Acc: 0.7230 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5848 | Val Avg. Loss: 0.6424
# Epoch [10/25] | Train Bal. Acc: 0.6992 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5737 | Val Avg. Loss: 0.7288
# Epoch [11/25] | Train Bal. Acc: 0.7468 | Val Bal. Acc: 0.6818
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5684 | Val Avg. Loss: 0.7000
# Epoch [12/25] | Train Bal. Acc: 0.6794 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5523 | Val Avg. Loss: 0.6984
# Epoch [13/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5665 | Val Avg. Loss: 0.7718
# Epoch [14/25] | Train Bal. Acc: 0.7127 | Val Bal. Acc: 0.7045
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5344 | Val Avg. Loss: 0.7718
# Epoch [15/25] | Train Bal. Acc: 0.7373 | Val Bal. Acc: 0.7045
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5372 | Val Avg. Loss: 0.7760
# Epoch [16/25] | Train Bal. Acc: 0.7246 | Val Bal. Acc: 0.7045
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5258 | Val Avg. Loss: 0.7787
# Epoch [17/25] | Train Bal. Acc: 0.7460 | Val Bal. Acc: 0.6818
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5230 | Val Avg. Loss: 0.8245
# Epoch [18/25] | Train Bal. Acc: 0.7365 | Val Bal. Acc: 0.6818
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5253 | Val Avg. Loss: 0.8531
# Epoch [19/25] | Train Bal. Acc: 0.7484 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5409 | Val Avg. Loss: 0.8480
# Epoch [20/25] | Train Bal. Acc: 0.7135 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5142 | Val Avg. Loss: 0.8756
# Epoch [21/25] | Train Bal. Acc: 0.7587 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5178 | Val Avg. Loss: 0.9334
# Epoch [22/25] | Train Bal. Acc: 0.7127 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4918 | Val Avg. Loss: 0.8882
# Epoch [23/25] | Train Bal. Acc: 0.7698 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4952 | Val Avg. Loss: 0.9178
# Epoch [24/25] | Train Bal. Acc: 0.7468 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5002 | Val Avg. Loss: 0.9599
# Epoch [25/25] | Train Bal. Acc: 0.7357 | Val Bal. Acc: 0.6364
# --------------------
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6943 | Val Avg. Loss: 0.6686
# Epoch [1/25] | Train Bal. Acc: 0.5371 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6725 | Val Avg. Loss: 0.6208
# Epoch [2/25] | Train Bal. Acc: 0.6010 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6676 | Val Avg. Loss: 0.6101
# Epoch [3/25] | Train Bal. Acc: 0.5774 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6538 | Val Avg. Loss: 0.6416
# Epoch [4/25] | Train Bal. Acc: 0.6010 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6463 | Val Avg. Loss: 0.6749
# Epoch [5/25] | Train Bal. Acc: 0.6363 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.6668
# Epoch [6/25] | Train Bal. Acc: 0.6803 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6243 | Val Avg. Loss: 0.6592
# Epoch [7/25] | Train Bal. Acc: 0.6581 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6056 | Val Avg. Loss: 0.6700
# Epoch [8/25] | Train Bal. Acc: 0.7124 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5905 | Val Avg. Loss: 0.6992
# Epoch [9/25] | Train Bal. Acc: 0.7024 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5999 | Val Avg. Loss: 0.6955
# Epoch [10/25] | Train Bal. Acc: 0.6626 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5731 | Val Avg. Loss: 0.6584
# Epoch [11/25] | Train Bal. Acc: 0.7138 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5671 | Val Avg. Loss: 0.6641
# Epoch [12/25] | Train Bal. Acc: 0.6916 | Val Bal. Acc: 0.5952
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5759 | Val Avg. Loss: 0.6930
# Epoch [13/25] | Train Bal. Acc: 0.7024 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5482 | Val Avg. Loss: 0.6801
# Epoch [14/25] | Train Bal. Acc: 0.7341 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5512 | Val Avg. Loss: 0.6798
# Epoch [15/25] | Train Bal. Acc: 0.7341 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5208 | Val Avg. Loss: 0.6691
# Epoch [16/25] | Train Bal. Acc: 0.7450 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5581 | Val Avg. Loss: 0.6784
# Epoch [17/25] | Train Bal. Acc: 0.6911 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5234 | Val Avg. Loss: 0.7097
# Epoch [18/25] | Train Bal. Acc: 0.6925 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5035 | Val Avg. Loss: 0.7086
# Epoch [19/25] | Train Bal. Acc: 0.7681 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5547 | Val Avg. Loss: 0.6990
# Epoch [20/25] | Train Bal. Acc: 0.6916 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4971 | Val Avg. Loss: 0.7265
# Epoch [21/25] | Train Bal. Acc: 0.7885 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4844 | Val Avg. Loss: 0.7148
# Epoch [22/25] | Train Bal. Acc: 0.7785 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4727 | Val Avg. Loss: 0.7313
# Epoch [23/25] | Train Bal. Acc: 0.7772 | Val Bal. Acc: 0.4286
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4958 | Val Avg. Loss: 0.7702
# Epoch [24/25] | Train Bal. Acc: 0.7894 | Val Bal. Acc: 0.4286
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4603 | Val Avg. Loss: 0.7768
# Epoch [25/25] | Train Bal. Acc: 0.8220 | Val Bal. Acc: 0.5238
# --------------------
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6795 | Val Avg. Loss: 0.6073
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6702 | Val Avg. Loss: 0.6172
# Epoch [2/25] | Train Bal. Acc: 0.5114 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6567 | Val Avg. Loss: 0.6323
# Epoch [3/25] | Train Bal. Acc: 0.5455 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6395 | Val Avg. Loss: 0.6457
# Epoch [4/25] | Train Bal. Acc: 0.5568 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6338 | Val Avg. Loss: 0.6566
# Epoch [5/25] | Train Bal. Acc: 0.6136 | Val Bal. Acc: 0.5379
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6300 | Val Avg. Loss: 0.6815
# Epoch [6/25] | Train Bal. Acc: 0.5905 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6136 | Val Avg. Loss: 0.6699
# Epoch [7/25] | Train Bal. Acc: 0.5805 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6000 | Val Avg. Loss: 0.6762
# Epoch [8/25] | Train Bal. Acc: 0.5818 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5932 | Val Avg. Loss: 0.6898
# Epoch [9/25] | Train Bal. Acc: 0.6359 | Val Bal. Acc: 0.5530
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5845 | Val Avg. Loss: 0.7001
# Epoch [10/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.5076
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5864 | Val Avg. Loss: 0.7036
# Epoch [11/25] | Train Bal. Acc: 0.7168 | Val Bal. Acc: 0.5076
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5615 | Val Avg. Loss: 0.7164
# Epoch [12/25] | Train Bal. Acc: 0.7195 | Val Bal. Acc: 0.5227
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5498 | Val Avg. Loss: 0.7251
# Epoch [13/25] | Train Bal. Acc: 0.7523 | Val Bal. Acc: 0.5227
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5532 | Val Avg. Loss: 0.7220
# Epoch [14/25] | Train Bal. Acc: 0.7182 | Val Bal. Acc: 0.4621
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5463 | Val Avg. Loss: 0.7615
# Epoch [15/25] | Train Bal. Acc: 0.7223 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5303 | Val Avg. Loss: 0.7459
# Epoch [16/25] | Train Bal. Acc: 0.7677 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5195 | Val Avg. Loss: 0.7310
# Epoch [17/25] | Train Bal. Acc: 0.7336 | Val Bal. Acc: 0.6061
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4928 | Val Avg. Loss: 0.7122
# Epoch [18/25] | Train Bal. Acc: 0.7877 | Val Bal. Acc: 0.6061
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4906 | Val Avg. Loss: 0.7658
# Epoch [19/25] | Train Bal. Acc: 0.7564 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4700 | Val Avg. Loss: 0.7736
# Epoch [20/25] | Train Bal. Acc: 0.8105 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4941 | Val Avg. Loss: 0.7975
# Epoch [21/25] | Train Bal. Acc: 0.7750 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4718 | Val Avg. Loss: 0.7870
# Epoch [22/25] | Train Bal. Acc: 0.8091 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4532 | Val Avg. Loss: 0.7744
# Epoch [23/25] | Train Bal. Acc: 0.8191 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4203 | Val Avg. Loss: 0.7736
# Epoch [24/25] | Train Bal. Acc: 0.8532 | Val Bal. Acc: 0.6061
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4239 | Val Avg. Loss: 0.7483
# Epoch [25/25] | Train Bal. Acc: 0.8191 | Val Bal. Acc: 0.6515
# --------------------
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6905 | Val Avg. Loss: 0.6203
# Epoch [1/25] | Train Bal. Acc: 0.4396 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6539 | Val Avg. Loss: 0.5735
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6392 | Val Avg. Loss: 0.5464
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6365 | Val Avg. Loss: 0.5252
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6124 | Val Avg. Loss: 0.5358
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6052 | Val Avg. Loss: 0.5291
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5956 | Val Avg. Loss: 0.5221
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5795 | Val Avg. Loss: 0.5052
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5767 | Val Avg. Loss: 0.5099
# Epoch [9/25] | Train Bal. Acc: 0.5294 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5619 | Val Avg. Loss: 0.4888
# Epoch [10/25] | Train Bal. Acc: 0.5441 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5505 | Val Avg. Loss: 0.4960
# Epoch [11/25] | Train Bal. Acc: 0.5762 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5349 | Val Avg. Loss: 0.5033
# Epoch [12/25] | Train Bal. Acc: 0.6523 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5330 | Val Avg. Loss: 0.4601
# Epoch [13/25] | Train Bal. Acc: 0.6581 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5191 | Val Avg. Loss: 0.4766
# Epoch [14/25] | Train Bal. Acc: 0.6759 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5117 | Val Avg. Loss: 0.4589
# Epoch [15/25] | Train Bal. Acc: 0.7169 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5014 | Val Avg. Loss: 0.4648
# Epoch [16/25] | Train Bal. Acc: 0.6933 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5282 | Val Avg. Loss: 0.5193
# Epoch [17/25] | Train Bal. Acc: 0.7400 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4874 | Val Avg. Loss: 0.4188
# Epoch [18/25] | Train Bal. Acc: 0.7579 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4839 | Val Avg. Loss: 0.4194
# Epoch [19/25] | Train Bal. Acc: 0.6875 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4945 | Val Avg. Loss: 0.4604
# Epoch [20/25] | Train Bal. Acc: 0.7342 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4898 | Val Avg. Loss: 0.4182
# Epoch [21/25] | Train Bal. Acc: 0.7726 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4678 | Val Avg. Loss: 0.4097
# Epoch [22/25] | Train Bal. Acc: 0.6933 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4511 | Val Avg. Loss: 0.4323
# Epoch [23/25] | Train Bal. Acc: 0.7700 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4641 | Val Avg. Loss: 0.4323
# Epoch [24/25] | Train Bal. Acc: 0.7547 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4597 | Val Avg. Loss: 0.3978
# Epoch [25/25] | Train Bal. Acc: 0.7637 | Val Bal. Acc: 0.7237
# --------------------
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7062 | Val Avg. Loss: 0.6964
# Epoch [1/25] | Train Bal. Acc: 0.4677 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6190 | Val Avg. Loss: 0.7383
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6004 | Val Avg. Loss: 0.8487
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6018 | Val Avg. Loss: 0.8795
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5866 | Val Avg. Loss: 0.8095
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5730 | Val Avg. Loss: 0.7952
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5743 | Val Avg. Loss: 0.8047
# Epoch [7/25] | Train Bal. Acc: 0.5156 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5666 | Val Avg. Loss: 0.8167
# Epoch [8/25] | Train Bal. Acc: 0.5469 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5540 | Val Avg. Loss: 0.8431
# Epoch [9/25] | Train Bal. Acc: 0.5625 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5615 | Val Avg. Loss: 0.8778
# Epoch [10/25] | Train Bal. Acc: 0.5542 | Val Bal. Acc: 0.5294
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5419 | Val Avg. Loss: 0.9005
# Epoch [11/25] | Train Bal. Acc: 0.6010 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5241 | Val Avg. Loss: 0.9002
# Epoch [12/25] | Train Bal. Acc: 0.6167 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5253 | Val Avg. Loss: 0.9374
# Epoch [13/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.4973 | Val Avg. Loss: 0.9637
# Epoch [14/25] | Train Bal. Acc: 0.6312 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.4837 | Val Avg. Loss: 0.9707
# Epoch [15/25] | Train Bal. Acc: 0.6615 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.4640 | Val Avg. Loss: 1.1548
# Epoch [16/25] | Train Bal. Acc: 0.6458 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.4570 | Val Avg. Loss: 1.1507
# Epoch [17/25] | Train Bal. Acc: 0.6687 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4554 | Val Avg. Loss: 1.0275
# Epoch [18/25] | Train Bal. Acc: 0.7229 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4288 | Val Avg. Loss: 1.1984
# Epoch [19/25] | Train Bal. Acc: 0.7854 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4303 | Val Avg. Loss: 1.2512
# Epoch [20/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4184 | Val Avg. Loss: 1.2143
# Epoch [21/25] | Train Bal. Acc: 0.7635 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.3942 | Val Avg. Loss: 1.1843
# Epoch [22/25] | Train Bal. Acc: 0.7854 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4088 | Val Avg. Loss: 1.2117
# Epoch [23/25] | Train Bal. Acc: 0.7625 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4123 | Val Avg. Loss: 1.2671
# Epoch [24/25] | Train Bal. Acc: 0.7854 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.3904 | Val Avg. Loss: 1.3551
# Epoch [25/25] | Train Bal. Acc: 0.7865 | Val Bal. Acc: 0.6140
# --------------------
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6014 | Val Avg. Loss: 0.9388
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.5550 | Val Avg. Loss: 1.1421
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5456 | Val Avg. Loss: 1.0629
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5324 | Val Avg. Loss: 0.9515
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5242 | Val Avg. Loss: 0.8939
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5054 | Val Avg. Loss: 0.9641
# Epoch [6/25] | Train Bal. Acc: 0.5500 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.4980 | Val Avg. Loss: 0.9871
# Epoch [7/25] | Train Bal. Acc: 0.5746 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.4943 | Val Avg. Loss: 0.9752
# Epoch [8/25] | Train Bal. Acc: 0.6158 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.4935 | Val Avg. Loss: 1.0541
# Epoch [9/25] | Train Bal. Acc: 0.6149 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.4763 | Val Avg. Loss: 1.0115
# Epoch [10/25] | Train Bal. Acc: 0.6316 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.4899 | Val Avg. Loss: 0.8856
# Epoch [11/25] | Train Bal. Acc: 0.6632 | Val Bal. Acc: 0.6803
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.4824 | Val Avg. Loss: 0.9880
# Epoch [12/25] | Train Bal. Acc: 0.6623 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.4660 | Val Avg. Loss: 1.0635
# Epoch [13/25] | Train Bal. Acc: 0.6719 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.4586 | Val Avg. Loss: 1.0726
# Epoch [14/25] | Train Bal. Acc: 0.6465 | Val Bal. Acc: 0.5865
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.4479 | Val Avg. Loss: 0.9973
# Epoch [15/25] | Train Bal. Acc: 0.6807 | Val Bal. Acc: 0.6803
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.4485 | Val Avg. Loss: 0.9737
# Epoch [16/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.4366 | Val Avg. Loss: 1.1008
# Epoch [17/25] | Train Bal. Acc: 0.7789 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4258 | Val Avg. Loss: 1.1927
# Epoch [18/25] | Train Bal. Acc: 0.7632 | Val Bal. Acc: 0.5865
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.3952 | Val Avg. Loss: 1.1428
# Epoch [19/25] | Train Bal. Acc: 0.7044 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4082 | Val Avg. Loss: 1.1109
# Epoch [20/25] | Train Bal. Acc: 0.7789 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4008 | Val Avg. Loss: 1.1667
# Epoch [21/25] | Train Bal. Acc: 0.7544 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.3989 | Val Avg. Loss: 1.1574
# Epoch [22/25] | Train Bal. Acc: 0.7719 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.3774 | Val Avg. Loss: 1.1656
# Epoch [23/25] | Train Bal. Acc: 0.7965 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.3624 | Val Avg. Loss: 1.1774
# Epoch [24/25] | Train Bal. Acc: 0.8298 | Val Bal. Acc: 0.5721
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.3712 | Val Avg. Loss: 1.2770
# Epoch [25/25] | Train Bal. Acc: 0.7956 | Val Bal. Acc: 0.6106
# --------------------
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6895 | Val Avg. Loss: 0.6051
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6694 | Val Avg. Loss: 0.6547
# Epoch [2/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6602 | Val Avg. Loss: 0.6689
# Epoch [3/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6539 | Val Avg. Loss: 0.6963
# Epoch [4/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6527 | Val Avg. Loss: 0.7365
# Epoch [5/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.2500
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6457 | Val Avg. Loss: 0.7056
# Epoch [6/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.3125
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6351 | Val Avg. Loss: 0.6740
# Epoch [7/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6332 | Val Avg. Loss: 0.6887
# Epoch [8/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6200 | Val Avg. Loss: 0.6873
# Epoch [9/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6178 | Val Avg. Loss: 0.6742
# Epoch [10/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6042 | Val Avg. Loss: 0.6315
# Epoch [11/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6121 | Val Avg. Loss: 0.6348
# Epoch [12/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5808 | Val Avg. Loss: 0.6209
# Epoch [13/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5921 | Val Avg. Loss: 0.6182
# Epoch [14/25] | Train Bal. Acc: 0.7222 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5800 | Val Avg. Loss: 0.6391
# Epoch [15/25] | Train Bal. Acc: 0.7222 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5641 | Val Avg. Loss: 0.6483
# Epoch [16/25] | Train Bal. Acc: 0.7444 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5599 | Val Avg. Loss: 0.6436
# Epoch [17/25] | Train Bal. Acc: 0.7333 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5517 | Val Avg. Loss: 0.6535
# Epoch [18/25] | Train Bal. Acc: 0.7111 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5348 | Val Avg. Loss: 0.6627
# Epoch [19/25] | Train Bal. Acc: 0.7333 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5286 | Val Avg. Loss: 0.6605
# Epoch [20/25] | Train Bal. Acc: 0.7667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5130 | Val Avg. Loss: 0.6301
# Epoch [21/25] | Train Bal. Acc: 0.7778 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4946 | Val Avg. Loss: 0.6541
# Epoch [22/25] | Train Bal. Acc: 0.7667 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5113 | Val Avg. Loss: 0.7167
# Epoch [23/25] | Train Bal. Acc: 0.7333 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5022 | Val Avg. Loss: 0.6921
# Epoch [24/25] | Train Bal. Acc: 0.7778 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4781 | Val Avg. Loss: 0.7039
# Epoch [25/25] | Train Bal. Acc: 0.7889 | Val Bal. Acc: 0.6250
# --------------------
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7022 | Val Avg. Loss: 0.6304
# Epoch [1/25] | Train Bal. Acc: 0.4737 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6886 | Val Avg. Loss: 0.6173
# Epoch [2/25] | Train Bal. Acc: 0.4886 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6811 | Val Avg. Loss: 0.6517
# Epoch [3/25] | Train Bal. Acc: 0.5973 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6767 | Val Avg. Loss: 0.6311
# Epoch [4/25] | Train Bal. Acc: 0.6399 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6589 | Val Avg. Loss: 0.5878
# Epoch [5/25] | Train Bal. Acc: 0.6401 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6603 | Val Avg. Loss: 0.5732
# Epoch [6/25] | Train Bal. Acc: 0.6181 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6330 | Val Avg. Loss: 0.5927
# Epoch [7/25] | Train Bal. Acc: 0.6611 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6316 | Val Avg. Loss: 0.6079
# Epoch [8/25] | Train Bal. Acc: 0.7254 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6383 | Val Avg. Loss: 0.6526
# Epoch [9/25] | Train Bal. Acc: 0.7022 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6108 | Val Avg. Loss: 0.5942
# Epoch [10/25] | Train Bal. Acc: 0.7357 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6132 | Val Avg. Loss: 0.5909
# Epoch [11/25] | Train Bal. Acc: 0.7036 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6206 | Val Avg. Loss: 0.6337
# Epoch [12/25] | Train Bal. Acc: 0.7138 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5924 | Val Avg. Loss: 0.6089
# Epoch [13/25] | Train Bal. Acc: 0.7251 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6096 | Val Avg. Loss: 0.6097
# Epoch [14/25] | Train Bal. Acc: 0.6807 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5830 | Val Avg. Loss: 0.6350
# Epoch [15/25] | Train Bal. Acc: 0.7348 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5746 | Val Avg. Loss: 0.5908
# Epoch [16/25] | Train Bal. Acc: 0.6918 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5851 | Val Avg. Loss: 0.5858
# Epoch [17/25] | Train Bal. Acc: 0.6930 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5773 | Val Avg. Loss: 0.6570
# Epoch [18/25] | Train Bal. Acc: 0.7135 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5676 | Val Avg. Loss: 0.6620
# Epoch [19/25] | Train Bal. Acc: 0.7343 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5559 | Val Avg. Loss: 0.5918
# Epoch [20/25] | Train Bal. Acc: 0.6923 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5521 | Val Avg. Loss: 0.6209
# Epoch [21/25] | Train Bal. Acc: 0.7471 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5518 | Val Avg. Loss: 0.5935
# Epoch [22/25] | Train Bal. Acc: 0.7365 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5344 | Val Avg. Loss: 0.6210
# Epoch [23/25] | Train Bal. Acc: 0.7469 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5098 | Val Avg. Loss: 0.6392
# Epoch [24/25] | Train Bal. Acc: 0.7913 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5211 | Val Avg. Loss: 0.6895
# Epoch [25/25] | Train Bal. Acc: 0.7355 | Val Bal. Acc: 0.5000
# --------------------
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6918 | Val Avg. Loss: 0.6907
# Epoch [1/25] | Train Bal. Acc: 0.5356 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6123 | Val Avg. Loss: 0.7613
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5942 | Val Avg. Loss: 0.8294
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5808 | Val Avg. Loss: 0.8023
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5294
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5714 | Val Avg. Loss: 0.7764
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5641 | Val Avg. Loss: 0.7782
# Epoch [6/25] | Train Bal. Acc: 0.5172 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5526 | Val Avg. Loss: 0.7725
# Epoch [7/25] | Train Bal. Acc: 0.5345 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5434 | Val Avg. Loss: 0.8125
# Epoch [8/25] | Train Bal. Acc: 0.5345 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5260 | Val Avg. Loss: 0.8527
# Epoch [9/25] | Train Bal. Acc: 0.5608 | Val Bal. Acc: 0.6471
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5281 | Val Avg. Loss: 0.8367
# Epoch [10/25] | Train Bal. Acc: 0.5780 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5066 | Val Avg. Loss: 0.9318
# Epoch [11/25] | Train Bal. Acc: 0.6207 | Val Bal. Acc: 0.6452
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.4867 | Val Avg. Loss: 0.9366
# Epoch [12/25] | Train Bal. Acc: 0.6379 | Val Bal. Acc: 0.5827
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.4805 | Val Avg. Loss: 1.0359
# Epoch [13/25] | Train Bal. Acc: 0.6215 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.4542 | Val Avg. Loss: 1.0286
# Epoch [14/25] | Train Bal. Acc: 0.6215 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.4492 | Val Avg. Loss: 1.0645
# Epoch [15/25] | Train Bal. Acc: 0.7077 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.4339 | Val Avg. Loss: 1.2320
# Epoch [16/25] | Train Bal. Acc: 0.6478 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.4284 | Val Avg. Loss: 1.1978
# Epoch [17/25] | Train Bal. Acc: 0.6733 | Val Bal. Acc: 0.6434
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4276 | Val Avg. Loss: 1.1091
# Epoch [18/25] | Train Bal. Acc: 0.7422 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.3998 | Val Avg. Loss: 1.1912
# Epoch [19/25] | Train Bal. Acc: 0.7513 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4106 | Val Avg. Loss: 1.1671
# Epoch [20/25] | Train Bal. Acc: 0.7176 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4049 | Val Avg. Loss: 1.1642
# Epoch [21/25] | Train Bal. Acc: 0.7267 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.3837 | Val Avg. Loss: 1.2240
# Epoch [22/25] | Train Bal. Acc: 0.8120 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.3851 | Val Avg. Loss: 1.2953
# Epoch [23/25] | Train Bal. Acc: 0.7858 | Val Bal. Acc: 0.6434
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.3668 | Val Avg. Loss: 1.1901
# Epoch [24/25] | Train Bal. Acc: 0.7858 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.3682 | Val Avg. Loss: 1.2459
# Epoch [25/25] | Train Bal. Acc: 0.7866 | Val Bal. Acc: 0.6121
# --------------------
# Accuracy (Balanced): 0.5817129629629629
# Avg. Loss: 0.7684920488229764
#               precision    recall  f1-score   support
#
#            0       0.52      0.43      0.47        54
#            1       0.66      0.74      0.69        80
#
#     accuracy                           0.61       134
#    macro avg       0.59      0.58      0.58       134
# weighted avg       0.60      0.61      0.60       134

# %% [markdown]
# # OUTER BROW RAISER & UPPER LID RAISER

# %%
attention_results = attention_based_mil(df, ["AU02_r", "AU12_r"])
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6763 | Val Avg. Loss: 0.6536
# Epoch [1/25] | Train Bal. Acc: 0.5251 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6612 | Val Avg. Loss: 0.5745
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6587 | Val Avg. Loss: 0.5815
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6527 | Val Avg. Loss: 0.5997
# Epoch [4/25] | Train Bal. Acc: 0.5301 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6506 | Val Avg. Loss: 0.6395
# Epoch [5/25] | Train Bal. Acc: 0.5934 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6482 | Val Avg. Loss: 0.6072
# Epoch [6/25] | Train Bal. Acc: 0.5821 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6417 | Val Avg. Loss: 0.5675
# Epoch [7/25] | Train Bal. Acc: 0.5695 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6442 | Val Avg. Loss: 0.5670
# Epoch [8/25] | Train Bal. Acc: 0.5576 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6471 | Val Avg. Loss: 0.5671
# Epoch [9/25] | Train Bal. Acc: 0.5758 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6331 | Val Avg. Loss: 0.5684
# Epoch [10/25] | Train Bal. Acc: 0.5727 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6476 | Val Avg. Loss: 0.5707
# Epoch [11/25] | Train Bal. Acc: 0.5520 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6406 | Val Avg. Loss: 0.5979
# Epoch [12/25] | Train Bal. Acc: 0.5877 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6410 | Val Avg. Loss: 0.6450
# Epoch [13/25] | Train Bal. Acc: 0.6479 | Val Bal. Acc: 0.5921
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6393 | Val Avg. Loss: 0.6236
# Epoch [14/25] | Train Bal. Acc: 0.6335 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6395 | Val Avg. Loss: 0.6225
# Epoch [15/25] | Train Bal. Acc: 0.6654 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6314 | Val Avg. Loss: 0.6158
# Epoch [16/25] | Train Bal. Acc: 0.6573 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6303 | Val Avg. Loss: 0.5789
# Epoch [17/25] | Train Bal. Acc: 0.6479 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6350 | Val Avg. Loss: 0.5524
# Epoch [18/25] | Train Bal. Acc: 0.6385 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6342 | Val Avg. Loss: 0.5565
# Epoch [19/25] | Train Bal. Acc: 0.6353 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6292 | Val Avg. Loss: 0.5719
# Epoch [20/25] | Train Bal. Acc: 0.6385 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6247 | Val Avg. Loss: 0.6037
# Epoch [21/25] | Train Bal. Acc: 0.6535 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6405 | Val Avg. Loss: 0.6136
# Epoch [22/25] | Train Bal. Acc: 0.6779 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6269 | Val Avg. Loss: 0.5805
# Epoch [23/25] | Train Bal. Acc: 0.6660 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.5474
# Epoch [24/25] | Train Bal. Acc: 0.6385 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6343 | Val Avg. Loss: 0.5297
# Epoch [25/25] | Train Bal. Acc: 0.6147 | Val Bal. Acc: 0.6349
# --------------------
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7187 | Val Avg. Loss: 0.7023
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6926 | Val Avg. Loss: 0.6760
# Epoch [2/25] | Train Bal. Acc: 0.4810 | Val Bal. Acc: 0.5328
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6887 | Val Avg. Loss: 0.6577
# Epoch [3/25] | Train Bal. Acc: 0.5238 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6888 | Val Avg. Loss: 0.6396
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6884 | Val Avg. Loss: 0.6327
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6788 | Val Avg. Loss: 0.6369
# Epoch [6/25] | Train Bal. Acc: 0.4889 | Val Bal. Acc: 0.5556
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6777 | Val Avg. Loss: 0.6393
# Epoch [7/25] | Train Bal. Acc: 0.5595 | Val Bal. Acc: 0.6439
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6735 | Val Avg. Loss: 0.6459
# Epoch [8/25] | Train Bal. Acc: 0.5635 | Val Bal. Acc: 0.6540
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6695 | Val Avg. Loss: 0.6547
# Epoch [9/25] | Train Bal. Acc: 0.6119 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6677 | Val Avg. Loss: 0.6478
# Epoch [10/25] | Train Bal. Acc: 0.6381 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6632 | Val Avg. Loss: 0.6581
# Epoch [11/25] | Train Bal. Acc: 0.6500 | Val Bal. Acc: 0.6616
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6607 | Val Avg. Loss: 0.6197
# Epoch [12/25] | Train Bal. Acc: 0.6738 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6510 | Val Avg. Loss: 0.6172
# Epoch [13/25] | Train Bal. Acc: 0.6722 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6535 | Val Avg. Loss: 0.6896
# Epoch [14/25] | Train Bal. Acc: 0.6651 | Val Bal. Acc: 0.5707
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6488 | Val Avg. Loss: 0.6799
# Epoch [15/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5707
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6354 | Val Avg. Loss: 0.6298
# Epoch [16/25] | Train Bal. Acc: 0.6643 | Val Bal. Acc: 0.6843
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6592 | Val Avg. Loss: 0.6266
# Epoch [17/25] | Train Bal. Acc: 0.6746 | Val Bal. Acc: 0.6843
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6308 | Val Avg. Loss: 0.6637
# Epoch [18/25] | Train Bal. Acc: 0.6873 | Val Bal. Acc: 0.5934
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6316 | Val Avg. Loss: 0.6664
# Epoch [19/25] | Train Bal. Acc: 0.6548 | Val Bal. Acc: 0.5480
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6382 | Val Avg. Loss: 0.6741
# Epoch [20/25] | Train Bal. Acc: 0.6540 | Val Bal. Acc: 0.5480
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6294 | Val Avg. Loss: 0.7202
# Epoch [21/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5480
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6237 | Val Avg. Loss: 0.6530
# Epoch [22/25] | Train Bal. Acc: 0.6310 | Val Bal. Acc: 0.6389
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6342 | Val Avg. Loss: 0.7057
# Epoch [23/25] | Train Bal. Acc: 0.6770 | Val Bal. Acc: 0.5480
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6144 | Val Avg. Loss: 0.6815
# Epoch [24/25] | Train Bal. Acc: 0.6540 | Val Bal. Acc: 0.5707
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.6759
# Epoch [25/25] | Train Bal. Acc: 0.6548 | Val Bal. Acc: 0.5707
# --------------------
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7058 | Val Avg. Loss: 0.6186
# Epoch [1/25] | Train Bal. Acc: 0.4796 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6879 | Val Avg. Loss: 0.6286
# Epoch [2/25] | Train Bal. Acc: 0.5453 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6860 | Val Avg. Loss: 0.6143
# Epoch [3/25] | Train Bal. Acc: 0.5688 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6788 | Val Avg. Loss: 0.6177
# Epoch [4/25] | Train Bal. Acc: 0.5679 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6829 | Val Avg. Loss: 0.6430
# Epoch [5/25] | Train Bal. Acc: 0.5924 | Val Bal. Acc: 0.7381
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6725 | Val Avg. Loss: 0.6279
# Epoch [6/25] | Train Bal. Acc: 0.6264 | Val Bal. Acc: 0.7619
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6716 | Val Avg. Loss: 0.6154
# Epoch [7/25] | Train Bal. Acc: 0.6250 | Val Bal. Acc: 0.7381
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6778 | Val Avg. Loss: 0.5947
# Epoch [8/25] | Train Bal. Acc: 0.6123 | Val Bal. Acc: 0.5952
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6682 | Val Avg. Loss: 0.6260
# Epoch [9/25] | Train Bal. Acc: 0.6449 | Val Bal. Acc: 0.7381
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6607 | Val Avg. Loss: 0.6460
# Epoch [10/25] | Train Bal. Acc: 0.6055 | Val Bal. Acc: 0.8095
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6643 | Val Avg. Loss: 0.6273
# Epoch [11/25] | Train Bal. Acc: 0.6159 | Val Bal. Acc: 0.7857
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6632 | Val Avg. Loss: 0.6157
# Epoch [12/25] | Train Bal. Acc: 0.6055 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6652 | Val Avg. Loss: 0.6259
# Epoch [13/25] | Train Bal. Acc: 0.6259 | Val Bal. Acc: 0.7381
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6587 | Val Avg. Loss: 0.6077
# Epoch [14/25] | Train Bal. Acc: 0.6698 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6616 | Val Avg. Loss: 0.6187
# Epoch [15/25] | Train Bal. Acc: 0.6146 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6543 | Val Avg. Loss: 0.6248
# Epoch [16/25] | Train Bal. Acc: 0.6807 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6508 | Val Avg. Loss: 0.6163
# Epoch [17/25] | Train Bal. Acc: 0.6689 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6510 | Val Avg. Loss: 0.6230
# Epoch [18/25] | Train Bal. Acc: 0.6363 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6425 | Val Avg. Loss: 0.6428
# Epoch [19/25] | Train Bal. Acc: 0.6585 | Val Bal. Acc: 0.6905
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6344 | Val Avg. Loss: 0.6276
# Epoch [20/25] | Train Bal. Acc: 0.6694 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6309 | Val Avg. Loss: 0.6329
# Epoch [21/25] | Train Bal. Acc: 0.6486 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6322 | Val Avg. Loss: 0.6200
# Epoch [22/25] | Train Bal. Acc: 0.6685 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6367 | Val Avg. Loss: 0.6199
# Epoch [23/25] | Train Bal. Acc: 0.6486 | Val Bal. Acc: 0.6905
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6344 | Val Avg. Loss: 0.6339
# Epoch [24/25] | Train Bal. Acc: 0.6590 | Val Bal. Acc: 0.6905
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6377 | Val Avg. Loss: 0.6648
# Epoch [25/25] | Train Bal. Acc: 0.6821 | Val Bal. Acc: 0.6667
# --------------------
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6893 | Val Avg. Loss: 0.5827
# Epoch [1/25] | Train Bal. Acc: 0.5464 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6789 | Val Avg. Loss: 0.5635
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6718 | Val Avg. Loss: 0.5632
# Epoch [3/25] | Train Bal. Acc: 0.5114 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6696 | Val Avg. Loss: 0.5940
# Epoch [4/25] | Train Bal. Acc: 0.5409 | Val Bal. Acc: 0.6212
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6522 | Val Avg. Loss: 0.6112
# Epoch [5/25] | Train Bal. Acc: 0.6259 | Val Bal. Acc: 0.6970
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6646 | Val Avg. Loss: 0.6425
# Epoch [6/25] | Train Bal. Acc: 0.6014 | Val Bal. Acc: 0.7348
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6433 | Val Avg. Loss: 0.5846
# Epoch [7/25] | Train Bal. Acc: 0.6868 | Val Bal. Acc: 0.7197
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6494 | Val Avg. Loss: 0.5723
# Epoch [8/25] | Train Bal. Acc: 0.6159 | Val Bal. Acc: 0.6364
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6442 | Val Avg. Loss: 0.6036
# Epoch [9/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6396 | Val Avg. Loss: 0.6164
# Epoch [10/25] | Train Bal. Acc: 0.6314 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6379 | Val Avg. Loss: 0.5885
# Epoch [11/25] | Train Bal. Acc: 0.6555 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6219 | Val Avg. Loss: 0.6034
# Epoch [12/25] | Train Bal. Acc: 0.6755 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6509 | Val Avg. Loss: 0.6188
# Epoch [13/25] | Train Bal. Acc: 0.6582 | Val Bal. Acc: 0.7348
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6351 | Val Avg. Loss: 0.6112
# Epoch [14/25] | Train Bal. Acc: 0.6668 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6226 | Val Avg. Loss: 0.6150
# Epoch [15/25] | Train Bal. Acc: 0.7323 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6167 | Val Avg. Loss: 0.6028
# Epoch [16/25] | Train Bal. Acc: 0.6595 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6300 | Val Avg. Loss: 0.5990
# Epoch [17/25] | Train Bal. Acc: 0.6882 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6252 | Val Avg. Loss: 0.5926
# Epoch [18/25] | Train Bal. Acc: 0.6895 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6198 | Val Avg. Loss: 0.6384
# Epoch [19/25] | Train Bal. Acc: 0.6768 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6029 | Val Avg. Loss: 0.6201
# Epoch [20/25] | Train Bal. Acc: 0.6923 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6126 | Val Avg. Loss: 0.5964
# Epoch [21/25] | Train Bal. Acc: 0.6855 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6131 | Val Avg. Loss: 0.6230
# Epoch [22/25] | Train Bal. Acc: 0.6995 | Val Bal. Acc: 0.6288
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6201 | Val Avg. Loss: 0.5994
# Epoch [23/25] | Train Bal. Acc: 0.6895 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6315 | Val Avg. Loss: 0.5804
# Epoch [24/25] | Train Bal. Acc: 0.7055 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5901 | Val Avg. Loss: 0.6040
# Epoch [25/25] | Train Bal. Acc: 0.7395 | Val Bal. Acc: 0.6515
# --------------------
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6579 | Val Avg. Loss: 0.5444
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6284 | Val Avg. Loss: 0.5179
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6284 | Val Avg. Loss: 0.5411
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6201 | Val Avg. Loss: 0.5413
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6225 | Val Avg. Loss: 0.5587
# Epoch [5/25] | Train Bal. Acc: 0.5294 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6291 | Val Avg. Loss: 0.5434
# Epoch [6/25] | Train Bal. Acc: 0.5614 | Val Bal. Acc: 0.5362
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6137 | Val Avg. Loss: 0.5407
# Epoch [7/25] | Train Bal. Acc: 0.5347 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5974 | Val Avg. Loss: 0.5263
# Epoch [8/25] | Train Bal. Acc: 0.5966 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6209 | Val Avg. Loss: 0.5234
# Epoch [9/25] | Train Bal. Acc: 0.5788 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6011 | Val Avg. Loss: 0.5277
# Epoch [10/25] | Train Bal. Acc: 0.5788 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6104 | Val Avg. Loss: 0.5269
# Epoch [11/25] | Train Bal. Acc: 0.5993 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6043 | Val Avg. Loss: 0.5280
# Epoch [12/25] | Train Bal. Acc: 0.6050 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6008 | Val Avg. Loss: 0.5164
# Epoch [13/25] | Train Bal. Acc: 0.6287 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6025 | Val Avg. Loss: 0.5306
# Epoch [14/25] | Train Bal. Acc: 0.6492 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6059 | Val Avg. Loss: 0.5052
# Epoch [15/25] | Train Bal. Acc: 0.6255 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5937 | Val Avg. Loss: 0.5158
# Epoch [16/25] | Train Bal. Acc: 0.6197 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6134 | Val Avg. Loss: 0.5646
# Epoch [17/25] | Train Bal. Acc: 0.6959 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6085 | Val Avg. Loss: 0.5417
# Epoch [18/25] | Train Bal. Acc: 0.6959 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5941 | Val Avg. Loss: 0.5083
# Epoch [19/25] | Train Bal. Acc: 0.6402 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5828 | Val Avg. Loss: 0.5119
# Epoch [20/25] | Train Bal. Acc: 0.6345 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5910 | Val Avg. Loss: 0.5123
# Epoch [21/25] | Train Bal. Acc: 0.6492 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6053 | Val Avg. Loss: 0.5173
# Epoch [22/25] | Train Bal. Acc: 0.6108 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5726 | Val Avg. Loss: 0.5255
# Epoch [23/25] | Train Bal. Acc: 0.7138 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5937 | Val Avg. Loss: 0.5365
# Epoch [24/25] | Train Bal. Acc: 0.6780 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5883 | Val Avg. Loss: 0.5279
# Epoch [25/25] | Train Bal. Acc: 0.6812 | Val Bal. Acc: 0.6349
# --------------------
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7106 | Val Avg. Loss: 0.6984
# Epoch [1/25] | Train Bal. Acc: 0.4760 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6094 | Val Avg. Loss: 0.7566
# Epoch [2/25] | Train Bal. Acc: 0.5469 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5920 | Val Avg. Loss: 0.8597
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5887 | Val Avg. Loss: 0.8267
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6050 | Val Avg. Loss: 0.7581
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5878 | Val Avg. Loss: 0.7487
# Epoch [6/25] | Train Bal. Acc: 0.5156 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5750 | Val Avg. Loss: 0.7630
# Epoch [7/25] | Train Bal. Acc: 0.5302 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5853 | Val Avg. Loss: 0.7708
# Epoch [8/25] | Train Bal. Acc: 0.5771 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5703 | Val Avg. Loss: 0.7761
# Epoch [9/25] | Train Bal. Acc: 0.5760 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5706 | Val Avg. Loss: 0.7707
# Epoch [10/25] | Train Bal. Acc: 0.5833 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5801 | Val Avg. Loss: 0.7830
# Epoch [11/25] | Train Bal. Acc: 0.5750 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5707 | Val Avg. Loss: 0.7628
# Epoch [12/25] | Train Bal. Acc: 0.5750 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5643 | Val Avg. Loss: 0.7727
# Epoch [13/25] | Train Bal. Acc: 0.6062 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5589 | Val Avg. Loss: 0.7744
# Epoch [14/25] | Train Bal. Acc: 0.6062 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5692 | Val Avg. Loss: 0.7570
# Epoch [15/25] | Train Bal. Acc: 0.6135 | Val Bal. Acc: 0.5827
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5587 | Val Avg. Loss: 0.7771
# Epoch [16/25] | Train Bal. Acc: 0.6135 | Val Bal. Acc: 0.6452
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5508 | Val Avg. Loss: 0.7850
# Epoch [17/25] | Train Bal. Acc: 0.6292 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5481 | Val Avg. Loss: 0.7662
# Epoch [18/25] | Train Bal. Acc: 0.6448 | Val Bal. Acc: 0.5515
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5510 | Val Avg. Loss: 0.7554
# Epoch [19/25] | Train Bal. Acc: 0.7146 | Val Bal. Acc: 0.5809
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5522 | Val Avg. Loss: 0.7806
# Epoch [20/25] | Train Bal. Acc: 0.6677 | Val Bal. Acc: 0.5515
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5499 | Val Avg. Loss: 0.8103
# Epoch [21/25] | Train Bal. Acc: 0.6760 | Val Bal. Acc: 0.5827
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5452 | Val Avg. Loss: 0.7852
# Epoch [22/25] | Train Bal. Acc: 0.6521 | Val Bal. Acc: 0.5515
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5508 | Val Avg. Loss: 0.7756
# Epoch [23/25] | Train Bal. Acc: 0.6677 | Val Bal. Acc: 0.5809
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5433 | Val Avg. Loss: 0.7807
# Epoch [24/25] | Train Bal. Acc: 0.6833 | Val Bal. Acc: 0.5809
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5423 | Val Avg. Loss: 0.8040
# Epoch [25/25] | Train Bal. Acc: 0.6833 | Val Bal. Acc: 0.5809
# --------------------
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6630 | Val Avg. Loss: 0.7331
# Epoch [1/25] | Train Bal. Acc: 0.4895 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6090 | Val Avg. Loss: 0.8704
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5831 | Val Avg. Loss: 0.9951
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5719 | Val Avg. Loss: 0.9563
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5683 | Val Avg. Loss: 0.8772
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5596 | Val Avg. Loss: 0.8835
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5481 | Val Avg. Loss: 0.8888
# Epoch [7/25] | Train Bal. Acc: 0.5333 | Val Bal. Acc: 0.5312
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5311 | Val Avg. Loss: 0.9021
# Epoch [8/25] | Train Bal. Acc: 0.5325 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5352 | Val Avg. Loss: 0.9858
# Epoch [9/25] | Train Bal. Acc: 0.5316 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5248 | Val Avg. Loss: 0.9257
# Epoch [10/25] | Train Bal. Acc: 0.5807 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5347 | Val Avg. Loss: 0.8138
# Epoch [11/25] | Train Bal. Acc: 0.6211 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5190 | Val Avg. Loss: 0.8764
# Epoch [12/25] | Train Bal. Acc: 0.6535 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5218 | Val Avg. Loss: 0.9329
# Epoch [13/25] | Train Bal. Acc: 0.6211 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5208 | Val Avg. Loss: 0.9261
# Epoch [14/25] | Train Bal. Acc: 0.5877 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5142 | Val Avg. Loss: 0.8586
# Epoch [15/25] | Train Bal. Acc: 0.6623 | Val Bal. Acc: 0.6178
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5204 | Val Avg. Loss: 0.8255
# Epoch [16/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5204 | Val Avg. Loss: 0.8718
# Epoch [17/25] | Train Bal. Acc: 0.7035 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5116 | Val Avg. Loss: 0.9477
# Epoch [18/25] | Train Bal. Acc: 0.6368 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5128 | Val Avg. Loss: 0.9444
# Epoch [19/25] | Train Bal. Acc: 0.6368 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5036 | Val Avg. Loss: 0.9207
# Epoch [20/25] | Train Bal. Acc: 0.6368 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5085 | Val Avg. Loss: 0.9179
# Epoch [21/25] | Train Bal. Acc: 0.6956 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5048 | Val Avg. Loss: 0.8897
# Epoch [22/25] | Train Bal. Acc: 0.6702 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5007 | Val Avg. Loss: 0.9183
# Epoch [23/25] | Train Bal. Acc: 0.6702 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5124 | Val Avg. Loss: 0.9224
# Epoch [24/25] | Train Bal. Acc: 0.6702 | Val Bal. Acc: 0.6562
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4998 | Val Avg. Loss: 0.9263
# Epoch [25/25] | Train Bal. Acc: 0.6868 | Val Bal. Acc: 0.6562
# --------------------
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7258 | Val Avg. Loss: 0.7161
# Epoch [1/25] | Train Bal. Acc: 0.3889 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6981 | Val Avg. Loss: 0.6752
# Epoch [2/25] | Train Bal. Acc: 0.5333 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6941 | Val Avg. Loss: 0.6715
# Epoch [3/25] | Train Bal. Acc: 0.4778 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6945 | Val Avg. Loss: 0.6924
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6952 | Val Avg. Loss: 0.7211
# Epoch [5/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6916 | Val Avg. Loss: 0.7176
# Epoch [6/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6890 | Val Avg. Loss: 0.7071
# Epoch [7/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6890 | Val Avg. Loss: 0.7219
# Epoch [8/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6894 | Val Avg. Loss: 0.7292
# Epoch [9/25] | Train Bal. Acc: 0.5333 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6902 | Val Avg. Loss: 0.7356
# Epoch [10/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6896 | Val Avg. Loss: 0.7188
# Epoch [11/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6869 | Val Avg. Loss: 0.7192
# Epoch [12/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6884 | Val Avg. Loss: 0.7083
# Epoch [13/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6856 | Val Avg. Loss: 0.7082
# Epoch [14/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6857 | Val Avg. Loss: 0.7176
# Epoch [15/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6850 | Val Avg. Loss: 0.7125
# Epoch [16/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6829 | Val Avg. Loss: 0.7140
# Epoch [17/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6855 | Val Avg. Loss: 0.7180
# Epoch [18/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6835 | Val Avg. Loss: 0.7302
# Epoch [19/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6859 | Val Avg. Loss: 0.7238
# Epoch [20/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6777 | Val Avg. Loss: 0.7197
# Epoch [21/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6827 | Val Avg. Loss: 0.7234
# Epoch [22/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6804 | Val Avg. Loss: 0.7203
# Epoch [23/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6789 | Val Avg. Loss: 0.7218
# Epoch [24/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6801 | Val Avg. Loss: 0.7080
# Epoch [25/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.3958
# --------------------
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6906 | Val Avg. Loss: 0.5830
# Epoch [1/25] | Train Bal. Acc: 0.5643 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6840 | Val Avg. Loss: 0.6049
# Epoch [2/25] | Train Bal. Acc: 0.5848 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6914 | Val Avg. Loss: 0.6726
# Epoch [3/25] | Train Bal. Acc: 0.5155 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6894 | Val Avg. Loss: 0.6497
# Epoch [4/25] | Train Bal. Acc: 0.5140 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6835 | Val Avg. Loss: 0.5820
# Epoch [5/25] | Train Bal. Acc: 0.6266 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6756 | Val Avg. Loss: 0.5617
# Epoch [6/25] | Train Bal. Acc: 0.6601 | Val Bal. Acc: 0.8125
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6785 | Val Avg. Loss: 0.5546
# Epoch [7/25] | Train Bal. Acc: 0.6169 | Val Bal. Acc: 0.8125
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6747 | Val Avg. Loss: 0.6091
# Epoch [8/25] | Train Bal. Acc: 0.5720 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6821 | Val Avg. Loss: 0.6676
# Epoch [9/25] | Train Bal. Acc: 0.5696 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6717 | Val Avg. Loss: 0.5504
# Epoch [10/25] | Train Bal. Acc: 0.5700 | Val Bal. Acc: 0.7917
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6758 | Val Avg. Loss: 0.5325
# Epoch [11/25] | Train Bal. Acc: 0.5833 | Val Bal. Acc: 0.7917
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6623 | Val Avg. Loss: 0.5995
# Epoch [12/25] | Train Bal. Acc: 0.5932 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6659 | Val Avg. Loss: 0.5524
# Epoch [13/25] | Train Bal. Acc: 0.6152 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6672 | Val Avg. Loss: 0.5511
# Epoch [14/25] | Train Bal. Acc: 0.6051 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6726 | Val Avg. Loss: 0.5934
# Epoch [15/25] | Train Bal. Acc: 0.5930 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6513 | Val Avg. Loss: 0.5348
# Epoch [16/25] | Train Bal. Acc: 0.6155 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6471 | Val Avg. Loss: 0.5427
# Epoch [17/25] | Train Bal. Acc: 0.6268 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6574 | Val Avg. Loss: 0.6270
# Epoch [18/25] | Train Bal. Acc: 0.6263 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6515 | Val Avg. Loss: 0.5991
# Epoch [19/25] | Train Bal. Acc: 0.6140 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6606 | Val Avg. Loss: 0.4913
# Epoch [20/25] | Train Bal. Acc: 0.5829 | Val Bal. Acc: 0.7917
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6868 | Val Avg. Loss: 0.6189
# Epoch [21/25] | Train Bal. Acc: 0.5935 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6534 | Val Avg. Loss: 0.5905
# Epoch [22/25] | Train Bal. Acc: 0.6152 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6440 | Val Avg. Loss: 0.5859
# Epoch [23/25] | Train Bal. Acc: 0.6268 | Val Bal. Acc: 0.7917
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6483 | Val Avg. Loss: 0.5678
# Epoch [24/25] | Train Bal. Acc: 0.6490 | Val Bal. Acc: 0.7917
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6631 | Val Avg. Loss: 0.6146
# Epoch [25/25] | Train Bal. Acc: 0.6053 | Val Bal. Acc: 0.7500
# --------------------
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6108 | Val Avg. Loss: 0.7901
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6055 | Val Avg. Loss: 0.8203
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5914 | Val Avg. Loss: 0.7712
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5862 | Val Avg. Loss: 0.7633
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5788 | Val Avg. Loss: 0.7916
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5920 | Val Avg. Loss: 0.8036
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5880 | Val Avg. Loss: 0.7596
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5764 | Val Avg. Loss: 0.7649
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5730 | Val Avg. Loss: 0.7685
# Epoch [9/25] | Train Bal. Acc: 0.5090 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5882 | Val Avg. Loss: 0.7541
# Epoch [10/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5879 | Val Avg. Loss: 0.7861
# Epoch [11/25] | Train Bal. Acc: 0.5353 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5804 | Val Avg. Loss: 0.7628
# Epoch [12/25] | Train Bal. Acc: 0.5189 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5857 | Val Avg. Loss: 0.7737
# Epoch [13/25] | Train Bal. Acc: 0.5616 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5771 | Val Avg. Loss: 0.7739
# Epoch [14/25] | Train Bal. Acc: 0.5353 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5743 | Val Avg. Loss: 0.7534
# Epoch [15/25] | Train Bal. Acc: 0.5362 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5759 | Val Avg. Loss: 0.7645
# Epoch [16/25] | Train Bal. Acc: 0.5280 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5675 | Val Avg. Loss: 0.7833
# Epoch [17/25] | Train Bal. Acc: 0.5534 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5630 | Val Avg. Loss: 0.7762
# Epoch [18/25] | Train Bal. Acc: 0.5707 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5727 | Val Avg. Loss: 0.7800
# Epoch [19/25] | Train Bal. Acc: 0.5625 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5621 | Val Avg. Loss: 0.7735
# Epoch [20/25] | Train Bal. Acc: 0.5969 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5637 | Val Avg. Loss: 0.7668
# Epoch [21/25] | Train Bal. Acc: 0.5797 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5571 | Val Avg. Loss: 0.7634
# Epoch [22/25] | Train Bal. Acc: 0.6150 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5601 | Val Avg. Loss: 0.7731
# Epoch [23/25] | Train Bal. Acc: 0.5806 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5569 | Val Avg. Loss: 0.7659
# Epoch [24/25] | Train Bal. Acc: 0.6323 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5553 | Val Avg. Loss: 0.7681
# Epoch [25/25] | Train Bal. Acc: 0.6232 | Val Bal. Acc: 0.6140
# --------------------
# Accuracy (Balanced): 0.6189814814814815
# Avg. Loss: 0.7047907043905819
#               precision    recall  f1-score   support
#
#            0       0.58      0.46      0.52        54
#            1       0.68      0.78      0.73        80
#
#     accuracy                           0.65       134
#    macro avg       0.63      0.62      0.62       134
# weighted avg       0.64      0.65      0.64       134

# %%
#_ = attention_based_mil(df, ["AU02_r", "AU12_r"])

# %% [markdown]
# # ATTENTION VISUALIZATIONS

# %%
df_attention = pd.DataFrame(attention_results)
df_attention
# Out:
#         clip_id  true_label  pred_prob  pred_label  \
# 0       Art6_S2           1   0.685323           1
# 1      Art6_S32           1   0.553007           1
# 2      Art6_S36           1   0.610539           1
# 3      Art6_S43           0   0.534383           1
# 4       Art6_S6           0   0.483701           0
# ..          ...         ...        ...         ...
# 129  Tech21_S32           0   0.572406           1
# 130  Tech21_S33           0   0.552848           1
# 131   Tech21_S4           0   0.485553           0
# 132   Tech21_S5           0   0.483552           0
# 133   Tech21_S6           0   0.561274           1
#
#                                              attention  \
# 0    [0.0091224, 0.0091224, 0.0091224, 0.009333276,...
# 1    [0.02369934, 0.023297086, 0.023297086, 0.03281...
# 2    [0.1003709, 0.101975456, 0.07749946, 0.0125489...
# 3    [0.018408924, 0.016281629, 0.016281629, 0.0162...
# 4    [0.1710097, 0.07096937, 0.085550815, 0.0906877...
# ..                                                 ...
# 129    [0.2771257, 0.33533147, 0.24178106, 0.14576176]
# 130  [0.049933415, 0.05611375, 0.06448805, 0.111119...
# 131  [0.16243833, 0.17819971, 0.21041784, 0.2107046...
# 132  [0.22032933, 0.18174994, 0.17869315, 0.2086548...
# 133  [0.033458456, 0.033100903, 0.035501722, 0.0359...
#
#                                               evidence  \
# 0    [tensor(-0.1876), tensor(-0.1876), tensor(-0.1...
# 1    [tensor(-0.1824), tensor(-0.1876), tensor(-0.1...
# 2    [tensor(1.2847), tensor(1.3267), tensor(0.8578...
# 3    [tensor(-0.1483), tensor(-0.1876), tensor(-0.1...
# 4    [tensor(0.1048), tensor(-0.1876), tensor(-0.12...
# ..                                                 ...
# 129  [tensor(0.2390), tensor(0.3768), tensor(0.1218...
# 130  [tensor(-0.1732), tensor(-0.1067), tensor(-0.0...
# 131  [tensor(-0.2263), tensor(-0.1883), tensor(-0.1...
# 132  [tensor(-0.1237), tensor(-0.1857), tensor(-0.1...
# 133  [tensor(-0.2529), tensor(-0.2585), tensor(-0.2...
#
#                                           contribution  \
# 0    [tensor(-0.0017), tensor(-0.0017), tensor(-0.0...
# 1    [tensor(-0.0043), tensor(-0.0044), tensor(-0.0...
# 2    [tensor(0.1289), tensor(0.1353), tensor(0.0665...
# 3    [tensor(-0.0027), tensor(-0.0031), tensor(-0.0...
# 4    [tensor(0.0179), tensor(-0.0133), tensor(-0.01...
# ..                                                 ...
# 129  [tensor(0.0662), tensor(0.1264), tensor(0.0295...
# 130  [tensor(-0.0086), tensor(-0.0060), tensor(-0.0...
# 131  [tensor(-0.0368), tensor(-0.0336), tensor(-0.0...
# 132  [tensor(-0.0273), tensor(-0.0338), tensor(-0.0...
# 133  [tensor(-0.0085), tensor(-0.0086), tensor(-0.0...
#
#                                                      X
# 0    [[-0.054545455, -0.44486693], [-0.054545455, -...
# 1    [[-0.027272727, -0.44486693], [-0.054545455, -...
# 2    [[10.690909, -0.44486693], [11.036364, -0.4448...
# 3    [[0.12727273, -0.44486693], [-0.054545455, -0....
# 4    [[1.2, -0.44486693], [-0.054545455, -0.4448669...
# ..                                                 ...
# 129  [[1.0, 1.1762621], [1.2372881, 1.5695306], [0....
# 130  [[0.050847456, 0.14348981], [0.016949153, 0.37...
# 131  [[-0.050847456, -0.111603186], [-0.050847456, ...
# 132  [[0.27118644, 0.29406554], [-0.050847456, 0.06...
# 133  [[-0.050847456, -0.22497785], [-0.050847456, -...
#
# [134 rows x 8 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_attention_heatmap_with_two_au(example):
    attention = np.asarray(
        example["attention"].iloc[0],
        dtype=float
    )

    X = np.asarray(
        example["X"].iloc[0],
        dtype=float
    )

    au02 = X[:, 0]
    au05 = X[:, 1]
    # au12 = X[:, 2]

    # Darstellung beginnt bei Window 1
    windows = np.arange(1, len(attention) + 1)

    if len(attention) != len(au02) or len(attention) != len(au05):
        raise ValueError(
            f"Attention has {len(attention)} windows, "
            f"AU02 has {len(au02)} values and "
            f"AU05 has {len(au05)} values."
        )

    clip_id = example["clip_id"].iloc[0]

    fig, axes = plt.subplots(
        2,
        1,
        figsize=(12, 4),
        sharex=True,
        gridspec_kw={
            "height_ratios": [0.35, 3],
            "hspace": 0.08
        }
    )

    # Attention-Heatmap
    heatmap = axes[0].imshow(
        attention.reshape(1, -1),
        aspect="auto",
        cmap="Blues",
        interpolation="nearest",
        extent=[
            0.5,
            len(attention) + 0.5,
            0,
            1
        ]
    )

    axes[0].set_yticks([])
    axes[0].set_ylabel("Attention")
    axes[0].set_title(
        f"Attention and Action Unit Activity – Clip {clip_id}"
    )

    axes[1].plot(
        windows,
        au02,
        marker="o",
        markersize=3,
        linewidth=1.5,
        color="dimgray",
        label="AU02_r"
    )

    axes[1].plot(
        windows,
        au05,
        marker="o",
        markersize=3,
        linewidth=1.5,
        color="darkgray",
        label="AU12_r"
    )
    
    # axes[1].plot(
    #     windows,
    #     au12,
    #     marker="o",
    #     markersize=3,
    #     linewidth=1.5,
    #     color="blue",
    #     label="AU12_r"
    # )

    axes[1].set_xlabel("Window")
    axes[1].set_ylabel("Normalized AU Value")
    axes[1].grid(alpha=0.3)
    axes[1].legend()

    fig.colorbar(
        heatmap,
        ax=axes,
        label="Attention Weight",
        fraction=0.025,
        pad=0.02
    )

    plt.show()

# %%
def plot_attention_heatmap_with_all_aus(example, au_names):
    attention = np.asarray(
        example["attention"].iloc[0],
        dtype=float
    )

    X = np.asarray(
        example["X"].iloc[0],
        dtype=float
    )

    clip_id = example["clip_id"].iloc[0]
    windows = np.arange(len(attention))

    if X.shape[0] != len(attention):
        raise ValueError(
            f"Attention has {len(attention)} windows, "
            f"but X has {X.shape[0]} windows."
        )

    if X.shape[1] != len(au_names):
        raise ValueError(
            f"X contains {X.shape[1]} features, "
            f"but {len(au_names)} AU names were provided."
        )

    fig, axes = plt.subplots(
        2,
        1,
        figsize=(14, 7),
        sharex=True,
        gridspec_kw={
            "height_ratios": [1, 4]
        }
    )

    # Attention-Heatmap
    heatmap = axes[0].imshow(
        attention.reshape(1, -1),
        aspect="auto",
        cmap="Reds",
        interpolation="nearest",
        extent=[
            -0.5,
            len(attention) - 0.5,
            0,
            1
        ]
    )

    axes[0].set_yticks([])
    axes[0].set_ylabel("Attention")
    axes[0].set_title(
        f"Attention and Action Unit activity – Clip {clip_id}"
    )

    # Alle AUs plotten
    for feature_index, au_name in enumerate(au_names):
        axes[1].plot(
            windows,
            X[:, feature_index],
            label=au_name,
            linewidth=1.5
        )

    axes[1].set_xlabel("Window Index")
    axes[1].set_ylabel("Normalized AU value")
    axes[1].grid(alpha=0.3)

    axes[1].legend(
        loc="upper center",
        bbox_to_anchor=(0.5, -0.18),
        ncol=4
    )

    fig.colorbar(
        heatmap,
        ax=axes,
        label="Attention Weight",
        fraction=0.025,
        pad=0.02
    )

    plt.subplots_adjust(bottom=0.23)
    plt.show()

# %%
def top_windows(example, fps=30):
    attention_weights = np.asarray(
        example["attention"].iloc[0],
        dtype=float
    )

    evidence = np.asarray(
        example["evidence"].iloc[0],
        dtype=float
    )

    contribution = np.asarray(
        example["contribution"].iloc[0],
        dtype=float
    )

    # Fünf höchste Attention-Werte
    top_indices = np.argsort(attention_weights)[-5:][::-1]

    window_size = 10
    stride = 5

    window_duration = window_size / fps
    stride_duration = stride / fps

    start_times = top_indices * stride_duration
    end_times = start_times + window_duration

    top_attention_windows = pd.DataFrame({
        "window": top_indices + 1,
        "start_time_seconds": start_times,
        "end_time_seconds": end_times,
        "attention_weight": attention_weights[top_indices],
        "evidence": evidence[top_indices],
        "contribution": contribution[top_indices]
    })

    return top_attention_windows

# %% [markdown]
# # EXAMPLES - TRUE POSITIVE

# %%
true_positives = [
    r for r in attention_results
    if r["true_label"] == 1 and r["pred_label"] == 1
]

true_positives_sorted = sorted(
    true_positives,
    key=lambda r: r["pred_prob"],
    reverse=True
)

for r in true_positives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Pol2_S42:  0.9402433037757874
# Pol2_S54:  0.9317455887794495
# Pol2_S4:  0.9007959365844727
# Pol2_S52:  0.8363577723503113
# Bus14_S5:  0.8331239819526672
# Med15_S98:  0.8209065198898315
# Bus14_S2:  0.8147451877593994
# Bus14_S18:  0.8038085103034973
# Med15_S82:  0.7747470736503601
# Bus14_S17:  0.7653082609176636
# Phi3_S25:  0.7532065510749817
# Med15_S69:  0.7384850382804871
# Bus14_S110:  0.7219827771186829
# Med15_S68:  0.7114484906196594
# Bus14_S48:  0.6997457146644592
# Bus14_S113:  0.696158230304718
# Pol2_S20:  0.694151759147644
# Bus14_S105:  0.6896995902061462
# Art6_S2:  0.6853233575820923
# Pol2_S125:  0.6625964045524597
# Edu2_S78:  0.659966230392456
# Pol2_S81:  0.6496433615684509
# Tech21_S105:  0.6453191637992859
# Art6_S88:  0.6341107487678528
# Bus14_S109:  0.6307516694068909
# Phi3_S5:  0.627253532409668
# Tech10_S84:  0.6163148880004883
# Tech10_S53:  0.611014723777771
# Art6_S36:  0.6105385422706604
# Edu2_S37:  0.6050737500190735
# Ent5_S3:  0.5956628322601318
# Ent5_S61:  0.5943468809127808
# Phi3_S177:  0.5789573788642883
# Tech10_S80:  0.5779537558555603
# Bus14_S98:  0.5750325322151184
# Edu2_S63:  0.5621410012245178
# Pol9_S8:  0.5601585507392883
# Art6_S32:  0.5530073046684265
# Pol9_S52:  0.5421232581138611
# Tech10_S85:  0.5411521196365356
# Pol9_S104:  0.538591206073761
# Pol2_S43:  0.5356404781341553
# Tech10_S118:  0.5320122241973877
# Ent5_S35:  0.5307794809341431
# Tech10_S65:  0.5295900702476501
# Pol9_S84:  0.5256289839744568
# Med15_S34:  0.5227983593940735
# Ent5_S153:  0.5223589539527893
# Edu2_S72:  0.5216137766838074
# Pol9_S69:  0.5214253664016724
# Pol9_S65:  0.5207427740097046
# Edu2_S68:  0.5205903649330139
# Pol9_S4:  0.5181550979614258
# Tech10_S54:  0.5138824582099915
# Ent5_S149:  0.5136404633522034
# Edu2_S32:  0.5132758617401123
# Tech10_S59:  0.5101858973503113
# Pol9_S53:  0.5099596977233887
# Pol9_S71:  0.5082802772521973
# Bus14_S111:  0.5060757398605347
# Ent5_S152:  0.50556480884552
# Edu2_S62:  0.5031816959381104

# %%
true_positive_ex1 = df_attention[df_attention["clip_id"] == "Med15_S98"]
true_positive_ex1
# Out:
#       clip_id  true_label  pred_prob  pred_label  \
# 63  Med15_S98           1   0.820907           1
#
#                                             attention  \
# 63  [0.009065061, 0.006776354, 0.0029656668, 0.002...
#
#                                              evidence  \
# 63  [tensor(0.5674), tensor(0.3775), tensor(-0.212...
#
#                                          contribution  \
# 63  [tensor(0.0051), tensor(0.0026), tensor(-0.000...
#
#                                                     X
# 63  [[3.2142856, -0.39857015], [2.5892856, -0.3985...

# %%
top_attention_windows = top_windows(true_positive_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/true_positive_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight  evidence  \
# 0     103           17.000000         17.333333          0.058471  3.117844
# 1     101           16.666667         17.000000          0.057527  3.128548
# 2      85           14.000000         14.333333          0.054260  2.890128
# 3     102           16.833333         17.166667          0.054185  2.753706
# 4     105           17.333333         17.666667          0.053619  2.617962
#
#    contribution
# 0      0.182305
# 1      0.179977
# 2      0.156818
# 3      0.149209
# 4      0.140373

# %%
plot_attention_heatmap_with_two_au(true_positive_ex1)

# %% [markdown]
# # EXAMPLE FALSE POSITIVE

# %%
false_positives = [
    r for r in attention_results
    if r["true_label"] == 0 and r["pred_label"] == 1
]

false_positives_sorted = sorted(
    false_positives,
    key=lambda r: r["pred_prob"],
    reverse=True
)

for r in false_positives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Pol2_S91:  0.9546335935592651
# Pol2_S35:  0.9253923892974854
# Pol2_S126:  0.9171056747436523
# Pol2_S90:  0.8968891501426697
# Med15_S51:  0.8930460810661316
# Pol2_S10:  0.8789887428283691
# Med15_S57:  0.833812952041626
# Bus14_S65:  0.7659361958503723
# Med15_S72:  0.736652672290802
# Med15_S73:  0.735696017742157
# Med15_S46:  0.7015506625175476
# Med15_S71:  0.6682209372520447
# Art6_S90:  0.640986979007721
# Phi3_S108:  0.5832448601722717
# Phi3_S42:  0.578701913356781
# Phi3_S85:  0.5737768411636353
# Tech21_S32:  0.5724061727523804
# Phi3_S97:  0.5672022104263306
# Tech21_S6:  0.5612743496894836
# Pol9_S42:  0.5538504719734192
# Tech21_S33:  0.5528479218482971
# Tech21_S30:  0.5437666773796082
# Med15_S81:  0.5429917573928833
# Med15_S26:  0.5354413986206055
# Art6_S43:  0.5343834161758423
# Pol9_S15:  0.5219281911849976
# Tech10_S58:  0.5160361528396606
# Pol2_S93:  0.5129154920578003
# Ent5_S19:  0.5027689933776855

# %%
false_positive_ex1 = df_attention[df_attention["clip_id"] == "Pol2_S91"]
false_positive_ex1
# Out:
#      clip_id  true_label  pred_prob  pred_label  \
# 90  Pol2_S91           0   0.954634           1
#
#                                             attention  \
# 90  [0.010107943, 0.0072885384, 0.0064611617, 0.00...
#
#                                              evidence  \
# 90  [tensor(-0.1663), tensor(0.0574), tensor(0.060...
#
#                                          contribution  \
# 90  [tensor(-0.0017), tensor(0.0004), tensor(0.000...
#
#                                                     X
# 90  [[0.3482143, 0.03815937], [0.3482143, 0.704826...

# %%
top_attention_windows = top_windows(false_positive_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/false_positive_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight  evidence  \
# 0      21            3.333333          3.666667          0.176340  3.780717
# 1      25            4.000000          4.333333          0.174878  5.015347
# 2      24            3.833333          4.166667          0.164283  4.316553
# 3      22            3.500000          3.833333          0.121775  2.866785
# 4      23            3.666667          4.000000          0.091221  2.629294
#
#    contribution
# 0      0.666691
# 1      0.877075
# 2      0.709136
# 3      0.349102
# 4      0.239848

# %%
plot_attention_heatmap_with_two_au(false_positive_ex1)

# %% [markdown]
# # EXAMPLE TRUE NEGATIVE

# %%
true_negatives = [
    r for r in attention_results
    if r["true_label"] == 0 and r["pred_label"] == 0
]

true_negatives_sorted = sorted(
    true_negatives,
    key=lambda r: r["pred_prob"],
    reverse=False
)

for r in true_negatives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Bus14_S28:  0.4103753864765167
# Pol2_S49:  0.4264466464519501
# Tech10_S2:  0.4282737970352173
# Phi3_S171:  0.4314495623111725
# Med15_S24:  0.43989285826683044
# Bus14_S88:  0.44997063279151917
# Med15_S70:  0.44998806715011597
# Tech10_S62:  0.45370548963546753
# Tech10_S57:  0.455874502658844
# Tech21_S29:  0.4620077311992645
# Ent5_S88:  0.46216464042663574
# Edu2_S54:  0.4651169776916504
# Med15_S99:  0.4753086268901825
# Pol9_S17:  0.47934606671333313
# Tech21_S3:  0.482102632522583
# Med15_S23:  0.4829789400100708
# Ent5_S33:  0.4831276834011078
# Tech21_S5:  0.4835520088672638
# Art6_S6:  0.48370057344436646
# Tech21_S4:  0.48555323481559753
# Ent5_S24:  0.4946894943714142
# Pol9_S55:  0.49545955657958984
# Art6_S89:  0.4985809326171875
# Pol9_S97:  0.49914851784706116
# Pol2_S9:  0.49999648332595825

# %%
true_negative_ex1 = df_attention[df_attention["clip_id"] == "Tech10_S2"]
true_negative_ex1
# Out:
#        clip_id  true_label  pred_prob  pred_label  \
# 111  Tech10_S2           0   0.428274           0
#
#                                              attention  \
# 111  [0.12516111, 0.12157236, 0.13309664, 0.1335283...
#
#                                               evidence  \
# 111  [tensor(-0.3042), tensor(-0.3037), tensor(-0.2...
#
#                                           contribution  \
# 111  [tensor(-0.0381), tensor(-0.0369), tensor(-0.0...
#
#                                                      X
# 111  [[0.027522936, -0.1381509], [0.27522936, -0.30...

# %%
top_attention_windows = top_windows(true_negative_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/true_negative_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight  evidence  \
# 0       4            0.500000          0.833333          0.133528 -0.224825
# 1       3            0.333333          0.666667          0.133097 -0.226870
# 2       1            0.000000          0.333333          0.125161 -0.304225
# 3       6            0.833333          1.166667          0.124815 -0.277481
# 4       5            0.666667          1.000000          0.124393 -0.280970
#
#    contribution
# 0     -0.030020
# 1     -0.030196
# 2     -0.038077
# 3     -0.034634
# 4     -0.034951

# %%
plot_attention_heatmap_with_two_au(true_negative_ex1)

# %% [markdown]
# # EXAMPLE FALSE NEGATIVE

# %%
false_negatives = [
    r for r in attention_results
    if r["true_label"] == 1 and r["pred_label"] == 0
]

false_negatives_sorted = sorted(
    false_negatives,
    key=lambda r: r["pred_prob"],
    reverse=False
)

for r in false_negatives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Bus14_S108:  0.39085301756858826
# Bus14_S106:  0.4094407558441162
# Pol9_S101:  0.41697466373443604
# Phi3_S129:  0.417310506105423
# Tech10_S99:  0.44507330656051636
# Edu2_S35:  0.4526037275791168
# Tech21_S16:  0.46652716398239136
# Pol2_S30:  0.4669121503829956
# Pol9_S78:  0.4673019349575043
# Tech10_S19:  0.46859994530677795
# Edu2_S34:  0.4724312722682953
# Tech21_S106:  0.4794146716594696
# Ent5_S36:  0.4835878610610962
# Pol2_S21:  0.4843284785747528
# Tech10_S113:  0.4886787235736847
# Ent5_S76:  0.492156982421875
# Edu2_S77:  0.49421054124832153
# Edu2_S51:  0.49493032693862915

# %%
false_negative_ex1 = df_attention[df_attention["clip_id"] == "Tech21_S16"]
false_negative_ex1
# Out:
#         clip_id  true_label  pred_prob  pred_label  \
# 125  Tech21_S16           1   0.466527           0
#
#                                              attention  \
# 125  [0.05669824, 0.08470862, 0.07990268, 0.0540249...
#
#                                               evidence  \
# 125  [tensor(-0.2547), tensor(-0.1185), tensor(-0.1...
#
#                                           contribution  \
# 125  [tensor(-0.0144), tensor(-0.0100), tensor(-0.0...
#
#                                                      X
# 125  [[0.34745762, -0.26217893], [1.1694915, -0.262...

# %%
top_attention_windows = top_windows(false_negative_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/false_negative_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight  evidence  \
# 0       2            0.166667          0.500000          0.084709 -0.118514
# 1       3            0.333333          0.666667          0.079903 -0.148495
# 2       7            1.000000          1.333333          0.063246 -0.237575
# 3       6            0.833333          1.166667          0.058480 -0.250762
# 4       1            0.000000          0.333333          0.056698 -0.254708
#
#    contribution
# 0     -0.010039
# 1     -0.011865
# 2     -0.015026
# 3     -0.014665
# 4     -0.014441

# %%
plot_attention_heatmap_with_two_au(false_negative_ex1)

# %% [markdown]
# # APPRAISAL STATISTICS

# %%
import pandas as pd

def appraisal_statistics(clip_ids, labels_path="../data/labels.csv"):
    # Labels laden
    labels = pd.read_csv(labels_path)

    # Nur Clips aus der übergebenen Liste auswählen
    selected = labels[labels["clip_id"].isin(clip_ids)].copy()

    # Prüfen, ob alle Clip-IDs gefunden wurden
    missing = set(clip_ids) - set(selected["clip_id"])

    if missing:
        print(f"Warning: {len(missing)} clip(s) not found:")
        print(sorted(missing))

    # Appraisal-Verteilung
    stats = (
        selected["appraisal"]
        .value_counts(dropna=False)
        .rename_axis("appraisal")
        .reset_index(name="count")
    )

    print(f"Total clips: {len(selected)}")
    
    return stats

# %%
true_pos = []
false_neg = []

for pos in true_positives_sorted:
    true_pos.append(pos["clip_id"])
    
for neg in false_negatives_sorted:
    false_neg.append(neg["clip_id"])

# %%
print(appraisal_statistics(true_pos))
# Out:
# Total clips: 62
#                 appraisal  count
# 0               Judgement     27
# 1            Appreciation     19
# 2                  Affect     11
# 3  Judgement/Appreciation      2
# 4        Affect/Judgement      2
# 5     Affect/Appreciation      1

# %%
print(appraisal_statistics(false_neg))
# Out:
# Total clips: 18
#       appraisal  count
# 0     Judgement     10
# 1  Appreciation      6
# 2        Affect      2
