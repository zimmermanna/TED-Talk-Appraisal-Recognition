# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/combined.csv")

# %% [markdown]
# # ALL AU's

# %%
from src.MILArchitecture.full_pipelines import attention_based_mil
from src.utils.data import au_cols

_ = attention_based_mil(df, au_cols)
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6651 | Val Avg. Loss: 0.5791
# Epoch [1/25] | Train Bal. Acc: 0.5157 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6476 | Val Avg. Loss: 0.5318
# Epoch [2/25] | Train Bal. Acc: 0.5714 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6407 | Val Avg. Loss: 0.5539
# Epoch [3/25] | Train Bal. Acc: 0.5595 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6311 | Val Avg. Loss: 0.5787
# Epoch [4/25] | Train Bal. Acc: 0.5338 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6404 | Val Avg. Loss: 0.6150
# Epoch [5/25] | Train Bal. Acc: 0.5670 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6286 | Val Avg. Loss: 0.5719
# Epoch [6/25] | Train Bal. Acc: 0.6003 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6229 | Val Avg. Loss: 0.5327
# Epoch [7/25] | Train Bal. Acc: 0.5758 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6192 | Val Avg. Loss: 0.5334
# Epoch [8/25] | Train Bal. Acc: 0.5370 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6129 | Val Avg. Loss: 0.5510
# Epoch [9/25] | Train Bal. Acc: 0.5639 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6084 | Val Avg. Loss: 0.5688
# Epoch [10/25] | Train Bal. Acc: 0.5758 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5974 | Val Avg. Loss: 0.5635
# Epoch [11/25] | Train Bal. Acc: 0.5639 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5975 | Val Avg. Loss: 0.5770
# Epoch [12/25] | Train Bal. Acc: 0.5670 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5875 | Val Avg. Loss: 0.6035
# Epoch [13/25] | Train Bal. Acc: 0.6385 | Val Bal. Acc: 0.5559
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5881 | Val Avg. Loss: 0.5393
# Epoch [14/25] | Train Bal. Acc: 0.6623 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5826 | Val Avg. Loss: 0.5361
# Epoch [15/25] | Train Bal. Acc: 0.6472 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5609 | Val Avg. Loss: 0.5641
# Epoch [16/25] | Train Bal. Acc: 0.6685 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5579 | Val Avg. Loss: 0.5195
# Epoch [17/25] | Train Bal. Acc: 0.6836 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5921 | Val Avg. Loss: 0.4758
# Epoch [18/25] | Train Bal. Acc: 0.6535 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5627 | Val Avg. Loss: 0.5287
# Epoch [19/25] | Train Bal. Acc: 0.6416 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5608 | Val Avg. Loss: 0.5990
# Epoch [20/25] | Train Bal. Acc: 0.7312 | Val Bal. Acc: 0.5921
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5604 | Val Avg. Loss: 0.5996
# Epoch [21/25] | Train Bal. Acc: 0.7168 | Val Bal. Acc: 0.5921
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5403 | Val Avg. Loss: 0.5283
# Epoch [22/25] | Train Bal. Acc: 0.7256 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5397 | Val Avg. Loss: 0.5123
# Epoch [23/25] | Train Bal. Acc: 0.7043 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5399 | Val Avg. Loss: 0.5597
# Epoch [24/25] | Train Bal. Acc: 0.7281 | Val Bal. Acc: 0.7072
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5363 | Val Avg. Loss: 0.5372
# Epoch [25/25] | Train Bal. Acc: 0.7193 | Val Bal. Acc: 0.6086
# --------------------
# Bal. Accuracy: 0.875
# Avg. Loss:  0.5200682282447815
# [[3 1]
#  [0 4]]
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7016 | Val Avg. Loss: 0.6337
# Epoch [1/25] | Train Bal. Acc: 0.5238 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6854 | Val Avg. Loss: 0.6305
# Epoch [2/25] | Train Bal. Acc: 0.5238 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6666 | Val Avg. Loss: 0.6172
# Epoch [3/25] | Train Bal. Acc: 0.5476 | Val Bal. Acc: 0.6111
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6576 | Val Avg. Loss: 0.5933
# Epoch [4/25] | Train Bal. Acc: 0.5611 | Val Bal. Acc: 0.6768
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6445 | Val Avg. Loss: 0.5838
# Epoch [5/25] | Train Bal. Acc: 0.6214 | Val Bal. Acc: 0.6641
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6292 | Val Avg. Loss: 0.6042
# Epoch [6/25] | Train Bal. Acc: 0.6698 | Val Bal. Acc: 0.7626
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6214 | Val Avg. Loss: 0.6279
# Epoch [7/25] | Train Bal. Acc: 0.6976 | Val Bal. Acc: 0.6944
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6050 | Val Avg. Loss: 0.6435
# Epoch [8/25] | Train Bal. Acc: 0.7254 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5919 | Val Avg. Loss: 0.6439
# Epoch [9/25] | Train Bal. Acc: 0.7230 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5848 | Val Avg. Loss: 0.6424
# Epoch [10/25] | Train Bal. Acc: 0.6992 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5737 | Val Avg. Loss: 0.7288
# Epoch [11/25] | Train Bal. Acc: 0.7468 | Val Bal. Acc: 0.6818
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5684 | Val Avg. Loss: 0.7000
# Epoch [12/25] | Train Bal. Acc: 0.6794 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5523 | Val Avg. Loss: 0.6984
# Epoch [13/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.7273
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5665 | Val Avg. Loss: 0.7718
# Epoch [14/25] | Train Bal. Acc: 0.7127 | Val Bal. Acc: 0.7045
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5344 | Val Avg. Loss: 0.7718
# Epoch [15/25] | Train Bal. Acc: 0.7373 | Val Bal. Acc: 0.7045
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5372 | Val Avg. Loss: 0.7760
# Epoch [16/25] | Train Bal. Acc: 0.7246 | Val Bal. Acc: 0.7045
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5258 | Val Avg. Loss: 0.7787
# Epoch [17/25] | Train Bal. Acc: 0.7460 | Val Bal. Acc: 0.6818
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5230 | Val Avg. Loss: 0.8245
# Epoch [18/25] | Train Bal. Acc: 0.7365 | Val Bal. Acc: 0.6818
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5253 | Val Avg. Loss: 0.8531
# Epoch [19/25] | Train Bal. Acc: 0.7484 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5409 | Val Avg. Loss: 0.8480
# Epoch [20/25] | Train Bal. Acc: 0.7135 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5142 | Val Avg. Loss: 0.8756
# Epoch [21/25] | Train Bal. Acc: 0.7587 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5178 | Val Avg. Loss: 0.9334
# Epoch [22/25] | Train Bal. Acc: 0.7127 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4918 | Val Avg. Loss: 0.8882
# Epoch [23/25] | Train Bal. Acc: 0.7698 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4952 | Val Avg. Loss: 0.9178
# Epoch [24/25] | Train Bal. Acc: 0.7468 | Val Bal. Acc: 0.6591
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5002 | Val Avg. Loss: 0.9599
# Epoch [25/25] | Train Bal. Acc: 0.7357 | Val Bal. Acc: 0.6364
# --------------------
# Bal. Accuracy: 0.7564102564102564
# Avg. Loss:  0.5175466537475586
# [[ 2  1]
#  [ 2 11]]
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6943 | Val Avg. Loss: 0.6686
# Epoch [1/25] | Train Bal. Acc: 0.5371 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6725 | Val Avg. Loss: 0.6208
# Epoch [2/25] | Train Bal. Acc: 0.6010 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6676 | Val Avg. Loss: 0.6101
# Epoch [3/25] | Train Bal. Acc: 0.5774 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6538 | Val Avg. Loss: 0.6416
# Epoch [4/25] | Train Bal. Acc: 0.6010 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6463 | Val Avg. Loss: 0.6749
# Epoch [5/25] | Train Bal. Acc: 0.6363 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.6668
# Epoch [6/25] | Train Bal. Acc: 0.6803 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6243 | Val Avg. Loss: 0.6592
# Epoch [7/25] | Train Bal. Acc: 0.6581 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6056 | Val Avg. Loss: 0.6700
# Epoch [8/25] | Train Bal. Acc: 0.7124 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5905 | Val Avg. Loss: 0.6992
# Epoch [9/25] | Train Bal. Acc: 0.7024 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5999 | Val Avg. Loss: 0.6955
# Epoch [10/25] | Train Bal. Acc: 0.6626 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5731 | Val Avg. Loss: 0.6584
# Epoch [11/25] | Train Bal. Acc: 0.7138 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5671 | Val Avg. Loss: 0.6641
# Epoch [12/25] | Train Bal. Acc: 0.6916 | Val Bal. Acc: 0.5952
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5759 | Val Avg. Loss: 0.6930
# Epoch [13/25] | Train Bal. Acc: 0.7024 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5482 | Val Avg. Loss: 0.6801
# Epoch [14/25] | Train Bal. Acc: 0.7341 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5512 | Val Avg. Loss: 0.6798
# Epoch [15/25] | Train Bal. Acc: 0.7341 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5208 | Val Avg. Loss: 0.6691
# Epoch [16/25] | Train Bal. Acc: 0.7450 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5581 | Val Avg. Loss: 0.6784
# Epoch [17/25] | Train Bal. Acc: 0.6911 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5234 | Val Avg. Loss: 0.7097
# Epoch [18/25] | Train Bal. Acc: 0.6925 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5035 | Val Avg. Loss: 0.7086
# Epoch [19/25] | Train Bal. Acc: 0.7681 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5547 | Val Avg. Loss: 0.6990
# Epoch [20/25] | Train Bal. Acc: 0.6916 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4971 | Val Avg. Loss: 0.7265
# Epoch [21/25] | Train Bal. Acc: 0.7885 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4844 | Val Avg. Loss: 0.7148
# Epoch [22/25] | Train Bal. Acc: 0.7785 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4727 | Val Avg. Loss: 0.7313
# Epoch [23/25] | Train Bal. Acc: 0.7772 | Val Bal. Acc: 0.4286
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4958 | Val Avg. Loss: 0.7702
# Epoch [24/25] | Train Bal. Acc: 0.7894 | Val Bal. Acc: 0.4286
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4603 | Val Avg. Loss: 0.7768
# Epoch [25/25] | Train Bal. Acc: 0.8220 | Val Bal. Acc: 0.5238
# --------------------
# Bal. Accuracy: 0.2727272727272727
# Avg. Loss:  0.6350937485694885
# [[0 1]
#  [5 6]]
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6795 | Val Avg. Loss: 0.6073
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6702 | Val Avg. Loss: 0.6172
# Epoch [2/25] | Train Bal. Acc: 0.5114 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6567 | Val Avg. Loss: 0.6323
# Epoch [3/25] | Train Bal. Acc: 0.5455 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6395 | Val Avg. Loss: 0.6457
# Epoch [4/25] | Train Bal. Acc: 0.5568 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6338 | Val Avg. Loss: 0.6566
# Epoch [5/25] | Train Bal. Acc: 0.6136 | Val Bal. Acc: 0.5379
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6300 | Val Avg. Loss: 0.6815
# Epoch [6/25] | Train Bal. Acc: 0.5905 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6136 | Val Avg. Loss: 0.6699
# Epoch [7/25] | Train Bal. Acc: 0.5805 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6000 | Val Avg. Loss: 0.6762
# Epoch [8/25] | Train Bal. Acc: 0.5818 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5932 | Val Avg. Loss: 0.6898
# Epoch [9/25] | Train Bal. Acc: 0.6359 | Val Bal. Acc: 0.5530
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5845 | Val Avg. Loss: 0.7001
# Epoch [10/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.5076
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5864 | Val Avg. Loss: 0.7036
# Epoch [11/25] | Train Bal. Acc: 0.7168 | Val Bal. Acc: 0.5076
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5615 | Val Avg. Loss: 0.7164
# Epoch [12/25] | Train Bal. Acc: 0.7195 | Val Bal. Acc: 0.5227
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5498 | Val Avg. Loss: 0.7251
# Epoch [13/25] | Train Bal. Acc: 0.7523 | Val Bal. Acc: 0.5227
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5532 | Val Avg. Loss: 0.7220
# Epoch [14/25] | Train Bal. Acc: 0.7182 | Val Bal. Acc: 0.4621
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5463 | Val Avg. Loss: 0.7615
# Epoch [15/25] | Train Bal. Acc: 0.7223 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5303 | Val Avg. Loss: 0.7459
# Epoch [16/25] | Train Bal. Acc: 0.7677 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5195 | Val Avg. Loss: 0.7310
# Epoch [17/25] | Train Bal. Acc: 0.7336 | Val Bal. Acc: 0.6061
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4928 | Val Avg. Loss: 0.7122
# Epoch [18/25] | Train Bal. Acc: 0.7877 | Val Bal. Acc: 0.6061
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4906 | Val Avg. Loss: 0.7658
# Epoch [19/25] | Train Bal. Acc: 0.7564 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4700 | Val Avg. Loss: 0.7736
# Epoch [20/25] | Train Bal. Acc: 0.8105 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4941 | Val Avg. Loss: 0.7975
# Epoch [21/25] | Train Bal. Acc: 0.7750 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4718 | Val Avg. Loss: 0.7870
# Epoch [22/25] | Train Bal. Acc: 0.8091 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4532 | Val Avg. Loss: 0.7744
# Epoch [23/25] | Train Bal. Acc: 0.8191 | Val Bal. Acc: 0.6894
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4203 | Val Avg. Loss: 0.7736
# Epoch [24/25] | Train Bal. Acc: 0.8532 | Val Bal. Acc: 0.6061
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4239 | Val Avg. Loss: 0.7483
# Epoch [25/25] | Train Bal. Acc: 0.8191 | Val Bal. Acc: 0.6515
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6883484721183777
# [[2 2]
#  [4 4]]
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6905 | Val Avg. Loss: 0.6203
# Epoch [1/25] | Train Bal. Acc: 0.4396 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6539 | Val Avg. Loss: 0.5735
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6392 | Val Avg. Loss: 0.5464
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6365 | Val Avg. Loss: 0.5252
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6124 | Val Avg. Loss: 0.5358
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6052 | Val Avg. Loss: 0.5291
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5956 | Val Avg. Loss: 0.5221
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5795 | Val Avg. Loss: 0.5052
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5767 | Val Avg. Loss: 0.5099
# Epoch [9/25] | Train Bal. Acc: 0.5294 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5619 | Val Avg. Loss: 0.4888
# Epoch [10/25] | Train Bal. Acc: 0.5441 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5505 | Val Avg. Loss: 0.4960
# Epoch [11/25] | Train Bal. Acc: 0.5762 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5349 | Val Avg. Loss: 0.5033
# Epoch [12/25] | Train Bal. Acc: 0.6523 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5330 | Val Avg. Loss: 0.4601
# Epoch [13/25] | Train Bal. Acc: 0.6581 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5191 | Val Avg. Loss: 0.4766
# Epoch [14/25] | Train Bal. Acc: 0.6759 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5117 | Val Avg. Loss: 0.4589
# Epoch [15/25] | Train Bal. Acc: 0.7169 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5014 | Val Avg. Loss: 0.4648
# Epoch [16/25] | Train Bal. Acc: 0.6933 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5282 | Val Avg. Loss: 0.5193
# Epoch [17/25] | Train Bal. Acc: 0.7400 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4874 | Val Avg. Loss: 0.4188
# Epoch [18/25] | Train Bal. Acc: 0.7579 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4839 | Val Avg. Loss: 0.4194
# Epoch [19/25] | Train Bal. Acc: 0.6875 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4945 | Val Avg. Loss: 0.4604
# Epoch [20/25] | Train Bal. Acc: 0.7342 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4898 | Val Avg. Loss: 0.4182
# Epoch [21/25] | Train Bal. Acc: 0.7726 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4678 | Val Avg. Loss: 0.4097
# Epoch [22/25] | Train Bal. Acc: 0.6933 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4511 | Val Avg. Loss: 0.4323
# Epoch [23/25] | Train Bal. Acc: 0.7700 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4641 | Val Avg. Loss: 0.4323
# Epoch [24/25] | Train Bal. Acc: 0.7547 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4597 | Val Avg. Loss: 0.3978
# Epoch [25/25] | Train Bal. Acc: 0.7637 | Val Bal. Acc: 0.7237
# --------------------
# Bal. Accuracy: 0.7083333333333334
# Avg. Loss:  1.5989365893251755
# [[5 7]
#  [0 5]]
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7062 | Val Avg. Loss: 0.6964
# Epoch [1/25] | Train Bal. Acc: 0.4677 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6190 | Val Avg. Loss: 0.7383
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6004 | Val Avg. Loss: 0.8487
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6018 | Val Avg. Loss: 0.8795
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5866 | Val Avg. Loss: 0.8095
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5730 | Val Avg. Loss: 0.7952
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5743 | Val Avg. Loss: 0.8047
# Epoch [7/25] | Train Bal. Acc: 0.5156 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5666 | Val Avg. Loss: 0.8167
# Epoch [8/25] | Train Bal. Acc: 0.5469 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5540 | Val Avg. Loss: 0.8431
# Epoch [9/25] | Train Bal. Acc: 0.5625 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5615 | Val Avg. Loss: 0.8778
# Epoch [10/25] | Train Bal. Acc: 0.5542 | Val Bal. Acc: 0.5294
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5419 | Val Avg. Loss: 0.9005
# Epoch [11/25] | Train Bal. Acc: 0.6010 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5241 | Val Avg. Loss: 0.9002
# Epoch [12/25] | Train Bal. Acc: 0.6167 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5253 | Val Avg. Loss: 0.9374
# Epoch [13/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5588
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.4973 | Val Avg. Loss: 0.9637
# Epoch [14/25] | Train Bal. Acc: 0.6312 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.4837 | Val Avg. Loss: 0.9707
# Epoch [15/25] | Train Bal. Acc: 0.6615 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.4640 | Val Avg. Loss: 1.1548
# Epoch [16/25] | Train Bal. Acc: 0.6458 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.4570 | Val Avg. Loss: 1.1507
# Epoch [17/25] | Train Bal. Acc: 0.6687 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4554 | Val Avg. Loss: 1.0275
# Epoch [18/25] | Train Bal. Acc: 0.7229 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4288 | Val Avg. Loss: 1.1984
# Epoch [19/25] | Train Bal. Acc: 0.7854 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4303 | Val Avg. Loss: 1.2512
# Epoch [20/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4184 | Val Avg. Loss: 1.2143
# Epoch [21/25] | Train Bal. Acc: 0.7635 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.3942 | Val Avg. Loss: 1.1843
# Epoch [22/25] | Train Bal. Acc: 0.7854 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4088 | Val Avg. Loss: 1.2117
# Epoch [23/25] | Train Bal. Acc: 0.7625 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4123 | Val Avg. Loss: 1.2671
# Epoch [24/25] | Train Bal. Acc: 0.7854 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.3904 | Val Avg. Loss: 1.3551
# Epoch [25/25] | Train Bal. Acc: 0.7865 | Val Bal. Acc: 0.6140
# --------------------
# Bal. Accuracy: 0.775
# Avg. Loss:  0.559795618057251
# [[4 1]
#  [1 3]]
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6014 | Val Avg. Loss: 0.9388
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.5550 | Val Avg. Loss: 1.1421
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5456 | Val Avg. Loss: 1.0629
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5324 | Val Avg. Loss: 0.9515
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5242 | Val Avg. Loss: 0.8939
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5054 | Val Avg. Loss: 0.9641
# Epoch [6/25] | Train Bal. Acc: 0.5500 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.4980 | Val Avg. Loss: 0.9871
# Epoch [7/25] | Train Bal. Acc: 0.5746 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.4943 | Val Avg. Loss: 0.9752
# Epoch [8/25] | Train Bal. Acc: 0.6158 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.4935 | Val Avg. Loss: 1.0541
# Epoch [9/25] | Train Bal. Acc: 0.6149 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.4763 | Val Avg. Loss: 1.0115
# Epoch [10/25] | Train Bal. Acc: 0.6316 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.4899 | Val Avg. Loss: 0.8856
# Epoch [11/25] | Train Bal. Acc: 0.6632 | Val Bal. Acc: 0.6803
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.4824 | Val Avg. Loss: 0.9880
# Epoch [12/25] | Train Bal. Acc: 0.6623 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.4660 | Val Avg. Loss: 1.0635
# Epoch [13/25] | Train Bal. Acc: 0.6719 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.4586 | Val Avg. Loss: 1.0726
# Epoch [14/25] | Train Bal. Acc: 0.6465 | Val Bal. Acc: 0.5865
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.4479 | Val Avg. Loss: 0.9973
# Epoch [15/25] | Train Bal. Acc: 0.6807 | Val Bal. Acc: 0.6803
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.4485 | Val Avg. Loss: 0.9737
# Epoch [16/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.4366 | Val Avg. Loss: 1.1008
# Epoch [17/25] | Train Bal. Acc: 0.7789 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4258 | Val Avg. Loss: 1.1927
# Epoch [18/25] | Train Bal. Acc: 0.7632 | Val Bal. Acc: 0.5865
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.3952 | Val Avg. Loss: 1.1428
# Epoch [19/25] | Train Bal. Acc: 0.7044 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4082 | Val Avg. Loss: 1.1109
# Epoch [20/25] | Train Bal. Acc: 0.7789 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4008 | Val Avg. Loss: 1.1667
# Epoch [21/25] | Train Bal. Acc: 0.7544 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.3989 | Val Avg. Loss: 1.1574
# Epoch [22/25] | Train Bal. Acc: 0.7719 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.3774 | Val Avg. Loss: 1.1656
# Epoch [23/25] | Train Bal. Acc: 0.7965 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.3624 | Val Avg. Loss: 1.1774
# Epoch [24/25] | Train Bal. Acc: 0.8298 | Val Bal. Acc: 0.5721
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.3712 | Val Avg. Loss: 1.2770
# Epoch [25/25] | Train Bal. Acc: 0.7956 | Val Bal. Acc: 0.6106
# --------------------
# Bal. Accuracy: 0.5625
# Avg. Loss:  0.9778114822175767
# [[ 1  7]
#  [ 0 10]]
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6895 | Val Avg. Loss: 0.6051
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6694 | Val Avg. Loss: 0.6547
# Epoch [2/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6602 | Val Avg. Loss: 0.6689
# Epoch [3/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6539 | Val Avg. Loss: 0.6963
# Epoch [4/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6527 | Val Avg. Loss: 0.7365
# Epoch [5/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.2500
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6457 | Val Avg. Loss: 0.7056
# Epoch [6/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.3125
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6351 | Val Avg. Loss: 0.6740
# Epoch [7/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6332 | Val Avg. Loss: 0.6887
# Epoch [8/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6200 | Val Avg. Loss: 0.6873
# Epoch [9/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6178 | Val Avg. Loss: 0.6742
# Epoch [10/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6042 | Val Avg. Loss: 0.6315
# Epoch [11/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6121 | Val Avg. Loss: 0.6348
# Epoch [12/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5808 | Val Avg. Loss: 0.6209
# Epoch [13/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5921 | Val Avg. Loss: 0.6182
# Epoch [14/25] | Train Bal. Acc: 0.7222 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5800 | Val Avg. Loss: 0.6391
# Epoch [15/25] | Train Bal. Acc: 0.7222 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5641 | Val Avg. Loss: 0.6483
# Epoch [16/25] | Train Bal. Acc: 0.7444 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5599 | Val Avg. Loss: 0.6436
# Epoch [17/25] | Train Bal. Acc: 0.7333 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5517 | Val Avg. Loss: 0.6535
# Epoch [18/25] | Train Bal. Acc: 0.7111 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5348 | Val Avg. Loss: 0.6627
# Epoch [19/25] | Train Bal. Acc: 0.7333 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5286 | Val Avg. Loss: 0.6605
# Epoch [20/25] | Train Bal. Acc: 0.7667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5130 | Val Avg. Loss: 0.6301
# Epoch [21/25] | Train Bal. Acc: 0.7778 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4946 | Val Avg. Loss: 0.6541
# Epoch [22/25] | Train Bal. Acc: 0.7667 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5113 | Val Avg. Loss: 0.7167
# Epoch [23/25] | Train Bal. Acc: 0.7333 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5022 | Val Avg. Loss: 0.6921
# Epoch [24/25] | Train Bal. Acc: 0.7778 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4781 | Val Avg. Loss: 0.7039
# Epoch [25/25] | Train Bal. Acc: 0.7889 | Val Bal. Acc: 0.6250
# --------------------
# Bal. Accuracy: 0.4818181818181818
# Avg. Loss:  0.7862100601196289
# [[3 2]
#  [7 4]]
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7022 | Val Avg. Loss: 0.6304
# Epoch [1/25] | Train Bal. Acc: 0.4737 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6886 | Val Avg. Loss: 0.6173
# Epoch [2/25] | Train Bal. Acc: 0.4886 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6811 | Val Avg. Loss: 0.6517
# Epoch [3/25] | Train Bal. Acc: 0.5973 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6767 | Val Avg. Loss: 0.6311
# Epoch [4/25] | Train Bal. Acc: 0.6399 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6589 | Val Avg. Loss: 0.5878
# Epoch [5/25] | Train Bal. Acc: 0.6401 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6603 | Val Avg. Loss: 0.5732
# Epoch [6/25] | Train Bal. Acc: 0.6181 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6330 | Val Avg. Loss: 0.5927
# Epoch [7/25] | Train Bal. Acc: 0.6611 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6316 | Val Avg. Loss: 0.6079
# Epoch [8/25] | Train Bal. Acc: 0.7254 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6383 | Val Avg. Loss: 0.6526
# Epoch [9/25] | Train Bal. Acc: 0.7022 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6108 | Val Avg. Loss: 0.5942
# Epoch [10/25] | Train Bal. Acc: 0.7357 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6132 | Val Avg. Loss: 0.5909
# Epoch [11/25] | Train Bal. Acc: 0.7036 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6206 | Val Avg. Loss: 0.6337
# Epoch [12/25] | Train Bal. Acc: 0.7138 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5924 | Val Avg. Loss: 0.6089
# Epoch [13/25] | Train Bal. Acc: 0.7251 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6096 | Val Avg. Loss: 0.6097
# Epoch [14/25] | Train Bal. Acc: 0.6807 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5830 | Val Avg. Loss: 0.6350
# Epoch [15/25] | Train Bal. Acc: 0.7348 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5746 | Val Avg. Loss: 0.5908
# Epoch [16/25] | Train Bal. Acc: 0.6918 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5851 | Val Avg. Loss: 0.5858
# Epoch [17/25] | Train Bal. Acc: 0.6930 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5773 | Val Avg. Loss: 0.6570
# Epoch [18/25] | Train Bal. Acc: 0.7135 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5676 | Val Avg. Loss: 0.6620
# Epoch [19/25] | Train Bal. Acc: 0.7343 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5559 | Val Avg. Loss: 0.5918
# Epoch [20/25] | Train Bal. Acc: 0.6923 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5521 | Val Avg. Loss: 0.6209
# Epoch [21/25] | Train Bal. Acc: 0.7471 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5518 | Val Avg. Loss: 0.5935
# Epoch [22/25] | Train Bal. Acc: 0.7365 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5344 | Val Avg. Loss: 0.6210
# Epoch [23/25] | Train Bal. Acc: 0.7469 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5098 | Val Avg. Loss: 0.6392
# Epoch [24/25] | Train Bal. Acc: 0.7913 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5211 | Val Avg. Loss: 0.6895
# Epoch [25/25] | Train Bal. Acc: 0.7355 | Val Bal. Acc: 0.5000
# --------------------
# Bal. Accuracy: 0.7840909090909092
# Avg. Loss:  0.5863511562347412
# [[3 1]
#  [2 9]]
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6918 | Val Avg. Loss: 0.6907
# Epoch [1/25] | Train Bal. Acc: 0.5356 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6123 | Val Avg. Loss: 0.7613
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5942 | Val Avg. Loss: 0.8294
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5808 | Val Avg. Loss: 0.8023
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5294
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5714 | Val Avg. Loss: 0.7764
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5641 | Val Avg. Loss: 0.7782
# Epoch [6/25] | Train Bal. Acc: 0.5172 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5526 | Val Avg. Loss: 0.7725
# Epoch [7/25] | Train Bal. Acc: 0.5345 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5434 | Val Avg. Loss: 0.8125
# Epoch [8/25] | Train Bal. Acc: 0.5345 | Val Bal. Acc: 0.6176
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5260 | Val Avg. Loss: 0.8527
# Epoch [9/25] | Train Bal. Acc: 0.5608 | Val Bal. Acc: 0.6471
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5281 | Val Avg. Loss: 0.8367
# Epoch [10/25] | Train Bal. Acc: 0.5780 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5066 | Val Avg. Loss: 0.9318
# Epoch [11/25] | Train Bal. Acc: 0.6207 | Val Bal. Acc: 0.6452
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.4867 | Val Avg. Loss: 0.9366
# Epoch [12/25] | Train Bal. Acc: 0.6379 | Val Bal. Acc: 0.5827
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.4805 | Val Avg. Loss: 1.0359
# Epoch [13/25] | Train Bal. Acc: 0.6215 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.4542 | Val Avg. Loss: 1.0286
# Epoch [14/25] | Train Bal. Acc: 0.6215 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.4492 | Val Avg. Loss: 1.0645
# Epoch [15/25] | Train Bal. Acc: 0.7077 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.4339 | Val Avg. Loss: 1.2320
# Epoch [16/25] | Train Bal. Acc: 0.6478 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.4284 | Val Avg. Loss: 1.1978
# Epoch [17/25] | Train Bal. Acc: 0.6733 | Val Bal. Acc: 0.6434
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4276 | Val Avg. Loss: 1.1091
# Epoch [18/25] | Train Bal. Acc: 0.7422 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.3998 | Val Avg. Loss: 1.1912
# Epoch [19/25] | Train Bal. Acc: 0.7513 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4106 | Val Avg. Loss: 1.1671
# Epoch [20/25] | Train Bal. Acc: 0.7176 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4049 | Val Avg. Loss: 1.1642
# Epoch [21/25] | Train Bal. Acc: 0.7267 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.3837 | Val Avg. Loss: 1.2240
# Epoch [22/25] | Train Bal. Acc: 0.8120 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.3851 | Val Avg. Loss: 1.2953
# Epoch [23/25] | Train Bal. Acc: 0.7858 | Val Bal. Acc: 0.6434
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.3668 | Val Avg. Loss: 1.1901
# Epoch [24/25] | Train Bal. Acc: 0.7858 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.3682 | Val Avg. Loss: 1.2459
# Epoch [25/25] | Train Bal. Acc: 0.7866 | Val Bal. Acc: 0.6121
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.8147584795951843
# [[0 8]
#  [0 3]]
# Accuracy (Balanced): 0.5817129629629629
# Avg. Loss: 0.7684920488229764
#               precision    recall  f1-score   support
#
#            0       0.52      0.43      0.47        54
#            1       0.66      0.74      0.69        80
#
#     accuracy                           0.61       134
#    macro avg       0.59      0.58      0.58       134
# weighted avg       0.60      0.61      0.60       134

# %% [markdown]
# # OUTER BROW RAISER & UPPER LID RAISER

# %%
attention_results = attention_based_mil(df, ["AU02_r", "AU05_r"])
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6758 | Val Avg. Loss: 0.5777
# Epoch [1/25] | Train Bal. Acc: 0.5269 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6687 | Val Avg. Loss: 0.5501
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6630 | Val Avg. Loss: 0.5590
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6611 | Val Avg. Loss: 0.6042
# Epoch [4/25] | Train Bal. Acc: 0.5038 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6650 | Val Avg. Loss: 0.6416
# Epoch [5/25] | Train Bal. Acc: 0.6034 | Val Bal. Acc: 0.6711
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6510 | Val Avg. Loss: 0.5636
# Epoch [6/25] | Train Bal. Acc: 0.6209 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6388 | Val Avg. Loss: 0.5331
# Epoch [7/25] | Train Bal. Acc: 0.5689 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6534 | Val Avg. Loss: 0.5447
# Epoch [8/25] | Train Bal. Acc: 0.5508 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6471 | Val Avg. Loss: 0.5618
# Epoch [9/25] | Train Bal. Acc: 0.5783 | Val Bal. Acc: 0.4737
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6353 | Val Avg. Loss: 0.5770
# Epoch [10/25] | Train Bal. Acc: 0.5965 | Val Bal. Acc: 0.5362
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6369 | Val Avg. Loss: 0.5618
# Epoch [11/25] | Train Bal. Acc: 0.5846 | Val Bal. Acc: 0.4737
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6354 | Val Avg. Loss: 0.5693
# Epoch [12/25] | Train Bal. Acc: 0.5877 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6343 | Val Avg. Loss: 0.6013
# Epoch [13/25] | Train Bal. Acc: 0.5739 | Val Bal. Acc: 0.7336
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6243 | Val Avg. Loss: 0.5577
# Epoch [14/25] | Train Bal. Acc: 0.5746 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6317 | Val Avg. Loss: 0.5372
# Epoch [15/25] | Train Bal. Acc: 0.5883 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6376 | Val Avg. Loss: 0.5384
# Epoch [16/25] | Train Bal. Acc: 0.6178 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6368 | Val Avg. Loss: 0.5497
# Epoch [17/25] | Train Bal. Acc: 0.6128 | Val Bal. Acc: 0.7336
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6364 | Val Avg. Loss: 0.5443
# Epoch [18/25] | Train Bal. Acc: 0.6009 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6259 | Val Avg. Loss: 0.5533
# Epoch [19/25] | Train Bal. Acc: 0.5833 | Val Bal. Acc: 0.7336
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6240 | Val Avg. Loss: 0.5619
# Epoch [20/25] | Train Bal. Acc: 0.6134 | Val Bal. Acc: 0.7336
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6335 | Val Avg. Loss: 0.5707
# Epoch [21/25] | Train Bal. Acc: 0.6109 | Val Bal. Acc: 0.7072
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6302 | Val Avg. Loss: 0.5543
# Epoch [22/25] | Train Bal. Acc: 0.6485 | Val Bal. Acc: 0.7336
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6175 | Val Avg. Loss: 0.5411
# Epoch [23/25] | Train Bal. Acc: 0.6159 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6260 | Val Avg. Loss: 0.5347
# Epoch [24/25] | Train Bal. Acc: 0.6040 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6479 | Val Avg. Loss: 0.5330
# Epoch [25/25] | Train Bal. Acc: 0.5708 | Val Bal. Acc: 0.6612
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.8217614889144897
# [[1 3]
#  [1 3]]
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7234 | Val Avg. Loss: 0.7021
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6885 | Val Avg. Loss: 0.6696
# Epoch [2/25] | Train Bal. Acc: 0.5381 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6851 | Val Avg. Loss: 0.6498
# Epoch [3/25] | Train Bal. Acc: 0.5119 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6887 | Val Avg. Loss: 0.6288
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6873 | Val Avg. Loss: 0.6159
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6806 | Val Avg. Loss: 0.6045
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6792 | Val Avg. Loss: 0.6056
# Epoch [7/25] | Train Bal. Acc: 0.5119 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6732 | Val Avg. Loss: 0.6091
# Epoch [8/25] | Train Bal. Acc: 0.5476 | Val Bal. Acc: 0.6212
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6683 | Val Avg. Loss: 0.6153
# Epoch [9/25] | Train Bal. Acc: 0.5873 | Val Bal. Acc: 0.5985
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6699 | Val Avg. Loss: 0.6035
# Epoch [10/25] | Train Bal. Acc: 0.6246 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6625 | Val Avg. Loss: 0.6100
# Epoch [11/25] | Train Bal. Acc: 0.6619 | Val Bal. Acc: 0.6414
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6551 | Val Avg. Loss: 0.5837
# Epoch [12/25] | Train Bal. Acc: 0.6627 | Val Bal. Acc: 0.5859
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6657 | Val Avg. Loss: 0.5733
# Epoch [13/25] | Train Bal. Acc: 0.6968 | Val Bal. Acc: 0.5859
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6587 | Val Avg. Loss: 0.6017
# Epoch [14/25] | Train Bal. Acc: 0.6992 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6595 | Val Avg. Loss: 0.6134
# Epoch [15/25] | Train Bal. Acc: 0.6683 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6449 | Val Avg. Loss: 0.5946
# Epoch [16/25] | Train Bal. Acc: 0.6913 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6652 | Val Avg. Loss: 0.5807
# Epoch [17/25] | Train Bal. Acc: 0.6421 | Val Bal. Acc: 0.6970
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6367 | Val Avg. Loss: 0.5921
# Epoch [18/25] | Train Bal. Acc: 0.7127 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6419 | Val Avg. Loss: 0.5938
# Epoch [19/25] | Train Bal. Acc: 0.6913 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6345 | Val Avg. Loss: 0.5828
# Epoch [20/25] | Train Bal. Acc: 0.7365 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6414 | Val Avg. Loss: 0.5927
# Epoch [21/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6300 | Val Avg. Loss: 0.5833
# Epoch [22/25] | Train Bal. Acc: 0.6921 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6252 | Val Avg. Loss: 0.6101
# Epoch [23/25] | Train Bal. Acc: 0.6913 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6194 | Val Avg. Loss: 0.5748
# Epoch [24/25] | Train Bal. Acc: 0.7151 | Val Bal. Acc: 0.6970
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6304 | Val Avg. Loss: 0.5713
# Epoch [25/25] | Train Bal. Acc: 0.7111 | Val Bal. Acc: 0.6970
# --------------------
# Bal. Accuracy: 0.7564102564102564
# Avg. Loss:  0.4893556833267212
# [[ 2  1]
#  [ 2 11]]
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6883 | Val Avg. Loss: 0.6313
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6663 | Val Avg. Loss: 0.6035
# Epoch [2/25] | Train Bal. Acc: 0.5113 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6698 | Val Avg. Loss: 0.5844
# Epoch [3/25] | Train Bal. Acc: 0.5983 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6590 | Val Avg. Loss: 0.6222
# Epoch [4/25] | Train Bal. Acc: 0.5892 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6479 | Val Avg. Loss: 0.6610
# Epoch [5/25] | Train Bal. Acc: 0.6381 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6470 | Val Avg. Loss: 0.6358
# Epoch [6/25] | Train Bal. Acc: 0.6291 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6469 | Val Avg. Loss: 0.6099
# Epoch [7/25] | Train Bal. Acc: 0.6255 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6373 | Val Avg. Loss: 0.6183
# Epoch [8/25] | Train Bal. Acc: 0.6463 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.6491
# Epoch [9/25] | Train Bal. Acc: 0.6486 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6289 | Val Avg. Loss: 0.6564
# Epoch [10/25] | Train Bal. Acc: 0.6716 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6377 | Val Avg. Loss: 0.6404
# Epoch [11/25] | Train Bal. Acc: 0.6073 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6447 | Val Avg. Loss: 0.6304
# Epoch [12/25] | Train Bal. Acc: 0.6286 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6433 | Val Avg. Loss: 0.6616
# Epoch [13/25] | Train Bal. Acc: 0.6282 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6293 | Val Avg. Loss: 0.6520
# Epoch [14/25] | Train Bal. Acc: 0.6486 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6392 | Val Avg. Loss: 0.6891
# Epoch [15/25] | Train Bal. Acc: 0.6069 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6220 | Val Avg. Loss: 0.6619
# Epoch [16/25] | Train Bal. Acc: 0.6196 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6377 | Val Avg. Loss: 0.6445
# Epoch [17/25] | Train Bal. Acc: 0.6386 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6299 | Val Avg. Loss: 0.6537
# Epoch [18/25] | Train Bal. Acc: 0.6495 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6467 | Val Avg. Loss: 0.6870
# Epoch [19/25] | Train Bal. Acc: 0.6282 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6505 | Val Avg. Loss: 0.6741
# Epoch [20/25] | Train Bal. Acc: 0.6178 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6350 | Val Avg. Loss: 0.6826
# Epoch [21/25] | Train Bal. Acc: 0.5978 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6335 | Val Avg. Loss: 0.6447
# Epoch [22/25] | Train Bal. Acc: 0.6386 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6202 | Val Avg. Loss: 0.6369
# Epoch [23/25] | Train Bal. Acc: 0.6703 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6275 | Val Avg. Loss: 0.6611
# Epoch [24/25] | Train Bal. Acc: 0.6390 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6358 | Val Avg. Loss: 0.6870
# Epoch [25/25] | Train Bal. Acc: 0.5657 | Val Bal. Acc: 0.5476
# --------------------
# Bal. Accuracy: 0.4090909090909091
# Avg. Loss:  0.5802837610244751
# [[0 1]
#  [2 9]]
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6769 | Val Avg. Loss: 0.5707
# Epoch [1/25] | Train Bal. Acc: 0.5495 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6761 | Val Avg. Loss: 0.5885
# Epoch [2/25] | Train Bal. Acc: 0.5709 | Val Bal. Acc: 0.6212
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6702 | Val Avg. Loss: 0.5812
# Epoch [3/25] | Train Bal. Acc: 0.5664 | Val Bal. Acc: 0.5985
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6681 | Val Avg. Loss: 0.5936
# Epoch [4/25] | Train Bal. Acc: 0.6445 | Val Bal. Acc: 0.5530
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6574 | Val Avg. Loss: 0.5833
# Epoch [5/25] | Train Bal. Acc: 0.6459 | Val Bal. Acc: 0.5758
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6662 | Val Avg. Loss: 0.6080
# Epoch [6/25] | Train Bal. Acc: 0.6400 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6579 | Val Avg. Loss: 0.5558
# Epoch [7/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.6364
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6525 | Val Avg. Loss: 0.5470
# Epoch [8/25] | Train Bal. Acc: 0.6373 | Val Bal. Acc: 0.6364
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6479 | Val Avg. Loss: 0.5626
# Epoch [9/25] | Train Bal. Acc: 0.6473 | Val Bal. Acc: 0.6136
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6463 | Val Avg. Loss: 0.5616
# Epoch [10/25] | Train Bal. Acc: 0.6500 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6407 | Val Avg. Loss: 0.5399
# Epoch [11/25] | Train Bal. Acc: 0.6414 | Val Bal. Acc: 0.6136
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6284 | Val Avg. Loss: 0.5664
# Epoch [12/25] | Train Bal. Acc: 0.6600 | Val Bal. Acc: 0.5682
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6523 | Val Avg. Loss: 0.5806
# Epoch [13/25] | Train Bal. Acc: 0.6641 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6338 | Val Avg. Loss: 0.5621
# Epoch [14/25] | Train Bal. Acc: 0.6568 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6302 | Val Avg. Loss: 0.5670
# Epoch [15/25] | Train Bal. Acc: 0.6655 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6237 | Val Avg. Loss: 0.5360
# Epoch [16/25] | Train Bal. Acc: 0.6341 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6258 | Val Avg. Loss: 0.5342
# Epoch [17/25] | Train Bal. Acc: 0.6655 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6273 | Val Avg. Loss: 0.5294
# Epoch [18/25] | Train Bal. Acc: 0.6568 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6116 | Val Avg. Loss: 0.5672
# Epoch [19/25] | Train Bal. Acc: 0.6695 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6060 | Val Avg. Loss: 0.5298
# Epoch [20/25] | Train Bal. Acc: 0.6723 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6065 | Val Avg. Loss: 0.5108
# Epoch [21/25] | Train Bal. Acc: 0.6541 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6374 | Val Avg. Loss: 0.5573
# Epoch [22/25] | Train Bal. Acc: 0.6895 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6184 | Val Avg. Loss: 0.5489
# Epoch [23/25] | Train Bal. Acc: 0.6836 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6130 | Val Avg. Loss: 0.5313
# Epoch [24/25] | Train Bal. Acc: 0.6582 | Val Bal. Acc: 0.5909
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6027 | Val Avg. Loss: 0.5347
# Epoch [25/25] | Train Bal. Acc: 0.6568 | Val Bal. Acc: 0.5909
# --------------------
# Bal. Accuracy: 0.625
# Avg. Loss:  0.6423786282539368
# [[2 2]
#  [2 6]]
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6539 | Val Avg. Loss: 0.5015
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6125 | Val Avg. Loss: 0.5146
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6162 | Val Avg. Loss: 0.5227
# Epoch [3/25] | Train Bal. Acc: 0.5147 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6158 | Val Avg. Loss: 0.4954
# Epoch [4/25] | Train Bal. Acc: 0.5352 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6111 | Val Avg. Loss: 0.5051
# Epoch [5/25] | Train Bal. Acc: 0.5352 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6223 | Val Avg. Loss: 0.4959
# Epoch [6/25] | Train Bal. Acc: 0.5347 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6026 | Val Avg. Loss: 0.4856
# Epoch [7/25] | Train Bal. Acc: 0.5672 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5892 | Val Avg. Loss: 0.4689
# Epoch [8/25] | Train Bal. Acc: 0.5935 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6198 | Val Avg. Loss: 0.4857
# Epoch [9/25] | Train Bal. Acc: 0.5551 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5998 | Val Avg. Loss: 0.4770
# Epoch [10/25] | Train Bal. Acc: 0.5846 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6003 | Val Avg. Loss: 0.4596
# Epoch [11/25] | Train Bal. Acc: 0.5641 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5929 | Val Avg. Loss: 0.4576
# Epoch [12/25] | Train Bal. Acc: 0.5756 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5972 | Val Avg. Loss: 0.4520
# Epoch [13/25] | Train Bal. Acc: 0.5846 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6092 | Val Avg. Loss: 0.4758
# Epoch [14/25] | Train Bal. Acc: 0.5987 | Val Bal. Acc: 0.8125
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6004 | Val Avg. Loss: 0.4332
# Epoch [15/25] | Train Bal. Acc: 0.6166 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6037 | Val Avg. Loss: 0.4498
# Epoch [16/25] | Train Bal. Acc: 0.6255 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6274 | Val Avg. Loss: 0.5184
# Epoch [17/25] | Train Bal. Acc: 0.6397 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6016 | Val Avg. Loss: 0.4640
# Epoch [18/25] | Train Bal. Acc: 0.6339 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6068 | Val Avg. Loss: 0.4314
# Epoch [19/25] | Train Bal. Acc: 0.6108 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5893 | Val Avg. Loss: 0.4590
# Epoch [20/25] | Train Bal. Acc: 0.6224 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5918 | Val Avg. Loss: 0.4689
# Epoch [21/25] | Train Bal. Acc: 0.6313 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5988 | Val Avg. Loss: 0.4562
# Epoch [22/25] | Train Bal. Acc: 0.6134 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5861 | Val Avg. Loss: 0.4481
# Epoch [23/25] | Train Bal. Acc: 0.6192 | Val Bal. Acc: 0.8125
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5938 | Val Avg. Loss: 0.4423
# Epoch [24/25] | Train Bal. Acc: 0.6460 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5817 | Val Avg. Loss: 0.4512
# Epoch [25/25] | Train Bal. Acc: 0.6371 | Val Bal. Acc: 0.7862
# --------------------
# Bal. Accuracy: 0.5666666666666667
# Avg. Loss:  0.8743428097051733
# [[4 8]
#  [1 4]]
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7027 | Val Avg. Loss: 0.7304
# Epoch [1/25] | Train Bal. Acc: 0.5208 | Val Bal. Acc: 0.4982
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.5828 | Val Avg. Loss: 0.8394
# Epoch [2/25] | Train Bal. Acc: 0.5312 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5942 | Val Avg. Loss: 0.9139
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5882 | Val Avg. Loss: 0.8334
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5879 | Val Avg. Loss: 0.7573
# Epoch [5/25] | Train Bal. Acc: 0.4917 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5752 | Val Avg. Loss: 0.7746
# Epoch [6/25] | Train Bal. Acc: 0.5698 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5642 | Val Avg. Loss: 0.8065
# Epoch [7/25] | Train Bal. Acc: 0.5542 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5773 | Val Avg. Loss: 0.7773
# Epoch [8/25] | Train Bal. Acc: 0.5927 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5630 | Val Avg. Loss: 0.7578
# Epoch [9/25] | Train Bal. Acc: 0.5990 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5597 | Val Avg. Loss: 0.7577
# Epoch [10/25] | Train Bal. Acc: 0.5823 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5652 | Val Avg. Loss: 0.7762
# Epoch [11/25] | Train Bal. Acc: 0.6219 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5647 | Val Avg. Loss: 0.7368
# Epoch [12/25] | Train Bal. Acc: 0.6375 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5533 | Val Avg. Loss: 0.7621
# Epoch [13/25] | Train Bal. Acc: 0.6365 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5510 | Val Avg. Loss: 0.7584
# Epoch [14/25] | Train Bal. Acc: 0.6292 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5682 | Val Avg. Loss: 0.7087
# Epoch [15/25] | Train Bal. Acc: 0.6510 | Val Bal. Acc: 0.5496
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5528 | Val Avg. Loss: 0.7509
# Epoch [16/25] | Train Bal. Acc: 0.6594 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5543 | Val Avg. Loss: 0.7720
# Epoch [17/25] | Train Bal. Acc: 0.7073 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5467 | Val Avg. Loss: 0.7437
# Epoch [18/25] | Train Bal. Acc: 0.6750 | Val Bal. Acc: 0.5515
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5382 | Val Avg. Loss: 0.7357
# Epoch [19/25] | Train Bal. Acc: 0.6979 | Val Bal. Acc: 0.5496
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5534 | Val Avg. Loss: 0.7696
# Epoch [20/25] | Train Bal. Acc: 0.6740 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5612 | Val Avg. Loss: 0.8078
# Epoch [21/25] | Train Bal. Acc: 0.6833 | Val Bal. Acc: 0.5533
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5393 | Val Avg. Loss: 0.7226
# Epoch [22/25] | Train Bal. Acc: 0.6740 | Val Bal. Acc: 0.5496
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5609 | Val Avg. Loss: 0.7244
# Epoch [23/25] | Train Bal. Acc: 0.7135 | Val Bal. Acc: 0.5809
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5561 | Val Avg. Loss: 0.7580
# Epoch [24/25] | Train Bal. Acc: 0.6823 | Val Bal. Acc: 0.5515
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5373 | Val Avg. Loss: 0.8053
# Epoch [25/25] | Train Bal. Acc: 0.6979 | Val Bal. Acc: 0.5533
# --------------------
# Bal. Accuracy: 0.6
# Avg. Loss:  0.5908421277999878
# [[1 4]
#  [0 4]]
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6712 | Val Avg. Loss: 0.7363
# Epoch [1/25] | Train Bal. Acc: 0.4211 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6077 | Val Avg. Loss: 0.9668
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5767 | Val Avg. Loss: 1.0911
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5782 | Val Avg. Loss: 0.9749
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5630 | Val Avg. Loss: 0.8570
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5556 | Val Avg. Loss: 0.8878
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5459 | Val Avg. Loss: 0.8956
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5244 | Val Avg. Loss: 0.8987
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5172 | Val Avg. Loss: 1.0375
# Epoch [9/25] | Train Bal. Acc: 0.5500 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5105 | Val Avg. Loss: 0.9055
# Epoch [10/25] | Train Bal. Acc: 0.5325 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5207 | Val Avg. Loss: 0.7656
# Epoch [11/25] | Train Bal. Acc: 0.6377 | Val Bal. Acc: 0.6178
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.4998 | Val Avg. Loss: 0.9311
# Epoch [12/25] | Train Bal. Acc: 0.6623 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.4987 | Val Avg. Loss: 0.9597
# Epoch [13/25] | Train Bal. Acc: 0.6386 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.4882 | Val Avg. Loss: 0.8920
# Epoch [14/25] | Train Bal. Acc: 0.6474 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.4877 | Val Avg. Loss: 0.8003
# Epoch [15/25] | Train Bal. Acc: 0.6281 | Val Bal. Acc: 0.6178
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5058 | Val Avg. Loss: 0.7884
# Epoch [16/25] | Train Bal. Acc: 0.6781 | Val Bal. Acc: 0.6418
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.4887 | Val Avg. Loss: 0.9222
# Epoch [17/25] | Train Bal. Acc: 0.6868 | Val Bal. Acc: 0.5865
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.4920 | Val Avg. Loss: 1.0036
# Epoch [18/25] | Train Bal. Acc: 0.6377 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4844 | Val Avg. Loss: 0.8975
# Epoch [19/25] | Train Bal. Acc: 0.6456 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4750 | Val Avg. Loss: 0.7986
# Epoch [20/25] | Train Bal. Acc: 0.6684 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4712 | Val Avg. Loss: 0.9040
# Epoch [21/25] | Train Bal. Acc: 0.6860 | Val Bal. Acc: 0.6178
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4738 | Val Avg. Loss: 0.9181
# Epoch [22/25] | Train Bal. Acc: 0.7123 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4771 | Val Avg. Loss: 0.9594
# Epoch [23/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4826 | Val Avg. Loss: 0.8941
# Epoch [24/25] | Train Bal. Acc: 0.6526 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4583 | Val Avg. Loss: 0.8751
# Epoch [25/25] | Train Bal. Acc: 0.6868 | Val Bal. Acc: 0.6418
# --------------------
# Bal. Accuracy: 0.525
# Avg. Loss:  1.1546062893337674
# [[2 6]
#  [2 8]]
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7608 | Val Avg. Loss: 0.6435
# Epoch [1/25] | Train Bal. Acc: 0.3111 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6993 | Val Avg. Loss: 0.6170
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6970 | Val Avg. Loss: 0.6179
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6990 | Val Avg. Loss: 0.6328
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6974 | Val Avg. Loss: 0.6562
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6920 | Val Avg. Loss: 0.6609
# Epoch [6/25] | Train Bal. Acc: 0.4889 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6899 | Val Avg. Loss: 0.6673
# Epoch [7/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6911 | Val Avg. Loss: 0.6804
# Epoch [8/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6928 | Val Avg. Loss: 0.6914
# Epoch [9/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6921 | Val Avg. Loss: 0.6972
# Epoch [10/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6908 | Val Avg. Loss: 0.6869
# Epoch [11/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6892 | Val Avg. Loss: 0.6889
# Epoch [12/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6916 | Val Avg. Loss: 0.6770
# Epoch [13/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6857 | Val Avg. Loss: 0.6760
# Epoch [14/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6883 | Val Avg. Loss: 0.6792
# Epoch [15/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6878 | Val Avg. Loss: 0.6786
# Epoch [16/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6858 | Val Avg. Loss: 0.6796
# Epoch [17/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6878 | Val Avg. Loss: 0.6862
# Epoch [18/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6854 | Val Avg. Loss: 0.6971
# Epoch [19/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6891 | Val Avg. Loss: 0.6957
# Epoch [20/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6832 | Val Avg. Loss: 0.6892
# Epoch [21/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6896 | Val Avg. Loss: 0.6934
# Epoch [22/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6851 | Val Avg. Loss: 0.6881
# Epoch [23/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6853 | Val Avg. Loss: 0.6863
# Epoch [24/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6873 | Val Avg. Loss: 0.6760
# Epoch [25/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.5417
# --------------------
# Bal. Accuracy: 0.7727272727272727
# Avg. Loss:  0.6915618181228638
# [[5 0]
#  [5 6]]
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6921 | Val Avg. Loss: 0.6410
# Epoch [1/25] | Train Bal. Acc: 0.5435 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6782 | Val Avg. Loss: 0.6687
# Epoch [2/25] | Train Bal. Acc: 0.5630 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6763 | Val Avg. Loss: 0.6882
# Epoch [3/25] | Train Bal. Acc: 0.6249 | Val Bal. Acc: 0.3333
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6743 | Val Avg. Loss: 0.6455
# Epoch [4/25] | Train Bal. Acc: 0.5490 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6534 | Val Avg. Loss: 0.6088
# Epoch [5/25] | Train Bal. Acc: 0.6271 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6557 | Val Avg. Loss: 0.6344
# Epoch [6/25] | Train Bal. Acc: 0.6051 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6503 | Val Avg. Loss: 0.6729
# Epoch [7/25] | Train Bal. Acc: 0.6147 | Val Bal. Acc: 0.3333
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6608 | Val Avg. Loss: 0.6514
# Epoch [8/25] | Train Bal. Acc: 0.6145 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6561 | Val Avg. Loss: 0.7047
# Epoch [9/25] | Train Bal. Acc: 0.5587 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6387 | Val Avg. Loss: 0.6474
# Epoch [10/25] | Train Bal. Acc: 0.6355 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6447 | Val Avg. Loss: 0.6424
# Epoch [11/25] | Train Bal. Acc: 0.6041 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6411 | Val Avg. Loss: 0.6832
# Epoch [12/25] | Train Bal. Acc: 0.6365 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6235 | Val Avg. Loss: 0.6485
# Epoch [13/25] | Train Bal. Acc: 0.6362 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6538 | Val Avg. Loss: 0.6842
# Epoch [14/25] | Train Bal. Acc: 0.6258 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6533 | Val Avg. Loss: 0.7323
# Epoch [15/25] | Train Bal. Acc: 0.5908 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6377 | Val Avg. Loss: 0.6684
# Epoch [16/25] | Train Bal. Acc: 0.6684 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6319 | Val Avg. Loss: 0.6463
# Epoch [17/25] | Train Bal. Acc: 0.6478 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6418 | Val Avg. Loss: 0.6962
# Epoch [18/25] | Train Bal. Acc: 0.5920 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6417 | Val Avg. Loss: 0.7018
# Epoch [19/25] | Train Bal. Acc: 0.6140 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6576 | Val Avg. Loss: 0.6524
# Epoch [20/25] | Train Bal. Acc: 0.6367 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6642 | Val Avg. Loss: 0.7423
# Epoch [21/25] | Train Bal. Acc: 0.6246 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6497 | Val Avg. Loss: 0.7012
# Epoch [22/25] | Train Bal. Acc: 0.6686 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6453 | Val Avg. Loss: 0.6913
# Epoch [23/25] | Train Bal. Acc: 0.6135 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6317 | Val Avg. Loss: 0.6675
# Epoch [24/25] | Train Bal. Acc: 0.6908 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6480 | Val Avg. Loss: 0.7120
# Epoch [25/25] | Train Bal. Acc: 0.6034 | Val Bal. Acc: 0.4792
# --------------------
# Bal. Accuracy: 0.6022727272727273
# Avg. Loss:  0.6152299046516418
# [[3 1]
#  [6 5]]
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.5985 | Val Avg. Loss: 0.8720
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.5897 | Val Avg. Loss: 0.8940
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5828 | Val Avg. Loss: 0.8087
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5793 | Val Avg. Loss: 0.7890
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5715 | Val Avg. Loss: 0.8483
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5787 | Val Avg. Loss: 0.8604
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5681 | Val Avg. Loss: 0.7710
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.4688
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5601 | Val Avg. Loss: 0.7917
# Epoch [8/25] | Train Bal. Acc: 0.5172 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5528 | Val Avg. Loss: 0.8190
# Epoch [9/25] | Train Bal. Acc: 0.5345 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5596 | Val Avg. Loss: 0.7959
# Epoch [10/25] | Train Bal. Acc: 0.5616 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5603 | Val Avg. Loss: 0.8614
# Epoch [11/25] | Train Bal. Acc: 0.5789 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5580 | Val Avg. Loss: 0.7842
# Epoch [12/25] | Train Bal. Acc: 0.5189 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5561 | Val Avg. Loss: 0.8270
# Epoch [13/25] | Train Bal. Acc: 0.6306 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5508 | Val Avg. Loss: 0.8025
# Epoch [14/25] | Train Bal. Acc: 0.6051 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5528 | Val Avg. Loss: 0.7629
# Epoch [15/25] | Train Bal. Acc: 0.6495 | Val Bal. Acc: 0.5221
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5547 | Val Avg. Loss: 0.8128
# Epoch [16/25] | Train Bal. Acc: 0.6495 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5530 | Val Avg. Loss: 0.8372
# Epoch [17/25] | Train Bal. Acc: 0.6060 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5361 | Val Avg. Loss: 0.7964
# Epoch [18/25] | Train Bal. Acc: 0.6396 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5418 | Val Avg. Loss: 0.8232
# Epoch [19/25] | Train Bal. Acc: 0.5806 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5390 | Val Avg. Loss: 0.8292
# Epoch [20/25] | Train Bal. Acc: 0.6487 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5436 | Val Avg. Loss: 0.7960
# Epoch [21/25] | Train Bal. Acc: 0.5986 | Val Bal. Acc: 0.5809
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5408 | Val Avg. Loss: 0.7837
# Epoch [22/25] | Train Bal. Acc: 0.6413 | Val Bal. Acc: 0.5809
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5343 | Val Avg. Loss: 0.8280
# Epoch [23/25] | Train Bal. Acc: 0.6405 | Val Bal. Acc: 0.5809
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5354 | Val Avg. Loss: 0.7986
# Epoch [24/25] | Train Bal. Acc: 0.6331 | Val Bal. Acc: 0.5496
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5372 | Val Avg. Loss: 0.7835
# Epoch [25/25] | Train Bal. Acc: 0.6413 | Val Bal. Acc: 0.5496
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.672489583492279
# [[8 0]
#  [3 0]]
# Accuracy (Balanced): 0.6092592592592592
# Avg. Loss: 0.7132852094625337
#               precision    recall  f1-score   support
#
#            0       0.54      0.52      0.53        54
#            1       0.68      0.70      0.69        80
#
#     accuracy                           0.63       134
#    macro avg       0.61      0.61      0.61       134
# weighted avg       0.62      0.63      0.63       134

# %%
_ = attention_based_mil(df, ["AU02_r", "AU09_r"])
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6814 | Val Avg. Loss: 0.5826
# Epoch [1/25] | Train Bal. Acc: 0.5633 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6783 | Val Avg. Loss: 0.5535
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6759 | Val Avg. Loss: 0.5664
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6731 | Val Avg. Loss: 0.6301
# Epoch [4/25] | Train Bal. Acc: 0.5031 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6774 | Val Avg. Loss: 0.6609
# Epoch [5/25] | Train Bal. Acc: 0.6284 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6757 | Val Avg. Loss: 0.6270
# Epoch [6/25] | Train Bal. Acc: 0.5514 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6680 | Val Avg. Loss: 0.5830
# Epoch [7/25] | Train Bal. Acc: 0.5150 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6687 | Val Avg. Loss: 0.5680
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6729 | Val Avg. Loss: 0.5498
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6742 | Val Avg. Loss: 0.5601
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6660 | Val Avg. Loss: 0.5821
# Epoch [11/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6622 | Val Avg. Loss: 0.6103
# Epoch [12/25] | Train Bal. Acc: 0.5119 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6669 | Val Avg. Loss: 0.6247
# Epoch [13/25] | Train Bal. Acc: 0.5451 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6653 | Val Avg. Loss: 0.6057
# Epoch [14/25] | Train Bal. Acc: 0.5840 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6598 | Val Avg. Loss: 0.5816
# Epoch [15/25] | Train Bal. Acc: 0.5808 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6579 | Val Avg. Loss: 0.5604
# Epoch [16/25] | Train Bal. Acc: 0.6046 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6570 | Val Avg. Loss: 0.5381
# Epoch [17/25] | Train Bal. Acc: 0.5871 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6593 | Val Avg. Loss: 0.5513
# Epoch [18/25] | Train Bal. Acc: 0.5959 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6525 | Val Avg. Loss: 0.5710
# Epoch [19/25] | Train Bal. Acc: 0.5902 | Val Bal. Acc: 0.7237
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6572 | Val Avg. Loss: 0.5542
# Epoch [20/25] | Train Bal. Acc: 0.5965 | Val Bal. Acc: 0.7237
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6518 | Val Avg. Loss: 0.6076
# Epoch [21/25] | Train Bal. Acc: 0.5996 | Val Bal. Acc: 0.6447
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6576 | Val Avg. Loss: 0.5978
# Epoch [22/25] | Train Bal. Acc: 0.6003 | Val Bal. Acc: 0.6447
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6450 | Val Avg. Loss: 0.5441
# Epoch [23/25] | Train Bal. Acc: 0.6147 | Val Bal. Acc: 0.6711
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6558 | Val Avg. Loss: 0.5463
# Epoch [24/25] | Train Bal. Acc: 0.6115 | Val Bal. Acc: 0.6974
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6780 | Val Avg. Loss: 0.5556
# Epoch [25/25] | Train Bal. Acc: 0.6021 | Val Bal. Acc: 0.6974
# --------------------
# Bal. Accuracy: 0.625
# Avg. Loss:  0.6585657596588135
# [[1 3]
#  [0 4]]
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7258 | Val Avg. Loss: 0.7086
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6872 | Val Avg. Loss: 0.6503
# Epoch [2/25] | Train Bal. Acc: 0.5246 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6817 | Val Avg. Loss: 0.6230
# Epoch [3/25] | Train Bal. Acc: 0.5119 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6870 | Val Avg. Loss: 0.6006
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6898 | Val Avg. Loss: 0.6026
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6800 | Val Avg. Loss: 0.6208
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6785 | Val Avg. Loss: 0.6256
# Epoch [7/25] | Train Bal. Acc: 0.5952 | Val Bal. Acc: 0.6439
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6752 | Val Avg. Loss: 0.6226
# Epoch [8/25] | Train Bal. Acc: 0.5500 | Val Bal. Acc: 0.6768
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6744 | Val Avg. Loss: 0.6206
# Epoch [9/25] | Train Bal. Acc: 0.5786 | Val Bal. Acc: 0.6313
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6736 | Val Avg. Loss: 0.6099
# Epoch [10/25] | Train Bal. Acc: 0.5913 | Val Bal. Acc: 0.6313
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6716 | Val Avg. Loss: 0.6261
# Epoch [11/25] | Train Bal. Acc: 0.6389 | Val Bal. Acc: 0.6869
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6705 | Val Avg. Loss: 0.6106
# Epoch [12/25] | Train Bal. Acc: 0.6524 | Val Bal. Acc: 0.6313
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6658 | Val Avg. Loss: 0.5907
# Epoch [13/25] | Train Bal. Acc: 0.6611 | Val Bal. Acc: 0.6313
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6682 | Val Avg. Loss: 0.6185
# Epoch [14/25] | Train Bal. Acc: 0.6619 | Val Bal. Acc: 0.7424
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6662 | Val Avg. Loss: 0.6257
# Epoch [15/25] | Train Bal. Acc: 0.6643 | Val Bal. Acc: 0.7298
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6636 | Val Avg. Loss: 0.6148
# Epoch [16/25] | Train Bal. Acc: 0.6651 | Val Bal. Acc: 0.7980
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6744 | Val Avg. Loss: 0.6100
# Epoch [17/25] | Train Bal. Acc: 0.6286 | Val Bal. Acc: 0.7424
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6581 | Val Avg. Loss: 0.6184
# Epoch [18/25] | Train Bal. Acc: 0.6421 | Val Bal. Acc: 0.7298
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6629 | Val Avg. Loss: 0.6240
# Epoch [19/25] | Train Bal. Acc: 0.6325 | Val Bal. Acc: 0.7854
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6635 | Val Avg. Loss: 0.6155
# Epoch [20/25] | Train Bal. Acc: 0.6429 | Val Bal. Acc: 0.7854
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6648 | Val Avg. Loss: 0.6302
# Epoch [21/25] | Train Bal. Acc: 0.6325 | Val Bal. Acc: 0.7626
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6543 | Val Avg. Loss: 0.6064
# Epoch [22/25] | Train Bal. Acc: 0.6452 | Val Bal. Acc: 0.7298
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6635 | Val Avg. Loss: 0.6001
# Epoch [23/25] | Train Bal. Acc: 0.6532 | Val Bal. Acc: 0.7298
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6505 | Val Avg. Loss: 0.5972
# Epoch [24/25] | Train Bal. Acc: 0.6429 | Val Bal. Acc: 0.7298
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6599 | Val Avg. Loss: 0.6102
# Epoch [25/25] | Train Bal. Acc: 0.6421 | Val Bal. Acc: 0.7854
# --------------------
# Bal. Accuracy: 0.5128205128205128
# Avg. Loss:  0.5718896985054016
# [[1 2]
#  [4 9]]
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6886 | Val Avg. Loss: 0.6332
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6717 | Val Avg. Loss: 0.6195
# Epoch [2/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6699 | Val Avg. Loss: 0.6087
# Epoch [3/25] | Train Bal. Acc: 0.6209 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6651 | Val Avg. Loss: 0.6291
# Epoch [4/25] | Train Bal. Acc: 0.6332 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6674 | Val Avg. Loss: 0.6463
# Epoch [5/25] | Train Bal. Acc: 0.6028 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6573 | Val Avg. Loss: 0.6584
# Epoch [6/25] | Train Bal. Acc: 0.6481 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6528 | Val Avg. Loss: 0.6463
# Epoch [7/25] | Train Bal. Acc: 0.6377 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6598 | Val Avg. Loss: 0.6400
# Epoch [8/25] | Train Bal. Acc: 0.6472 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6536 | Val Avg. Loss: 0.6680
# Epoch [9/25] | Train Bal. Acc: 0.6803 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6581 | Val Avg. Loss: 0.6805
# Epoch [10/25] | Train Bal. Acc: 0.6078 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6476 | Val Avg. Loss: 0.6557
# Epoch [11/25] | Train Bal. Acc: 0.6282 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6483 | Val Avg. Loss: 0.6572
# Epoch [12/25] | Train Bal. Acc: 0.6173 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6563 | Val Avg. Loss: 0.6593
# Epoch [13/25] | Train Bal. Acc: 0.6372 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6455 | Val Avg. Loss: 0.6583
# Epoch [14/25] | Train Bal. Acc: 0.6590 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6447 | Val Avg. Loss: 0.6624
# Epoch [15/25] | Train Bal. Acc: 0.6164 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6348 | Val Avg. Loss: 0.6628
# Epoch [16/25] | Train Bal. Acc: 0.6381 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6299 | Val Avg. Loss: 0.6549
# Epoch [17/25] | Train Bal. Acc: 0.6481 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6303 | Val Avg. Loss: 0.6646
# Epoch [18/25] | Train Bal. Acc: 0.6476 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6438 | Val Avg. Loss: 0.6787
# Epoch [19/25] | Train Bal. Acc: 0.6381 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6327 | Val Avg. Loss: 0.6720
# Epoch [20/25] | Train Bal. Acc: 0.6698 | Val Bal. Acc: 0.5476
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6405 | Val Avg. Loss: 0.6938
# Epoch [21/25] | Train Bal. Acc: 0.6064 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6129 | Val Avg. Loss: 0.6771
# Epoch [22/25] | Train Bal. Acc: 0.6495 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6220 | Val Avg. Loss: 0.6634
# Epoch [23/25] | Train Bal. Acc: 0.6268 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6410 | Val Avg. Loss: 0.6778
# Epoch [24/25] | Train Bal. Acc: 0.6472 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6295 | Val Avg. Loss: 0.6918
# Epoch [25/25] | Train Bal. Acc: 0.6377 | Val Bal. Acc: 0.6429
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6116894483566284
# [[ 0  1]
#  [ 0 11]]
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6727 | Val Avg. Loss: 0.6319
# Epoch [1/25] | Train Bal. Acc: 0.5723 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6715 | Val Avg. Loss: 0.6427
# Epoch [2/25] | Train Bal. Acc: 0.5355 | Val Bal. Acc: 0.4545
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6599 | Val Avg. Loss: 0.6633
# Epoch [3/25] | Train Bal. Acc: 0.6318 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6488 | Val Avg. Loss: 0.6779
# Epoch [4/25] | Train Bal. Acc: 0.6814 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6499 | Val Avg. Loss: 0.6857
# Epoch [5/25] | Train Bal. Acc: 0.6968 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6548 | Val Avg. Loss: 0.6976
# Epoch [6/25] | Train Bal. Acc: 0.6255 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6558 | Val Avg. Loss: 0.6858
# Epoch [7/25] | Train Bal. Acc: 0.6541 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6500 | Val Avg. Loss: 0.6917
# Epoch [8/25] | Train Bal. Acc: 0.6455 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6441 | Val Avg. Loss: 0.6967
# Epoch [9/25] | Train Bal. Acc: 0.6668 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6486 | Val Avg. Loss: 0.6961
# Epoch [10/25] | Train Bal. Acc: 0.6682 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6429 | Val Avg. Loss: 0.6876
# Epoch [11/25] | Train Bal. Acc: 0.6541 | Val Bal. Acc: 0.4924
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6352 | Val Avg. Loss: 0.7001
# Epoch [12/25] | Train Bal. Acc: 0.7055 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6524 | Val Avg. Loss: 0.7202
# Epoch [13/25] | Train Bal. Acc: 0.6523 | Val Bal. Acc: 0.3788
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6466 | Val Avg. Loss: 0.7121
# Epoch [14/25] | Train Bal. Acc: 0.6482 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6394 | Val Avg. Loss: 0.7098
# Epoch [15/25] | Train Bal. Acc: 0.6182 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6324 | Val Avg. Loss: 0.7063
# Epoch [16/25] | Train Bal. Acc: 0.6509 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6305 | Val Avg. Loss: 0.7003
# Epoch [17/25] | Train Bal. Acc: 0.6595 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6360 | Val Avg. Loss: 0.6912
# Epoch [18/25] | Train Bal. Acc: 0.6555 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6245 | Val Avg. Loss: 0.6983
# Epoch [19/25] | Train Bal. Acc: 0.6855 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6335 | Val Avg. Loss: 0.6984
# Epoch [20/25] | Train Bal. Acc: 0.6668 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6312 | Val Avg. Loss: 0.6989
# Epoch [21/25] | Train Bal. Acc: 0.6227 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6214 | Val Avg. Loss: 0.6988
# Epoch [22/25] | Train Bal. Acc: 0.6555 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6256 | Val Avg. Loss: 0.6931
# Epoch [23/25] | Train Bal. Acc: 0.6527 | Val Bal. Acc: 0.4924
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6206 | Val Avg. Loss: 0.6912
# Epoch [24/25] | Train Bal. Acc: 0.6514 | Val Bal. Acc: 0.4924
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6452 | Val Avg. Loss: 0.7006
# Epoch [25/25] | Train Bal. Acc: 0.6555 | Val Bal. Acc: 0.4470
# --------------------
# Bal. Accuracy: 0.625
# Avg. Loss:  0.6394631266593933
# [[2 2]
#  [2 6]]
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6615 | Val Avg. Loss: 0.5336
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6534 | Val Avg. Loss: 0.5540
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6415 | Val Avg. Loss: 0.5535
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6297 | Val Avg. Loss: 0.5234
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6283 | Val Avg. Loss: 0.5252
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6359 | Val Avg. Loss: 0.5111
# Epoch [6/25] | Train Bal. Acc: 0.4911 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6213 | Val Avg. Loss: 0.5182
# Epoch [7/25] | Train Bal. Acc: 0.5205 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6016 | Val Avg. Loss: 0.4946
# Epoch [8/25] | Train Bal. Acc: 0.5205 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6203 | Val Avg. Loss: 0.4912
# Epoch [9/25] | Train Bal. Acc: 0.5557 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6154 | Val Avg. Loss: 0.5043
# Epoch [10/25] | Train Bal. Acc: 0.5672 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6172 | Val Avg. Loss: 0.5000
# Epoch [11/25] | Train Bal. Acc: 0.5551 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6073 | Val Avg. Loss: 0.4897
# Epoch [12/25] | Train Bal. Acc: 0.5609 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6113 | Val Avg. Loss: 0.4744
# Epoch [13/25] | Train Bal. Acc: 0.6024 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6175 | Val Avg. Loss: 0.5035
# Epoch [14/25] | Train Bal. Acc: 0.5756 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6004 | Val Avg. Loss: 0.4797
# Epoch [15/25] | Train Bal. Acc: 0.5636 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6157 | Val Avg. Loss: 0.4811
# Epoch [16/25] | Train Bal. Acc: 0.5725 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6345 | Val Avg. Loss: 0.5319
# Epoch [17/25] | Train Bal. Acc: 0.5987 | Val Bal. Acc: 0.7336
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6152 | Val Avg. Loss: 0.5089
# Epoch [18/25] | Train Bal. Acc: 0.6339 | Val Bal. Acc: 0.7336
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6102 | Val Avg. Loss: 0.4724
# Epoch [19/25] | Train Bal. Acc: 0.6313 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5962 | Val Avg. Loss: 0.4848
# Epoch [20/25] | Train Bal. Acc: 0.6019 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6005 | Val Avg. Loss: 0.4842
# Epoch [21/25] | Train Bal. Acc: 0.6077 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6185 | Val Avg. Loss: 0.4845
# Epoch [22/25] | Train Bal. Acc: 0.5751 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6035 | Val Avg. Loss: 0.4943
# Epoch [23/25] | Train Bal. Acc: 0.6077 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6064 | Val Avg. Loss: 0.4903
# Epoch [24/25] | Train Bal. Acc: 0.6134 | Val Bal. Acc: 0.7599
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6093 | Val Avg. Loss: 0.4884
# Epoch [25/25] | Train Bal. Acc: 0.6045 | Val Bal. Acc: 0.7599
# --------------------
# Bal. Accuracy: 0.6666666666666666
# Avg. Loss:  0.9157290143125197
# [[4 8]
#  [0 5]]
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7029 | Val Avg. Loss: 0.7175
# Epoch [1/25] | Train Bal. Acc: 0.4646 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6169 | Val Avg. Loss: 0.7404
# Epoch [2/25] | Train Bal. Acc: 0.5469 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6041 | Val Avg. Loss: 0.8241
# Epoch [3/25] | Train Bal. Acc: 0.5156 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5937 | Val Avg. Loss: 0.8311
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6093 | Val Avg. Loss: 0.7744
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5873 | Val Avg. Loss: 0.7710
# Epoch [6/25] | Train Bal. Acc: 0.5156 | Val Bal. Acc: 0.4982
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5793 | Val Avg. Loss: 0.7876
# Epoch [7/25] | Train Bal. Acc: 0.5312 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5847 | Val Avg. Loss: 0.7955
# Epoch [8/25] | Train Bal. Acc: 0.5854 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5724 | Val Avg. Loss: 0.8009
# Epoch [9/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5684 | Val Avg. Loss: 0.7962
# Epoch [10/25] | Train Bal. Acc: 0.6083 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5774 | Val Avg. Loss: 0.8199
# Epoch [11/25] | Train Bal. Acc: 0.6312 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5695 | Val Avg. Loss: 0.7938
# Epoch [12/25] | Train Bal. Acc: 0.6302 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5631 | Val Avg. Loss: 0.8029
# Epoch [13/25] | Train Bal. Acc: 0.6135 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5682 | Val Avg. Loss: 0.8167
# Epoch [14/25] | Train Bal. Acc: 0.6146 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5830 | Val Avg. Loss: 0.7697
# Epoch [15/25] | Train Bal. Acc: 0.6208 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5639 | Val Avg. Loss: 0.8134
# Epoch [16/25] | Train Bal. Acc: 0.6052 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5702 | Val Avg. Loss: 0.8423
# Epoch [17/25] | Train Bal. Acc: 0.6135 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5598 | Val Avg. Loss: 0.7917
# Epoch [18/25] | Train Bal. Acc: 0.6125 | Val Bal. Acc: 0.6434
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5718 | Val Avg. Loss: 0.7683
# Epoch [19/25] | Train Bal. Acc: 0.6344 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5731 | Val Avg. Loss: 0.7920
# Epoch [20/25] | Train Bal. Acc: 0.6500 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5787 | Val Avg. Loss: 0.8316
# Epoch [21/25] | Train Bal. Acc: 0.5875 | Val Bal. Acc: 0.5846
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5642 | Val Avg. Loss: 0.8113
# Epoch [22/25] | Train Bal. Acc: 0.6271 | Val Bal. Acc: 0.6140
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5667 | Val Avg. Loss: 0.7949
# Epoch [23/25] | Train Bal. Acc: 0.6115 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5728 | Val Avg. Loss: 0.7839
# Epoch [24/25] | Train Bal. Acc: 0.6188 | Val Bal. Acc: 0.6121
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5594 | Val Avg. Loss: 0.7965
# Epoch [25/25] | Train Bal. Acc: 0.6031 | Val Bal. Acc: 0.6140
# --------------------
# Bal. Accuracy: 0.475
# Avg. Loss:  0.671286404132843
# [[1 4]
#  [1 3]]
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6652 | Val Avg. Loss: 0.7338
# Epoch [1/25] | Train Bal. Acc: 0.4719 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6149 | Val Avg. Loss: 0.8498
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6012 | Val Avg. Loss: 0.9032
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5841 | Val Avg. Loss: 0.8890
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5697 | Val Avg. Loss: 0.8566
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5547 | Val Avg. Loss: 0.8981
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5394 | Val Avg. Loss: 0.9096
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5252 | Val Avg. Loss: 0.9123
# Epoch [8/25] | Train Bal. Acc: 0.5412 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5209 | Val Avg. Loss: 1.0241
# Epoch [9/25] | Train Bal. Acc: 0.5904 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5114 | Val Avg. Loss: 0.9840
# Epoch [10/25] | Train Bal. Acc: 0.5886 | Val Bal. Acc: 0.6106
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5271 | Val Avg. Loss: 0.8656
# Epoch [11/25] | Train Bal. Acc: 0.6281 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5134 | Val Avg. Loss: 0.9388
# Epoch [12/25] | Train Bal. Acc: 0.6860 | Val Bal. Acc: 0.6418
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5133 | Val Avg. Loss: 0.9921
# Epoch [13/25] | Train Bal. Acc: 0.6360 | Val Bal. Acc: 0.6418
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5069 | Val Avg. Loss: 0.9922
# Epoch [14/25] | Train Bal. Acc: 0.6114 | Val Bal. Acc: 0.6418
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5047 | Val Avg. Loss: 0.9206
# Epoch [15/25] | Train Bal. Acc: 0.6439 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5136 | Val Avg. Loss: 0.8953
# Epoch [16/25] | Train Bal. Acc: 0.6684 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5168 | Val Avg. Loss: 0.9519
# Epoch [17/25] | Train Bal. Acc: 0.6772 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5128 | Val Avg. Loss: 1.0101
# Epoch [18/25] | Train Bal. Acc: 0.6193 | Val Bal. Acc: 0.6418
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4901 | Val Avg. Loss: 1.0079
# Epoch [19/25] | Train Bal. Acc: 0.6360 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.4986 | Val Avg. Loss: 0.9934
# Epoch [20/25] | Train Bal. Acc: 0.6360 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5078 | Val Avg. Loss: 1.0015
# Epoch [21/25] | Train Bal. Acc: 0.6860 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4945 | Val Avg. Loss: 1.0223
# Epoch [22/25] | Train Bal. Acc: 0.6684 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4899 | Val Avg. Loss: 1.0692
# Epoch [23/25] | Train Bal. Acc: 0.6439 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5048 | Val Avg. Loss: 1.0619
# Epoch [24/25] | Train Bal. Acc: 0.6860 | Val Bal. Acc: 0.6731
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4846 | Val Avg. Loss: 1.0642
# Epoch [25/25] | Train Bal. Acc: 0.7105 | Val Bal. Acc: 0.6731
# --------------------
# Bal. Accuracy: 0.525
# Avg. Loss:  0.9878100819057889
# [[2 6]
#  [2 8]]
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7518 | Val Avg. Loss: 0.6410
# Epoch [1/25] | Train Bal. Acc: 0.3222 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.7017 | Val Avg. Loss: 0.6177
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6989 | Val Avg. Loss: 0.6199
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6980 | Val Avg. Loss: 0.6353
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6959 | Val Avg. Loss: 0.6579
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6921 | Val Avg. Loss: 0.6611
# Epoch [6/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6898 | Val Avg. Loss: 0.6662
# Epoch [7/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6902 | Val Avg. Loss: 0.6779
# Epoch [8/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6923 | Val Avg. Loss: 0.6881
# Epoch [9/25] | Train Bal. Acc: 0.4667 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6912 | Val Avg. Loss: 0.6935
# Epoch [10/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6908 | Val Avg. Loss: 0.6838
# Epoch [11/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6885 | Val Avg. Loss: 0.6860
# Epoch [12/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6899 | Val Avg. Loss: 0.6740
# Epoch [13/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6871 | Val Avg. Loss: 0.6731
# Epoch [14/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6858 | Val Avg. Loss: 0.6764
# Epoch [15/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6860 | Val Avg. Loss: 0.6756
# Epoch [16/25] | Train Bal. Acc: 0.6222 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6851 | Val Avg. Loss: 0.6759
# Epoch [17/25] | Train Bal. Acc: 0.6222 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6859 | Val Avg. Loss: 0.6817
# Epoch [18/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6837 | Val Avg. Loss: 0.6917
# Epoch [19/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6860 | Val Avg. Loss: 0.6882
# Epoch [20/25] | Train Bal. Acc: 0.5333 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6814 | Val Avg. Loss: 0.6774
# Epoch [21/25] | Train Bal. Acc: 0.6222 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6844 | Val Avg. Loss: 0.6758
# Epoch [22/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6763 | Val Avg. Loss: 0.6538
# Epoch [23/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6675 | Val Avg. Loss: 0.6251
# Epoch [24/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6661 | Val Avg. Loss: 0.6039
# Epoch [25/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4792
# --------------------
# Bal. Accuracy: 0.5363636363636364
# Avg. Loss:  0.6960505843162537
# [[4 1]
#  [8 3]]
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6972 | Val Avg. Loss: 0.6440
# Epoch [1/25] | Train Bal. Acc: 0.5647 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6817 | Val Avg. Loss: 0.7083
# Epoch [2/25] | Train Bal. Acc: 0.6273 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6962 | Val Avg. Loss: 0.7565
# Epoch [3/25] | Train Bal. Acc: 0.4679 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6940 | Val Avg. Loss: 0.7262
# Epoch [4/25] | Train Bal. Acc: 0.4785 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6878 | Val Avg. Loss: 0.6794
# Epoch [5/25] | Train Bal. Acc: 0.5249 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6865 | Val Avg. Loss: 0.6535
# Epoch [6/25] | Train Bal. Acc: 0.6164 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6856 | Val Avg. Loss: 0.6493
# Epoch [7/25] | Train Bal. Acc: 0.5621 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6807 | Val Avg. Loss: 0.6481
# Epoch [8/25] | Train Bal. Acc: 0.5952 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6869 | Val Avg. Loss: 0.6807
# Epoch [9/25] | Train Bal. Acc: 0.6155 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6792 | Val Avg. Loss: 0.6526
# Epoch [10/25] | Train Bal. Acc: 0.5942 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6816 | Val Avg. Loss: 0.6478
# Epoch [11/25] | Train Bal. Acc: 0.6164 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6821 | Val Avg. Loss: 0.6733
# Epoch [12/25] | Train Bal. Acc: 0.6261 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6780 | Val Avg. Loss: 0.6421
# Epoch [13/25] | Train Bal. Acc: 0.6048 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6762 | Val Avg. Loss: 0.6258
# Epoch [14/25] | Train Bal. Acc: 0.5729 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6804 | Val Avg. Loss: 0.6498
# Epoch [15/25] | Train Bal. Acc: 0.5614 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6728 | Val Avg. Loss: 0.6385
# Epoch [16/25] | Train Bal. Acc: 0.5940 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6760 | Val Avg. Loss: 0.6420
# Epoch [17/25] | Train Bal. Acc: 0.5944 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6777 | Val Avg. Loss: 0.6796
# Epoch [18/25] | Train Bal. Acc: 0.5713 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6762 | Val Avg. Loss: 0.6684
# Epoch [19/25] | Train Bal. Acc: 0.5597 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6751 | Val Avg. Loss: 0.5966
# Epoch [20/25] | Train Bal. Acc: 0.5833 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6850 | Val Avg. Loss: 0.6443
# Epoch [21/25] | Train Bal. Acc: 0.5616 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6709 | Val Avg. Loss: 0.6359
# Epoch [22/25] | Train Bal. Acc: 0.6162 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6713 | Val Avg. Loss: 0.6267
# Epoch [23/25] | Train Bal. Acc: 0.5725 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6681 | Val Avg. Loss: 0.6236
# Epoch [24/25] | Train Bal. Acc: 0.6167 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6686 | Val Avg. Loss: 0.6510
# Epoch [25/25] | Train Bal. Acc: 0.5944 | Val Bal. Acc: 0.5000
# --------------------
# Bal. Accuracy: 0.6590909090909092
# Avg. Loss:  0.584829568862915
# [[2 2]
#  [2 9]]
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6102 | Val Avg. Loss: 0.7918
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6070 | Val Avg. Loss: 0.8172
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.5840 | Val Avg. Loss: 0.7812
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.5820 | Val Avg. Loss: 0.7885
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5699 | Val Avg. Loss: 0.8428
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5936 | Val Avg. Loss: 0.8473
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5788 | Val Avg. Loss: 0.7799
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5741 | Val Avg. Loss: 0.7964
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5630 | Val Avg. Loss: 0.8181
# Epoch [9/25] | Train Bal. Acc: 0.5172 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5752 | Val Avg. Loss: 0.8020
# Epoch [10/25] | Train Bal. Acc: 0.5435 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5803 | Val Avg. Loss: 0.8347
# Epoch [11/25] | Train Bal. Acc: 0.5353 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5881 | Val Avg. Loss: 0.7832
# Epoch [12/25] | Train Bal. Acc: 0.5362 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5709 | Val Avg. Loss: 0.8098
# Epoch [13/25] | Train Bal. Acc: 0.6215 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5686 | Val Avg. Loss: 0.8270
# Epoch [14/25] | Train Bal. Acc: 0.5616 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5673 | Val Avg. Loss: 0.7904
# Epoch [15/25] | Train Bal. Acc: 0.5526 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5789 | Val Avg. Loss: 0.8096
# Epoch [16/25] | Train Bal. Acc: 0.5362 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5665 | Val Avg. Loss: 0.8407
# Epoch [17/25] | Train Bal. Acc: 0.5616 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5489 | Val Avg. Loss: 0.8224
# Epoch [18/25] | Train Bal. Acc: 0.5871 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5867 | Val Avg. Loss: 0.8168
# Epoch [19/25] | Train Bal. Acc: 0.5871 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5719 | Val Avg. Loss: 0.8071
# Epoch [20/25] | Train Bal. Acc: 0.6388 | Val Bal. Acc: 0.5257
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5633 | Val Avg. Loss: 0.7910
# Epoch [21/25] | Train Bal. Acc: 0.6215 | Val Bal. Acc: 0.5257
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5703 | Val Avg. Loss: 0.7996
# Epoch [22/25] | Train Bal. Acc: 0.5707 | Val Bal. Acc: 0.5257
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5676 | Val Avg. Loss: 0.8264
# Epoch [23/25] | Train Bal. Acc: 0.6133 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5653 | Val Avg. Loss: 0.7964
# Epoch [24/25] | Train Bal. Acc: 0.5879 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5611 | Val Avg. Loss: 0.7887
# Epoch [25/25] | Train Bal. Acc: 0.5888 | Val Bal. Acc: 0.5846
# --------------------
# Bal. Accuracy: 0.41666666666666663
# Avg. Loss:  0.7103399038314819
# [[4 4]
#  [2 1]]
# Accuracy (Balanced): 0.5631944444444444
# Avg. Loss: 0.7047653590542039
#               precision    recall  f1-score   support
#
#            0       0.50      0.39      0.44        54
#            1       0.64      0.74      0.69        80
#
#     accuracy                           0.60       134
#    macro avg       0.57      0.56      0.56       134
# weighted avg       0.58      0.60      0.59       134

# %% [markdown]
# # FULL EYEBROW RAISE

# %%
_ = attention_based_mil(df, ["AU01_r", "AU02_r", "AU05_r"])
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6944 | Val Avg. Loss: 0.6195
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6713 | Val Avg. Loss: 0.5979
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6627 | Val Avg. Loss: 0.5733
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6647 | Val Avg. Loss: 0.5833
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6638 | Val Avg. Loss: 0.6230
# Epoch [5/25] | Train Bal. Acc: 0.5119 | Val Bal. Acc: 0.4737
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6453 | Val Avg. Loss: 0.5783
# Epoch [6/25] | Train Bal. Acc: 0.5269 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6416 | Val Avg. Loss: 0.5514
# Epoch [7/25] | Train Bal. Acc: 0.5238 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6408 | Val Avg. Loss: 0.5565
# Epoch [8/25] | Train Bal. Acc: 0.5238 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6408 | Val Avg. Loss: 0.5698
# Epoch [9/25] | Train Bal. Acc: 0.5150 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6343 | Val Avg. Loss: 0.5753
# Epoch [10/25] | Train Bal. Acc: 0.5182 | Val Bal. Acc: 0.4737
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6405 | Val Avg. Loss: 0.5779
# Epoch [11/25] | Train Bal. Acc: 0.5125 | Val Bal. Acc: 0.4737
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6368 | Val Avg. Loss: 0.5894
# Epoch [12/25] | Train Bal. Acc: 0.5363 | Val Bal. Acc: 0.4737
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6361 | Val Avg. Loss: 0.6181
# Epoch [13/25] | Train Bal. Acc: 0.5909 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6410 | Val Avg. Loss: 0.5797
# Epoch [14/25] | Train Bal. Acc: 0.5652 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6258 | Val Avg. Loss: 0.5510
# Epoch [15/25] | Train Bal. Acc: 0.5940 | Val Bal. Acc: 0.5099
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6262 | Val Avg. Loss: 0.5476
# Epoch [16/25] | Train Bal. Acc: 0.6028 | Val Bal. Acc: 0.6612
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6442 | Val Avg. Loss: 0.5662
# Epoch [17/25] | Train Bal. Acc: 0.6065 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6280 | Val Avg. Loss: 0.5592
# Epoch [18/25] | Train Bal. Acc: 0.6096 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6269 | Val Avg. Loss: 0.5597
# Epoch [19/25] | Train Bal. Acc: 0.6247 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6323 | Val Avg. Loss: 0.5643
# Epoch [20/25] | Train Bal. Acc: 0.6222 | Val Bal. Acc: 0.6447
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6272 | Val Avg. Loss: 0.5727
# Epoch [21/25] | Train Bal. Acc: 0.6015 | Val Bal. Acc: 0.7072
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6316 | Val Avg. Loss: 0.5734
# Epoch [22/25] | Train Bal. Acc: 0.6316 | Val Bal. Acc: 0.7072
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6268 | Val Avg. Loss: 0.5622
# Epoch [23/25] | Train Bal. Acc: 0.6316 | Val Bal. Acc: 0.7072
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6241 | Val Avg. Loss: 0.5484
# Epoch [24/25] | Train Bal. Acc: 0.6516 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6447 | Val Avg. Loss: 0.5407
# Epoch [25/25] | Train Bal. Acc: 0.6209 | Val Bal. Acc: 0.6250
# --------------------
# Bal. Accuracy: 0.375
# Avg. Loss:  0.8397311568260193
# [[1 3]
#  [2 2]]
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7012 | Val Avg. Loss: 0.6774
# Epoch [1/25] | Train Bal. Acc: 0.5048 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6896 | Val Avg. Loss: 0.6470
# Epoch [2/25] | Train Bal. Acc: 0.5008 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6870 | Val Avg. Loss: 0.6291
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6843 | Val Avg. Loss: 0.6148
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6826 | Val Avg. Loss: 0.6069
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6811 | Val Avg. Loss: 0.5936
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6755 | Val Avg. Loss: 0.5905
# Epoch [7/25] | Train Bal. Acc: 0.5357 | Val Bal. Acc: 0.5884
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6655 | Val Avg. Loss: 0.5999
# Epoch [8/25] | Train Bal. Acc: 0.5746 | Val Bal. Acc: 0.6313
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6666 | Val Avg. Loss: 0.6126
# Epoch [9/25] | Train Bal. Acc: 0.6048 | Val Bal. Acc: 0.7197
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6664 | Val Avg. Loss: 0.5873
# Epoch [10/25] | Train Bal. Acc: 0.6508 | Val Bal. Acc: 0.6641
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6569 | Val Avg. Loss: 0.5890
# Epoch [11/25] | Train Bal. Acc: 0.6278 | Val Bal. Acc: 0.6641
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6550 | Val Avg. Loss: 0.5737
# Epoch [12/25] | Train Bal. Acc: 0.6397 | Val Bal. Acc: 0.6641
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6545 | Val Avg. Loss: 0.5699
# Epoch [13/25] | Train Bal. Acc: 0.6389 | Val Bal. Acc: 0.6641
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6628 | Val Avg. Loss: 0.5959
# Epoch [14/25] | Train Bal. Acc: 0.6183 | Val Bal. Acc: 0.6414
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6521 | Val Avg. Loss: 0.6110
# Epoch [15/25] | Train Bal. Acc: 0.6675 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6476 | Val Avg. Loss: 0.5936
# Epoch [16/25] | Train Bal. Acc: 0.6238 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6362 | Val Avg. Loss: 0.5656
# Epoch [17/25] | Train Bal. Acc: 0.7127 | Val Bal. Acc: 0.6641
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6429 | Val Avg. Loss: 0.5770
# Epoch [18/25] | Train Bal. Acc: 0.6540 | Val Bal. Acc: 0.6414
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6475 | Val Avg. Loss: 0.6189
# Epoch [19/25] | Train Bal. Acc: 0.6230 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6450 | Val Avg. Loss: 0.6127
# Epoch [20/25] | Train Bal. Acc: 0.6460 | Val Bal. Acc: 0.6843
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6473 | Val Avg. Loss: 0.5978
# Epoch [21/25] | Train Bal. Acc: 0.6810 | Val Bal. Acc: 0.6187
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6326 | Val Avg. Loss: 0.5882
# Epoch [22/25] | Train Bal. Acc: 0.6786 | Val Bal. Acc: 0.6742
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6259 | Val Avg. Loss: 0.6114
# Epoch [23/25] | Train Bal. Acc: 0.7357 | Val Bal. Acc: 0.6288
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6416 | Val Avg. Loss: 0.5973
# Epoch [24/25] | Train Bal. Acc: 0.6794 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6284 | Val Avg. Loss: 0.5976
# Epoch [25/25] | Train Bal. Acc: 0.7349 | Val Bal. Acc: 0.6515
# --------------------
# Bal. Accuracy: 0.5512820512820513
# Avg. Loss:  0.5693758726119995
# [[ 1  2]
#  [ 3 10]]
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6884 | Val Avg. Loss: 0.6526
# Epoch [1/25] | Train Bal. Acc: 0.5331 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6722 | Val Avg. Loss: 0.6230
# Epoch [2/25] | Train Bal. Acc: 0.6096 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6711 | Val Avg. Loss: 0.6037
# Epoch [3/25] | Train Bal. Acc: 0.5770 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6515 | Val Avg. Loss: 0.6336
# Epoch [4/25] | Train Bal. Acc: 0.6110 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6624 | Val Avg. Loss: 0.6596
# Epoch [5/25] | Train Bal. Acc: 0.6268 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6437 | Val Avg. Loss: 0.6313
# Epoch [6/25] | Train Bal. Acc: 0.6386 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6461 | Val Avg. Loss: 0.6179
# Epoch [7/25] | Train Bal. Acc: 0.6784 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6263 | Val Avg. Loss: 0.6245
# Epoch [8/25] | Train Bal. Acc: 0.6902 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6311 | Val Avg. Loss: 0.6514
# Epoch [9/25] | Train Bal. Acc: 0.6698 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6477 | Val Avg. Loss: 0.6909
# Epoch [10/25] | Train Bal. Acc: 0.6300 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6286 | Val Avg. Loss: 0.6658
# Epoch [11/25] | Train Bal. Acc: 0.6096 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6370 | Val Avg. Loss: 0.6380
# Epoch [12/25] | Train Bal. Acc: 0.5978 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6264 | Val Avg. Loss: 0.6446
# Epoch [13/25] | Train Bal. Acc: 0.6499 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6365 | Val Avg. Loss: 0.6394
# Epoch [14/25] | Train Bal. Acc: 0.6490 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6312 | Val Avg. Loss: 0.6794
# Epoch [15/25] | Train Bal. Acc: 0.6168 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6264 | Val Avg. Loss: 0.6734
# Epoch [16/25] | Train Bal. Acc: 0.6517 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6228 | Val Avg. Loss: 0.6470
# Epoch [17/25] | Train Bal. Acc: 0.6291 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6374 | Val Avg. Loss: 0.6482
# Epoch [18/25] | Train Bal. Acc: 0.6386 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6311 | Val Avg. Loss: 0.6867
# Epoch [19/25] | Train Bal. Acc: 0.6599 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6304 | Val Avg. Loss: 0.6704
# Epoch [20/25] | Train Bal. Acc: 0.6617 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6121 | Val Avg. Loss: 0.6697
# Epoch [21/25] | Train Bal. Acc: 0.6612 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6189 | Val Avg. Loss: 0.6488
# Epoch [22/25] | Train Bal. Acc: 0.6703 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6233 | Val Avg. Loss: 0.6605
# Epoch [23/25] | Train Bal. Acc: 0.6911 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6227 | Val Avg. Loss: 0.6688
# Epoch [24/25] | Train Bal. Acc: 0.6707 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6286 | Val Avg. Loss: 0.6752
# Epoch [25/25] | Train Bal. Acc: 0.6291 | Val Bal. Acc: 0.4762
# --------------------
# Bal. Accuracy: 0.2727272727272727
# Avg. Loss:  0.5948225855827332
# [[0 1]
#  [5 6]]
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6956 | Val Avg. Loss: 0.5980
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6881 | Val Avg. Loss: 0.6156
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6895 | Val Avg. Loss: 0.5917
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6739 | Val Avg. Loss: 0.5879
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6690 | Val Avg. Loss: 0.5713
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6755 | Val Avg. Loss: 0.6132
# Epoch [6/25] | Train Bal. Acc: 0.4900 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6566 | Val Avg. Loss: 0.5805
# Epoch [7/25] | Train Bal. Acc: 0.5341 | Val Bal. Acc: 0.4773
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6513 | Val Avg. Loss: 0.5595
# Epoch [8/25] | Train Bal. Acc: 0.5723 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6424 | Val Avg. Loss: 0.5575
# Epoch [9/25] | Train Bal. Acc: 0.5723 | Val Bal. Acc: 0.6212
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6392 | Val Avg. Loss: 0.5762
# Epoch [10/25] | Train Bal. Acc: 0.6191 | Val Bal. Acc: 0.5530
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6361 | Val Avg. Loss: 0.5716
# Epoch [11/25] | Train Bal. Acc: 0.6159 | Val Bal. Acc: 0.5530
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6374 | Val Avg. Loss: 0.5831
# Epoch [12/25] | Train Bal. Acc: 0.6286 | Val Bal. Acc: 0.5076
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6239 | Val Avg. Loss: 0.5858
# Epoch [13/25] | Train Bal. Acc: 0.6541 | Val Bal. Acc: 0.4848
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6197 | Val Avg. Loss: 0.5695
# Epoch [14/25] | Train Bal. Acc: 0.6541 | Val Bal. Acc: 0.4848
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6057 | Val Avg. Loss: 0.5680
# Epoch [15/25] | Train Bal. Acc: 0.6882 | Val Bal. Acc: 0.4848
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6193 | Val Avg. Loss: 0.5553
# Epoch [16/25] | Train Bal. Acc: 0.6368 | Val Bal. Acc: 0.4848
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5999 | Val Avg. Loss: 0.5465
# Epoch [17/25] | Train Bal. Acc: 0.7223 | Val Bal. Acc: 0.4848
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6148 | Val Avg. Loss: 0.5367
# Epoch [18/25] | Train Bal. Acc: 0.6909 | Val Bal. Acc: 0.4848
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6149 | Val Avg. Loss: 0.6035
# Epoch [19/25] | Train Bal. Acc: 0.6582 | Val Bal. Acc: 0.6515
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5932 | Val Avg. Loss: 0.5796
# Epoch [20/25] | Train Bal. Acc: 0.7177 | Val Bal. Acc: 0.5682
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6144 | Val Avg. Loss: 0.5407
# Epoch [21/25] | Train Bal. Acc: 0.7023 | Val Bal. Acc: 0.5682
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6110 | Val Avg. Loss: 0.5654
# Epoch [22/25] | Train Bal. Acc: 0.6895 | Val Bal. Acc: 0.5682
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6098 | Val Avg. Loss: 0.5773
# Epoch [23/25] | Train Bal. Acc: 0.6655 | Val Bal. Acc: 0.5682
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6074 | Val Avg. Loss: 0.5885
# Epoch [24/25] | Train Bal. Acc: 0.6709 | Val Bal. Acc: 0.5682
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6063 | Val Avg. Loss: 0.5695
# Epoch [25/25] | Train Bal. Acc: 0.6709 | Val Bal. Acc: 0.5909
# --------------------
# Bal. Accuracy: 0.6875
# Avg. Loss:  0.5788611769676208
# [[3 1]
#  [3 5]]
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6649 | Val Avg. Loss: 0.5555
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6320 | Val Avg. Loss: 0.5230
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6293 | Val Avg. Loss: 0.5414
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6213 | Val Avg. Loss: 0.5323
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6151 | Val Avg. Loss: 0.5327
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6096 | Val Avg. Loss: 0.5115
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6062 | Val Avg. Loss: 0.5007
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6161 | Val Avg. Loss: 0.4950
# Epoch [8/25] | Train Bal. Acc: 0.5147 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6041 | Val Avg. Loss: 0.5048
# Epoch [9/25] | Train Bal. Acc: 0.5058 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5991 | Val Avg. Loss: 0.4903
# Epoch [10/25] | Train Bal. Acc: 0.5441 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6034 | Val Avg. Loss: 0.4728
# Epoch [11/25] | Train Bal. Acc: 0.5320 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5926 | Val Avg. Loss: 0.4736
# Epoch [12/25] | Train Bal. Acc: 0.5378 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5918 | Val Avg. Loss: 0.4655
# Epoch [13/25] | Train Bal. Acc: 0.5641 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5900 | Val Avg. Loss: 0.4826
# Epoch [14/25] | Train Bal. Acc: 0.5846 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5968 | Val Avg. Loss: 0.4428
# Epoch [15/25] | Train Bal. Acc: 0.6287 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5800 | Val Avg. Loss: 0.4469
# Epoch [16/25] | Train Bal. Acc: 0.5935 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6159 | Val Avg. Loss: 0.4890
# Epoch [17/25] | Train Bal. Acc: 0.6166 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5805 | Val Avg. Loss: 0.4470
# Epoch [18/25] | Train Bal. Acc: 0.6518 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6059 | Val Avg. Loss: 0.4251
# Epoch [19/25] | Train Bal. Acc: 0.6229 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5857 | Val Avg. Loss: 0.4605
# Epoch [20/25] | Train Bal. Acc: 0.5840 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5770 | Val Avg. Loss: 0.4405
# Epoch [21/25] | Train Bal. Acc: 0.6192 | Val Bal. Acc: 0.7237
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5737 | Val Avg. Loss: 0.4266
# Epoch [22/25] | Train Bal. Acc: 0.6224 | Val Bal. Acc: 0.7237
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5819 | Val Avg. Loss: 0.4377
# Epoch [23/25] | Train Bal. Acc: 0.6077 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5617 | Val Avg. Loss: 0.4341
# Epoch [24/25] | Train Bal. Acc: 0.6576 | Val Bal. Acc: 0.7862
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5780 | Val Avg. Loss: 0.4318
# Epoch [25/25] | Train Bal. Acc: 0.6754 | Val Bal. Acc: 0.7862
# --------------------
# Bal. Accuracy: 0.625
# Avg. Loss:  0.8464570431148305
# [[3 9]
#  [0 5]]
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7008 | Val Avg. Loss: 0.7005
# Epoch [1/25] | Train Bal. Acc: 0.4010 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6161 | Val Avg. Loss: 0.7288
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6075 | Val Avg. Loss: 0.8243
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6107 | Val Avg. Loss: 0.8218
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6012 | Val Avg. Loss: 0.7568
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5951 | Val Avg. Loss: 0.7448
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5895 | Val Avg. Loss: 0.7592
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5853 | Val Avg. Loss: 0.7779
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5666 | Val Avg. Loss: 0.7896
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5809 | Val Avg. Loss: 0.7744
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5664 | Val Avg. Loss: 0.7823
# Epoch [11/25] | Train Bal. Acc: 0.5312 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5810 | Val Avg. Loss: 0.7526
# Epoch [12/25] | Train Bal. Acc: 0.5219 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5644 | Val Avg. Loss: 0.7824
# Epoch [13/25] | Train Bal. Acc: 0.5542 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5777 | Val Avg. Loss: 0.7930
# Epoch [14/25] | Train Bal. Acc: 0.5687 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5764 | Val Avg. Loss: 0.7332
# Epoch [15/25] | Train Bal. Acc: 0.6229 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5642 | Val Avg. Loss: 0.7760
# Epoch [16/25] | Train Bal. Acc: 0.6448 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5669 | Val Avg. Loss: 0.8094
# Epoch [17/25] | Train Bal. Acc: 0.6385 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5567 | Val Avg. Loss: 0.7550
# Epoch [18/25] | Train Bal. Acc: 0.6292 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5583 | Val Avg. Loss: 0.7395
# Epoch [19/25] | Train Bal. Acc: 0.6833 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5502 | Val Avg. Loss: 0.7917
# Epoch [20/25] | Train Bal. Acc: 0.6510 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5480 | Val Avg. Loss: 0.8262
# Epoch [21/25] | Train Bal. Acc: 0.6604 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5483 | Val Avg. Loss: 0.7566
# Epoch [22/25] | Train Bal. Acc: 0.6687 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5418 | Val Avg. Loss: 0.7481
# Epoch [23/25] | Train Bal. Acc: 0.7146 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5619 | Val Avg. Loss: 0.7739
# Epoch [24/25] | Train Bal. Acc: 0.6896 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5477 | Val Avg. Loss: 0.7997
# Epoch [25/25] | Train Bal. Acc: 0.6521 | Val Bal. Acc: 0.5864
# --------------------
# Bal. Accuracy: 0.6
# Avg. Loss:  0.6558240056037903
# [[1 4]
#  [0 4]]
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7329 | Val Avg. Loss: 0.7134
# Epoch [1/25] | Train Bal. Acc: 0.4675 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6572 | Val Avg. Loss: 0.7489
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6461 | Val Avg. Loss: 0.7837
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6410 | Val Avg. Loss: 0.8020
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6395 | Val Avg. Loss: 0.8086
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6358 | Val Avg. Loss: 0.8145
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6287 | Val Avg. Loss: 0.8125
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6199 | Val Avg. Loss: 0.8214
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6111 | Val Avg. Loss: 0.8790
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5936 | Val Avg. Loss: 0.8905
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5912 | Val Avg. Loss: 0.8437
# Epoch [11/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5776 | Val Avg. Loss: 0.9014
# Epoch [12/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5586 | Val Avg. Loss: 0.9343
# Epoch [13/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5572 | Val Avg. Loss: 0.9553
# Epoch [14/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5413 | Val Avg. Loss: 0.8918
# Epoch [15/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5237 | Val Avg. Loss: 0.8740
# Epoch [16/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5178 | Val Avg. Loss: 0.9697
# Epoch [17/25] | Train Bal. Acc: 0.5579 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5111 | Val Avg. Loss: 1.0089
# Epoch [18/25] | Train Bal. Acc: 0.5649 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.4975 | Val Avg. Loss: 0.9650
# Epoch [19/25] | Train Bal. Acc: 0.5982 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5078 | Val Avg. Loss: 0.8949
# Epoch [20/25] | Train Bal. Acc: 0.5956 | Val Bal. Acc: 0.6178
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.4857 | Val Avg. Loss: 0.9215
# Epoch [21/25] | Train Bal. Acc: 0.6377 | Val Bal. Acc: 0.6178
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.4966 | Val Avg. Loss: 0.9300
# Epoch [22/25] | Train Bal. Acc: 0.6202 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.4919 | Val Avg. Loss: 1.0163
# Epoch [23/25] | Train Bal. Acc: 0.6202 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.4787 | Val Avg. Loss: 0.9653
# Epoch [24/25] | Train Bal. Acc: 0.6289 | Val Bal. Acc: 0.6490
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4857 | Val Avg. Loss: 0.9275
# Epoch [25/25] | Train Bal. Acc: 0.6605 | Val Bal. Acc: 0.6490
# --------------------
# Bal. Accuracy: 0.575
# Avg. Loss:  1.1004370583428278
# [[2 6]
#  [1 9]]
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6942 | Val Avg. Loss: 0.6290
# Epoch [1/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6828 | Val Avg. Loss: 0.5837
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6732 | Val Avg. Loss: 0.5484
# Epoch [3/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6633 | Val Avg. Loss: 0.5651
# Epoch [4/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6602 | Val Avg. Loss: 0.6118
# Epoch [5/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6414 | Val Avg. Loss: 0.5858
# Epoch [6/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.4792
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6368 | Val Avg. Loss: 0.5842
# Epoch [7/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6492 | Val Avg. Loss: 0.6325
# Epoch [8/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6368 | Val Avg. Loss: 0.6579
# Epoch [9/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6352 | Val Avg. Loss: 0.6472
# Epoch [10/25] | Train Bal. Acc: 0.6222 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6261 | Val Avg. Loss: 0.5940
# Epoch [11/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6342 | Val Avg. Loss: 0.6433
# Epoch [12/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6320 | Val Avg. Loss: 0.6216
# Epoch [13/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6263 | Val Avg. Loss: 0.6034
# Epoch [14/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.4583
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6332 | Val Avg. Loss: 0.6119
# Epoch [15/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6140 | Val Avg. Loss: 0.6301
# Epoch [16/25] | Train Bal. Acc: 0.6778 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6168 | Val Avg. Loss: 0.5985
# Epoch [17/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6164 | Val Avg. Loss: 0.6053
# Epoch [18/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6074 | Val Avg. Loss: 0.6404
# Epoch [19/25] | Train Bal. Acc: 0.6222 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6118 | Val Avg. Loss: 0.5491
# Epoch [20/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6110 | Val Avg. Loss: 0.5687
# Epoch [21/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5898 | Val Avg. Loss: 0.6109
# Epoch [22/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5879 | Val Avg. Loss: 0.6067
# Epoch [23/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6168 | Val Avg. Loss: 0.5947
# Epoch [24/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5827 | Val Avg. Loss: 0.5760
# Epoch [25/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.6042
# --------------------
# Bal. Accuracy: 0.42727272727272725
# Avg. Loss:  0.7371877431869507
# [[2 3]
#  [6 5]]
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7121 | Val Avg. Loss: 0.5915
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6969 | Val Avg. Loss: 0.6252
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6979 | Val Avg. Loss: 0.6782
# Epoch [3/25] | Train Bal. Acc: 0.4889 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6955 | Val Avg. Loss: 0.6877
# Epoch [4/25] | Train Bal. Acc: 0.5092 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6929 | Val Avg. Loss: 0.6804
# Epoch [5/25] | Train Bal. Acc: 0.5413 | Val Bal. Acc: 0.8125
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6913 | Val Avg. Loss: 0.6672
# Epoch [6/25] | Train Bal. Acc: 0.5638 | Val Bal. Acc: 0.7708
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6906 | Val Avg. Loss: 0.6371
# Epoch [7/25] | Train Bal. Acc: 0.5758 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6887 | Val Avg. Loss: 0.6171
# Epoch [8/25] | Train Bal. Acc: 0.5758 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6949 | Val Avg. Loss: 0.6746
# Epoch [9/25] | Train Bal. Acc: 0.5179 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6829 | Val Avg. Loss: 0.6171
# Epoch [10/25] | Train Bal. Acc: 0.6604 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6825 | Val Avg. Loss: 0.5688
# Epoch [11/25] | Train Bal. Acc: 0.6401 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6839 | Val Avg. Loss: 0.6138
# Epoch [12/25] | Train Bal. Acc: 0.6171 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6815 | Val Avg. Loss: 0.5820
# Epoch [13/25] | Train Bal. Acc: 0.6389 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6786 | Val Avg. Loss: 0.5512
# Epoch [14/25] | Train Bal. Acc: 0.6616 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6736 | Val Avg. Loss: 0.5619
# Epoch [15/25] | Train Bal. Acc: 0.6824 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6658 | Val Avg. Loss: 0.5058
# Epoch [16/25] | Train Bal. Acc: 0.7046 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6661 | Val Avg. Loss: 0.5303
# Epoch [17/25] | Train Bal. Acc: 0.6391 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6733 | Val Avg. Loss: 0.6007
# Epoch [18/25] | Train Bal. Acc: 0.6486 | Val Bal. Acc: 0.8333
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6557 | Val Avg. Loss: 0.5595
# Epoch [19/25] | Train Bal. Acc: 0.6469 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6712 | Val Avg. Loss: 0.4758
# Epoch [20/25] | Train Bal. Acc: 0.6495 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6900 | Val Avg. Loss: 0.5727
# Epoch [21/25] | Train Bal. Acc: 0.6048 | Val Bal. Acc: 0.8333
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6501 | Val Avg. Loss: 0.5394
# Epoch [22/25] | Train Bal. Acc: 0.6703 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6351 | Val Avg. Loss: 0.5278
# Epoch [23/25] | Train Bal. Acc: 0.6807 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6550 | Val Avg. Loss: 0.5169
# Epoch [24/25] | Train Bal. Acc: 0.6710 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6540 | Val Avg. Loss: 0.5804
# Epoch [25/25] | Train Bal. Acc: 0.6266 | Val Bal. Acc: 0.7292
# --------------------
# Bal. Accuracy: 0.7386363636363636
# Avg. Loss:  0.5921536087989807
# [[3 1]
#  [3 8]]
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6816 | Val Avg. Loss: 0.7179
# Epoch [1/25] | Train Bal. Acc: 0.4124 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6087 | Val Avg. Loss: 0.8059
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6110 | Val Avg. Loss: 0.8322
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6044 | Val Avg. Loss: 0.7875
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5951 | Val Avg. Loss: 0.7953
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5937 | Val Avg. Loss: 0.8283
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5958 | Val Avg. Loss: 0.7868
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5981 | Val Avg. Loss: 0.7942
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5929 | Val Avg. Loss: 0.7952
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5919 | Val Avg. Loss: 0.7764
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6004 | Val Avg. Loss: 0.8431
# Epoch [11/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5872 | Val Avg. Loss: 0.8002
# Epoch [12/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5902 | Val Avg. Loss: 0.8348
# Epoch [13/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5782 | Val Avg. Loss: 0.8354
# Epoch [14/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5715 | Val Avg. Loss: 0.8108
# Epoch [15/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5703 | Val Avg. Loss: 0.8381
# Epoch [16/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5794 | Val Avg. Loss: 0.8317
# Epoch [17/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5698 | Val Avg. Loss: 0.7901
# Epoch [18/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5667 | Val Avg. Loss: 0.7948
# Epoch [19/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5655 | Val Avg. Loss: 0.7999
# Epoch [20/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5521 | Val Avg. Loss: 0.8230
# Epoch [21/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.4688
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5537 | Val Avg. Loss: 0.8038
# Epoch [22/25] | Train Bal. Acc: 0.5090 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5489 | Val Avg. Loss: 0.7980
# Epoch [23/25] | Train Bal. Acc: 0.5690 | Val Bal. Acc: 0.5864
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5460 | Val Avg. Loss: 0.7917
# Epoch [24/25] | Train Bal. Acc: 0.5961 | Val Bal. Acc: 0.6158
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5268 | Val Avg. Loss: 0.8276
# Epoch [25/25] | Train Bal. Acc: 0.6133 | Val Bal. Acc: 0.6158
# --------------------
# Bal. Accuracy: 0.4375
# Avg. Loss:  0.690666913986206
# [[7 1]
#  [3 0]]
# Accuracy (Balanced): 0.5504629629629629
# Avg. Loss: 0.7205517165021958
#               precision    recall  f1-score   support
#
#            0       0.47      0.43      0.45        54
#            1       0.64      0.68      0.65        80
#
#     accuracy                           0.57       134
#    macro avg       0.55      0.55      0.55       134
# weighted avg       0.57      0.57      0.57       134

# %% [markdown]
# # ANGER

# %%
_ = attention_based_mil(df, ["AU04_r", "AU07_r","AU09_r"])
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6822 | Val Avg. Loss: 0.6298
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6648 | Val Avg. Loss: 0.6322
# Epoch [2/25] | Train Bal. Acc: 0.5388 | Val Bal. Acc: 0.5362
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6600 | Val Avg. Loss: 0.6185
# Epoch [3/25] | Train Bal. Acc: 0.5301 | Val Bal. Acc: 0.5362
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6563 | Val Avg. Loss: 0.6342
# Epoch [4/25] | Train Bal. Acc: 0.5213 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6598 | Val Avg. Loss: 0.6545
# Epoch [5/25] | Train Bal. Acc: 0.5482 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6544 | Val Avg. Loss: 0.6429
# Epoch [6/25] | Train Bal. Acc: 0.5545 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6500 | Val Avg. Loss: 0.6108
# Epoch [7/25] | Train Bal. Acc: 0.5689 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6510 | Val Avg. Loss: 0.6057
# Epoch [8/25] | Train Bal. Acc: 0.5213 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6601 | Val Avg. Loss: 0.5888
# Epoch [9/25] | Train Bal. Acc: 0.5213 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6526 | Val Avg. Loss: 0.6122
# Epoch [10/25] | Train Bal. Acc: 0.5363 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6468 | Val Avg. Loss: 0.6337
# Epoch [11/25] | Train Bal. Acc: 0.5514 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6412 | Val Avg. Loss: 0.6562
# Epoch [12/25] | Train Bal. Acc: 0.5370 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6422 | Val Avg. Loss: 0.6610
# Epoch [13/25] | Train Bal. Acc: 0.5551 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6393 | Val Avg. Loss: 0.6305
# Epoch [14/25] | Train Bal. Acc: 0.5846 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6370 | Val Avg. Loss: 0.6109
# Epoch [15/25] | Train Bal. Acc: 0.5752 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6331 | Val Avg. Loss: 0.6030
# Epoch [16/25] | Train Bal. Acc: 0.5276 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6373 | Val Avg. Loss: 0.5916
# Epoch [17/25] | Train Bal. Acc: 0.5307 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6360 | Val Avg. Loss: 0.6117
# Epoch [18/25] | Train Bal. Acc: 0.5100 | Val Bal. Acc: 0.6349
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6224 | Val Avg. Loss: 0.6281
# Epoch [19/25] | Train Bal. Acc: 0.5576 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6341 | Val Avg. Loss: 0.6272
# Epoch [20/25] | Train Bal. Acc: 0.5401 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.6655
# Epoch [21/25] | Train Bal. Acc: 0.5645 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6185 | Val Avg. Loss: 0.6327
# Epoch [22/25] | Train Bal. Acc: 0.5764 | Val Bal. Acc: 0.5822
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6151 | Val Avg. Loss: 0.5910
# Epoch [23/25] | Train Bal. Acc: 0.5520 | Val Bal. Acc: 0.5724
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6098 | Val Avg. Loss: 0.6050
# Epoch [24/25] | Train Bal. Acc: 0.5608 | Val Bal. Acc: 0.5197
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6454 | Val Avg. Loss: 0.6269
# Epoch [25/25] | Train Bal. Acc: 0.5514 | Val Bal. Acc: 0.5822
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6679907441139221
# [[0 4]
#  [0 4]]
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7047 | Val Avg. Loss: 0.7356
# Epoch [1/25] | Train Bal. Acc: 0.4754 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6837 | Val Avg. Loss: 0.7134
# Epoch [2/25] | Train Bal. Acc: 0.5706 | Val Bal. Acc: 0.4116
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6726 | Val Avg. Loss: 0.7081
# Epoch [3/25] | Train Bal. Acc: 0.6746 | Val Bal. Acc: 0.5253
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6648 | Val Avg. Loss: 0.7150
# Epoch [4/25] | Train Bal. Acc: 0.6341 | Val Bal. Acc: 0.5253
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6602 | Val Avg. Loss: 0.7297
# Epoch [5/25] | Train Bal. Acc: 0.5770 | Val Bal. Acc: 0.4798
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6535 | Val Avg. Loss: 0.7481
# Epoch [6/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.4798
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6451 | Val Avg. Loss: 0.7651
# Epoch [7/25] | Train Bal. Acc: 0.5770 | Val Bal. Acc: 0.4798
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6329 | Val Avg. Loss: 0.8080
# Epoch [8/25] | Train Bal. Acc: 0.5913 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6243 | Val Avg. Loss: 0.8446
# Epoch [9/25] | Train Bal. Acc: 0.6524 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6145 | Val Avg. Loss: 0.8603
# Epoch [10/25] | Train Bal. Acc: 0.6746 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6118 | Val Avg. Loss: 0.8975
# Epoch [11/25] | Train Bal. Acc: 0.6516 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6008 | Val Avg. Loss: 0.8945
# Epoch [12/25] | Train Bal. Acc: 0.6754 | Val Bal. Acc: 0.5126
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5960 | Val Avg. Loss: 0.8870
# Epoch [13/25] | Train Bal. Acc: 0.6381 | Val Bal. Acc: 0.5025
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5839 | Val Avg. Loss: 0.9201
# Epoch [14/25] | Train Bal. Acc: 0.6389 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5705 | Val Avg. Loss: 1.1257
# Epoch [15/25] | Train Bal. Acc: 0.6754 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5912 | Val Avg. Loss: 1.0427
# Epoch [16/25] | Train Bal. Acc: 0.6794 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5579 | Val Avg. Loss: 0.9538
# Epoch [17/25] | Train Bal. Acc: 0.6841 | Val Bal. Acc: 0.4242
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5576 | Val Avg. Loss: 1.0586
# Epoch [18/25] | Train Bal. Acc: 0.6857 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5497 | Val Avg. Loss: 1.1641
# Epoch [19/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5443 | Val Avg. Loss: 1.1112
# Epoch [20/25] | Train Bal. Acc: 0.7222 | Val Bal. Acc: 0.4899
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5371 | Val Avg. Loss: 1.1052
# Epoch [21/25] | Train Bal. Acc: 0.7095 | Val Bal. Acc: 0.4571
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5303 | Val Avg. Loss: 1.1665
# Epoch [22/25] | Train Bal. Acc: 0.7437 | Val Bal. Acc: 0.4343
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5310 | Val Avg. Loss: 1.2177
# Epoch [23/25] | Train Bal. Acc: 0.7333 | Val Bal. Acc: 0.4343
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5163 | Val Avg. Loss: 1.2954
# Epoch [24/25] | Train Bal. Acc: 0.7690 | Val Bal. Acc: 0.4343
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5158 | Val Avg. Loss: 1.2257
# Epoch [25/25] | Train Bal. Acc: 0.7556 | Val Bal. Acc: 0.4571
# --------------------
# Bal. Accuracy: 0.5512820512820513
# Avg. Loss:  0.6738128066062927
# [[ 1  2]
#  [ 3 10]]
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6938 | Val Avg. Loss: 0.6647
# Epoch [1/25] | Train Bal. Acc: 0.5113 | Val Bal. Acc: 0.5952
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6777 | Val Avg. Loss: 0.6390
# Epoch [2/25] | Train Bal. Acc: 0.5888 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6751 | Val Avg. Loss: 0.6153
# Epoch [3/25] | Train Bal. Acc: 0.6110 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6652 | Val Avg. Loss: 0.6334
# Epoch [4/25] | Train Bal. Acc: 0.6449 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6728 | Val Avg. Loss: 0.6466
# Epoch [5/25] | Train Bal. Acc: 0.6467 | Val Bal. Acc: 0.5952
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6592 | Val Avg. Loss: 0.6489
# Epoch [6/25] | Train Bal. Acc: 0.5851 | Val Bal. Acc: 0.5952
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6575 | Val Avg. Loss: 0.6303
# Epoch [7/25] | Train Bal. Acc: 0.6273 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6516 | Val Avg. Loss: 0.6215
# Epoch [8/25] | Train Bal. Acc: 0.6155 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6629 | Val Avg. Loss: 0.6405
# Epoch [9/25] | Train Bal. Acc: 0.6055 | Val Bal. Acc: 0.5952
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6565 | Val Avg. Loss: 0.6519
# Epoch [10/25] | Train Bal. Acc: 0.6277 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6473 | Val Avg. Loss: 0.6343
# Epoch [11/25] | Train Bal. Acc: 0.6282 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6531 | Val Avg. Loss: 0.6304
# Epoch [12/25] | Train Bal. Acc: 0.5856 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6473 | Val Avg. Loss: 0.6222
# Epoch [13/25] | Train Bal. Acc: 0.6585 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6409 | Val Avg. Loss: 0.6118
# Epoch [14/25] | Train Bal. Acc: 0.6476 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6399 | Val Avg. Loss: 0.6126
# Epoch [15/25] | Train Bal. Acc: 0.6051 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6335 | Val Avg. Loss: 0.6218
# Epoch [16/25] | Train Bal. Acc: 0.6377 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6422 | Val Avg. Loss: 0.6180
# Epoch [17/25] | Train Bal. Acc: 0.5838 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6350 | Val Avg. Loss: 0.6240
# Epoch [18/25] | Train Bal. Acc: 0.6055 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6369 | Val Avg. Loss: 0.6250
# Epoch [19/25] | Train Bal. Acc: 0.6277 | Val Bal. Acc: 0.6905
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6308 | Val Avg. Loss: 0.6090
# Epoch [20/25] | Train Bal. Acc: 0.6051 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6374 | Val Avg. Loss: 0.6282
# Epoch [21/25] | Train Bal. Acc: 0.5951 | Val Bal. Acc: 0.6429
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6362 | Val Avg. Loss: 0.6184
# Epoch [22/25] | Train Bal. Acc: 0.6386 | Val Bal. Acc: 0.6905
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6325 | Val Avg. Loss: 0.6032
# Epoch [23/25] | Train Bal. Acc: 0.6164 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6349 | Val Avg. Loss: 0.6050
# Epoch [24/25] | Train Bal. Acc: 0.6259 | Val Bal. Acc: 0.6190
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6476 | Val Avg. Loss: 0.6139
# Epoch [25/25] | Train Bal. Acc: 0.6064 | Val Bal. Acc: 0.6905
# --------------------
# Bal. Accuracy: 0.4090909090909091
# Avg. Loss:  0.6480951905250549
# [[0 1]
#  [2 9]]
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6891 | Val Avg. Loss: 0.6152
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6767 | Val Avg. Loss: 0.6250
# Epoch [2/25] | Train Bal. Acc: 0.5341 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6689 | Val Avg. Loss: 0.6301
# Epoch [3/25] | Train Bal. Acc: 0.5455 | Val Bal. Acc: 0.4773
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6565 | Val Avg. Loss: 0.6359
# Epoch [4/25] | Train Bal. Acc: 0.5795 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6419 | Val Avg. Loss: 0.6428
# Epoch [5/25] | Train Bal. Acc: 0.5736 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6404 | Val Avg. Loss: 0.6557
# Epoch [6/25] | Train Bal. Acc: 0.5905 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6347 | Val Avg. Loss: 0.6456
# Epoch [7/25] | Train Bal. Acc: 0.6245 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6130 | Val Avg. Loss: 0.6459
# Epoch [8/25] | Train Bal. Acc: 0.6145 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6227 | Val Avg. Loss: 0.6508
# Epoch [9/25] | Train Bal. Acc: 0.6500 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6157 | Val Avg. Loss: 0.6546
# Epoch [10/25] | Train Bal. Acc: 0.6500 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6135 | Val Avg. Loss: 0.6539
# Epoch [11/25] | Train Bal. Acc: 0.6400 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5962 | Val Avg. Loss: 0.6653
# Epoch [12/25] | Train Bal. Acc: 0.6614 | Val Bal. Acc: 0.4697
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5989 | Val Avg. Loss: 0.6768
# Epoch [13/25] | Train Bal. Acc: 0.6995 | Val Bal. Acc: 0.5076
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6084 | Val Avg. Loss: 0.6726
# Epoch [14/25] | Train Bal. Acc: 0.6995 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5992 | Val Avg. Loss: 0.6756
# Epoch [15/25] | Train Bal. Acc: 0.7209 | Val Bal. Acc: 0.5303
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5929 | Val Avg. Loss: 0.6744
# Epoch [16/25] | Train Bal. Acc: 0.7223 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5801 | Val Avg. Loss: 0.6709
# Epoch [17/25] | Train Bal. Acc: 0.7209 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5938 | Val Avg. Loss: 0.6701
# Epoch [18/25] | Train Bal. Acc: 0.6782 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5830 | Val Avg. Loss: 0.6790
# Epoch [19/25] | Train Bal. Acc: 0.7223 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5817 | Val Avg. Loss: 0.6790
# Epoch [20/25] | Train Bal. Acc: 0.7009 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5823 | Val Avg. Loss: 0.6755
# Epoch [21/25] | Train Bal. Acc: 0.7109 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5757 | Val Avg. Loss: 0.6761
# Epoch [22/25] | Train Bal. Acc: 0.7236 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5690 | Val Avg. Loss: 0.6717
# Epoch [23/25] | Train Bal. Acc: 0.7323 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5675 | Val Avg. Loss: 0.6709
# Epoch [24/25] | Train Bal. Acc: 0.7109 | Val Bal. Acc: 0.4470
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5677 | Val Avg. Loss: 0.6727
# Epoch [25/25] | Train Bal. Acc: 0.7109 | Val Bal. Acc: 0.4470
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6733750700950623
# [[2 2]
#  [4 4]]
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6716 | Val Avg. Loss: 0.5878
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6637 | Val Avg. Loss: 0.5862
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6674 | Val Avg. Loss: 0.5859
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6586 | Val Avg. Loss: 0.5933
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6584 | Val Avg. Loss: 0.6092
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6457 | Val Avg. Loss: 0.6036
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6495 | Val Avg. Loss: 0.5955
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6464 | Val Avg. Loss: 0.5932
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6379 | Val Avg. Loss: 0.5895
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6329 | Val Avg. Loss: 0.5824
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6318 | Val Avg. Loss: 0.5808
# Epoch [11/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6238 | Val Avg. Loss: 0.6004
# Epoch [12/25] | Train Bal. Acc: 0.4911 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6202 | Val Avg. Loss: 0.5938
# Epoch [13/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6096 | Val Avg. Loss: 0.5998
# Epoch [14/25] | Train Bal. Acc: 0.4911 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6037 | Val Avg. Loss: 0.5995
# Epoch [15/25] | Train Bal. Acc: 0.4911 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6050 | Val Avg. Loss: 0.5972
# Epoch [16/25] | Train Bal. Acc: 0.4911 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5832 | Val Avg. Loss: 0.6002
# Epoch [17/25] | Train Bal. Acc: 0.4968 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5863 | Val Avg. Loss: 0.5964
# Epoch [18/25] | Train Bal. Acc: 0.5378 | Val Bal. Acc: 0.5987
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5730 | Val Avg. Loss: 0.6034
# Epoch [19/25] | Train Bal. Acc: 0.5436 | Val Bal. Acc: 0.5461
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5677 | Val Avg. Loss: 0.6095
# Epoch [20/25] | Train Bal. Acc: 0.6113 | Val Bal. Acc: 0.6447
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5617 | Val Avg. Loss: 0.5981
# Epoch [21/25] | Train Bal. Acc: 0.6024 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5544 | Val Avg. Loss: 0.5926
# Epoch [22/25] | Train Bal. Acc: 0.6171 | Val Bal. Acc: 0.6086
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5385 | Val Avg. Loss: 0.6087
# Epoch [23/25] | Train Bal. Acc: 0.6492 | Val Bal. Acc: 0.6184
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5351 | Val Avg. Loss: 0.6099
# Epoch [24/25] | Train Bal. Acc: 0.6492 | Val Bal. Acc: 0.5559
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5318 | Val Avg. Loss: 0.6128
# Epoch [25/25] | Train Bal. Acc: 0.6434 | Val Bal. Acc: 0.5559
# --------------------
# Bal. Accuracy: 0.55
# Avg. Loss:  0.702741966528051
# [[6 6]
#  [2 3]]
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7226 | Val Avg. Loss: 0.6931
# Epoch [1/25] | Train Bal. Acc: 0.3073 | Val Bal. Acc: 0.5882
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6710 | Val Avg. Loss: 0.7080
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6429 | Val Avg. Loss: 0.7750
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6332 | Val Avg. Loss: 0.8401
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.8043
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6165 | Val Avg. Loss: 0.7849
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6169 | Val Avg. Loss: 0.7820
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6103 | Val Avg. Loss: 0.7754
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6098 | Val Avg. Loss: 0.7848
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.4688
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6023 | Val Avg. Loss: 0.7923
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.4688
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6056 | Val Avg. Loss: 0.7893
# Epoch [11/25] | Train Bal. Acc: 0.5156 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5976 | Val Avg. Loss: 0.7897
# Epoch [12/25] | Train Bal. Acc: 0.5469 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6048 | Val Avg. Loss: 0.8317
# Epoch [13/25] | Train Bal. Acc: 0.5542 | Val Bal. Acc: 0.4375
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5920 | Val Avg. Loss: 0.8024
# Epoch [14/25] | Train Bal. Acc: 0.5542 | Val Bal. Acc: 0.5257
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6019 | Val Avg. Loss: 0.7772
# Epoch [15/25] | Train Bal. Acc: 0.5531 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5973 | Val Avg. Loss: 0.7910
# Epoch [16/25] | Train Bal. Acc: 0.5531 | Val Bal. Acc: 0.5257
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5854 | Val Avg. Loss: 0.7842
# Epoch [17/25] | Train Bal. Acc: 0.5760 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5908 | Val Avg. Loss: 0.7956
# Epoch [18/25] | Train Bal. Acc: 0.5687 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5807 | Val Avg. Loss: 0.7949
# Epoch [19/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5719 | Val Avg. Loss: 0.8353
# Epoch [20/25] | Train Bal. Acc: 0.5760 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5792 | Val Avg. Loss: 0.8500
# Epoch [21/25] | Train Bal. Acc: 0.5844 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5754 | Val Avg. Loss: 0.8146
# Epoch [22/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5614 | Val Avg. Loss: 0.7964
# Epoch [23/25] | Train Bal. Acc: 0.6073 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5642 | Val Avg. Loss: 0.8138
# Epoch [24/25] | Train Bal. Acc: 0.6146 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5495 | Val Avg. Loss: 0.8319
# Epoch [25/25] | Train Bal. Acc: 0.6385 | Val Bal. Acc: 0.5551
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6928332448005676
# [[0 5]
#  [0 4]]
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6920 | Val Avg. Loss: 0.6777
# Epoch [1/25] | Train Bal. Acc: 0.5404 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6486 | Val Avg. Loss: 0.7209
# Epoch [2/25] | Train Bal. Acc: 0.5167 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6419 | Val Avg. Loss: 0.7695
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6371 | Val Avg. Loss: 0.7812
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6367 | Val Avg. Loss: 0.7707
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6331 | Val Avg. Loss: 0.7630
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6316 | Val Avg. Loss: 0.7457
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6312 | Val Avg. Loss: 0.7419
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6288 | Val Avg. Loss: 0.7587
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6227 | Val Avg. Loss: 0.7454
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6212 | Val Avg. Loss: 0.7295
# Epoch [11/25] | Train Bal. Acc: 0.5167 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6240 | Val Avg. Loss: 0.7429
# Epoch [12/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5312
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6213 | Val Avg. Loss: 0.7250
# Epoch [13/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5312
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6222 | Val Avg. Loss: 0.7255
# Epoch [14/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5312
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6211 | Val Avg. Loss: 0.7246
# Epoch [15/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5312
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6145 | Val Avg. Loss: 0.7044
# Epoch [16/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6206 | Val Avg. Loss: 0.7041
# Epoch [17/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6141 | Val Avg. Loss: 0.7186
# Epoch [18/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5938
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6066 | Val Avg. Loss: 0.7404
# Epoch [19/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6127 | Val Avg. Loss: 0.7238
# Epoch [20/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6016 | Val Avg. Loss: 0.7209
# Epoch [21/25] | Train Bal. Acc: 0.5079 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6004 | Val Avg. Loss: 0.6982
# Epoch [22/25] | Train Bal. Acc: 0.5079 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5931 | Val Avg. Loss: 0.7152
# Epoch [23/25] | Train Bal. Acc: 0.5246 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5808 | Val Avg. Loss: 0.7043
# Epoch [24/25] | Train Bal. Acc: 0.4991 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5928 | Val Avg. Loss: 0.7019
# Epoch [25/25] | Train Bal. Acc: 0.5079 | Val Bal. Acc: 0.6562
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6600731213887533
# [[ 0  8]
#  [ 0 10]]
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6939 | Val Avg. Loss: 0.6548
# Epoch [1/25] | Train Bal. Acc: 0.5333 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6816 | Val Avg. Loss: 0.6508
# Epoch [2/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.5625
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6790 | Val Avg. Loss: 0.6393
# Epoch [3/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6748 | Val Avg. Loss: 0.6378
# Epoch [4/25] | Train Bal. Acc: 0.6111 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6711 | Val Avg. Loss: 0.6465
# Epoch [5/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6625 | Val Avg. Loss: 0.6213
# Epoch [6/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6574 | Val Avg. Loss: 0.6025
# Epoch [7/25] | Train Bal. Acc: 0.6778 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6498 | Val Avg. Loss: 0.6005
# Epoch [8/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.5417
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6444 | Val Avg. Loss: 0.5959
# Epoch [9/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6359 | Val Avg. Loss: 0.5901
# Epoch [10/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6309 | Val Avg. Loss: 0.5747
# Epoch [11/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6292 | Val Avg. Loss: 0.5785
# Epoch [12/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6240 | Val Avg. Loss: 0.5702
# Epoch [13/25] | Train Bal. Acc: 0.6778 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6198 | Val Avg. Loss: 0.5741
# Epoch [14/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6138 | Val Avg. Loss: 0.5839
# Epoch [15/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6091 | Val Avg. Loss: 0.5913
# Epoch [16/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6077 | Val Avg. Loss: 0.5892
# Epoch [17/25] | Train Bal. Acc: 0.6778 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5926 | Val Avg. Loss: 0.5925
# Epoch [18/25] | Train Bal. Acc: 0.6778 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6042 | Val Avg. Loss: 0.5949
# Epoch [19/25] | Train Bal. Acc: 0.6778 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5966 | Val Avg. Loss: 0.5860
# Epoch [20/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6076 | Val Avg. Loss: 0.5792
# Epoch [21/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5950 | Val Avg. Loss: 0.5797
# Epoch [22/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5969 | Val Avg. Loss: 0.5760
# Epoch [23/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5919 | Val Avg. Loss: 0.5792
# Epoch [24/25] | Train Bal. Acc: 0.6889 | Val Bal. Acc: 0.5208
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5866 | Val Avg. Loss: 0.5742
# Epoch [25/25] | Train Bal. Acc: 0.7000 | Val Bal. Acc: 0.5208
# --------------------
# Bal. Accuracy: 0.5727272727272728
# Avg. Loss:  0.6936526298522949
# [[3 2]
#  [5 6]]
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7120 | Val Avg. Loss: 0.5983
# Epoch [1/25] | Train Bal. Acc: 0.5213 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6971 | Val Avg. Loss: 0.6283
# Epoch [2/25] | Train Bal. Acc: 0.5645 | Val Bal. Acc: 0.7500
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6967 | Val Avg. Loss: 0.6684
# Epoch [3/25] | Train Bal. Acc: 0.5184 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6929 | Val Avg. Loss: 0.6740
# Epoch [4/25] | Train Bal. Acc: 0.5167 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6894 | Val Avg. Loss: 0.6651
# Epoch [5/25] | Train Bal. Acc: 0.5056 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6841 | Val Avg. Loss: 0.6540
# Epoch [6/25] | Train Bal. Acc: 0.5502 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6803 | Val Avg. Loss: 0.6392
# Epoch [7/25] | Train Bal. Acc: 0.5179 | Val Bal. Acc: 0.6875
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6769 | Val Avg. Loss: 0.6131
# Epoch [8/25] | Train Bal. Acc: 0.5732 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6786 | Val Avg. Loss: 0.6292
# Epoch [9/25] | Train Bal. Acc: 0.5399 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6626 | Val Avg. Loss: 0.5968
# Epoch [10/25] | Train Bal. Acc: 0.6384 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6573 | Val Avg. Loss: 0.5814
# Epoch [11/25] | Train Bal. Acc: 0.5843 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6736 | Val Avg. Loss: 0.6226
# Epoch [12/25] | Train Bal. Acc: 0.6051 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6588 | Val Avg. Loss: 0.5887
# Epoch [13/25] | Train Bal. Acc: 0.6481 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6467 | Val Avg. Loss: 0.5573
# Epoch [14/25] | Train Bal. Acc: 0.6498 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6523 | Val Avg. Loss: 0.5727
# Epoch [15/25] | Train Bal. Acc: 0.6384 | Val Bal. Acc: 0.7292
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6592 | Val Avg. Loss: 0.5796
# Epoch [16/25] | Train Bal. Acc: 0.6271 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6419 | Val Avg. Loss: 0.5775
# Epoch [17/25] | Train Bal. Acc: 0.6594 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6470 | Val Avg. Loss: 0.5897
# Epoch [18/25] | Train Bal. Acc: 0.6372 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6364 | Val Avg. Loss: 0.5681
# Epoch [19/25] | Train Bal. Acc: 0.6698 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6463 | Val Avg. Loss: 0.5360
# Epoch [20/25] | Train Bal. Acc: 0.6601 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6444 | Val Avg. Loss: 0.5655
# Epoch [21/25] | Train Bal. Acc: 0.6377 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6346 | Val Avg. Loss: 0.5606
# Epoch [22/25] | Train Bal. Acc: 0.6379 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6318 | Val Avg. Loss: 0.5494
# Epoch [23/25] | Train Bal. Acc: 0.6051 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6405 | Val Avg. Loss: 0.5488
# Epoch [24/25] | Train Bal. Acc: 0.6266 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6276 | Val Avg. Loss: 0.5883
# Epoch [25/25] | Train Bal. Acc: 0.6698 | Val Bal. Acc: 0.6875
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6384792923927307
# [[ 0  4]
#  [ 0 11]]
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6398 | Val Avg. Loss: 0.7340
# Epoch [1/25] | Train Bal. Acc: 0.4836 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6135 | Val Avg. Loss: 0.7704
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6000 | Val Avg. Loss: 0.7956
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6003 | Val Avg. Loss: 0.7937
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.5956 | Val Avg. Loss: 0.7789
# Epoch [5/25] | Train Bal. Acc: 0.5172 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.5916 | Val Avg. Loss: 0.7658
# Epoch [6/25] | Train Bal. Acc: 0.5090 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.5826 | Val Avg. Loss: 0.7606
# Epoch [7/25] | Train Bal. Acc: 0.5263 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.5828 | Val Avg. Loss: 0.7770
# Epoch [8/25] | Train Bal. Acc: 0.5263 | Val Bal. Acc: 0.4982
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.5745 | Val Avg. Loss: 0.7722
# Epoch [9/25] | Train Bal. Acc: 0.5181 | Val Bal. Acc: 0.5276
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.5656 | Val Avg. Loss: 0.7796
# Epoch [10/25] | Train Bal. Acc: 0.5181 | Val Bal. Acc: 0.5570
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.5724 | Val Avg. Loss: 0.8096
# Epoch [11/25] | Train Bal. Acc: 0.5353 | Val Bal. Acc: 0.5257
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5549 | Val Avg. Loss: 0.7878
# Epoch [12/25] | Train Bal. Acc: 0.5353 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5565 | Val Avg. Loss: 0.7958
# Epoch [13/25] | Train Bal. Acc: 0.5616 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.5578 | Val Avg. Loss: 0.7605
# Epoch [14/25] | Train Bal. Acc: 0.5271 | Val Bal. Acc: 0.5239
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5553 | Val Avg. Loss: 0.7819
# Epoch [15/25] | Train Bal. Acc: 0.5879 | Val Bal. Acc: 0.5239
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5507 | Val Avg. Loss: 0.8583
# Epoch [16/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5460 | Val Avg. Loss: 0.8319
# Epoch [17/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5311 | Val Avg. Loss: 0.8042
# Epoch [18/25] | Train Bal. Acc: 0.6224 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5324 | Val Avg. Loss: 0.8566
# Epoch [19/25] | Train Bal. Acc: 0.5707 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5246 | Val Avg. Loss: 0.8840
# Epoch [20/25] | Train Bal. Acc: 0.5879 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5248 | Val Avg. Loss: 0.8124
# Epoch [21/25] | Train Bal. Acc: 0.5879 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5097 | Val Avg. Loss: 0.8586
# Epoch [22/25] | Train Bal. Acc: 0.6232 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5200 | Val Avg. Loss: 0.8972
# Epoch [23/25] | Train Bal. Acc: 0.6306 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5132 | Val Avg. Loss: 0.8451
# Epoch [24/25] | Train Bal. Acc: 0.6142 | Val Bal. Acc: 0.5551
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.4982 | Val Avg. Loss: 0.8665
# Epoch [25/25] | Train Bal. Acc: 0.6405 | Val Bal. Acc: 0.5551
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.9200012683868408
# [[0 8]
#  [0 3]]
# Accuracy (Balanced): 0.5111111111111111
# Avg. Loss: 0.697105533468957
#               precision    recall  f1-score   support
#
#            0       0.43      0.22      0.29        54
#            1       0.60      0.80      0.69        80
#
#     accuracy                           0.57       134
#    macro avg       0.52      0.51      0.49       134
# weighted avg       0.53      0.57      0.53       134

# %% [markdown]
# # HAPPIENES

# %%
_ = attention_based_mil(df, ["AU06_r", "AU12_r"])
# Out:
# --------------------
# Test Source: Art6
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6811 | Val Avg. Loss: 0.7030
# Epoch [1/25] | Train Bal. Acc: 0.5702 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6671 | Val Avg. Loss: 0.6803
# Epoch [2/25] | Train Bal. Acc: 0.5902 | Val Bal. Acc: 0.5559
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6605 | Val Avg. Loss: 0.6832
# Epoch [3/25] | Train Bal. Acc: 0.4912 | Val Bal. Acc: 0.4770
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6570 | Val Avg. Loss: 0.6956
# Epoch [4/25] | Train Bal. Acc: 0.5721 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6550 | Val Avg. Loss: 0.7126
# Epoch [5/25] | Train Bal. Acc: 0.5614 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6507 | Val Avg. Loss: 0.7205
# Epoch [6/25] | Train Bal. Acc: 0.6034 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6445 | Val Avg. Loss: 0.7134
# Epoch [7/25] | Train Bal. Acc: 0.6122 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6496 | Val Avg. Loss: 0.7149
# Epoch [8/25] | Train Bal. Acc: 0.5789 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6486 | Val Avg. Loss: 0.7225
# Epoch [9/25] | Train Bal. Acc: 0.5702 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6391 | Val Avg. Loss: 0.7269
# Epoch [10/25] | Train Bal. Acc: 0.5733 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6474 | Val Avg. Loss: 0.7314
# Epoch [11/25] | Train Bal. Acc: 0.5733 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6359 | Val Avg. Loss: 0.7421
# Epoch [12/25] | Train Bal. Acc: 0.5940 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6390 | Val Avg. Loss: 0.7658
# Epoch [13/25] | Train Bal. Acc: 0.6209 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6380 | Val Avg. Loss: 0.7791
# Epoch [14/25] | Train Bal. Acc: 0.6065 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6362 | Val Avg. Loss: 0.7873
# Epoch [15/25] | Train Bal. Acc: 0.6303 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6375 | Val Avg. Loss: 0.7962
# Epoch [16/25] | Train Bal. Acc: 0.6391 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6335 | Val Avg. Loss: 0.7866
# Epoch [17/25] | Train Bal. Acc: 0.6216 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6318 | Val Avg. Loss: 0.7673
# Epoch [18/25] | Train Bal. Acc: 0.6241 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6407 | Val Avg. Loss: 0.7743
# Epoch [19/25] | Train Bal. Acc: 0.6153 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6314 | Val Avg. Loss: 0.7795
# Epoch [20/25] | Train Bal. Acc: 0.6003 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6332 | Val Avg. Loss: 0.7902
# Epoch [21/25] | Train Bal. Acc: 0.6122 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6368 | Val Avg. Loss: 0.7971
# Epoch [22/25] | Train Bal. Acc: 0.6272 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6352 | Val Avg. Loss: 0.7904
# Epoch [23/25] | Train Bal. Acc: 0.6184 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6337 | Val Avg. Loss: 0.7785
# Epoch [24/25] | Train Bal. Acc: 0.6184 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6394 | Val Avg. Loss: 0.7631
# Epoch [25/25] | Train Bal. Acc: 0.6003 | Val Bal. Acc: 0.4605
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.6618123650550842
# [[0 4]
#  [0 4]]
#
# --------------------
# Test Source: Bus14
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7109 | Val Avg. Loss: 0.7258
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6916 | Val Avg. Loss: 0.7055
# Epoch [2/25] | Train Bal. Acc: 0.5413 | Val Bal. Acc: 0.4672
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6847 | Val Avg. Loss: 0.6918
# Epoch [3/25] | Train Bal. Acc: 0.5397 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6829 | Val Avg. Loss: 0.6832
# Epoch [4/25] | Train Bal. Acc: 0.5325 | Val Bal. Acc: 0.4268
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6814 | Val Avg. Loss: 0.6824
# Epoch [5/25] | Train Bal. Acc: 0.5198 | Val Bal. Acc: 0.4823
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6798 | Val Avg. Loss: 0.6877
# Epoch [6/25] | Train Bal. Acc: 0.5437 | Val Bal. Acc: 0.4823
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6770 | Val Avg. Loss: 0.6946
# Epoch [7/25] | Train Bal. Acc: 0.5437 | Val Bal. Acc: 0.4596
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6768 | Val Avg. Loss: 0.7078
# Epoch [8/25] | Train Bal. Acc: 0.5341 | Val Bal. Acc: 0.4141
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6774 | Val Avg. Loss: 0.7205
# Epoch [9/25] | Train Bal. Acc: 0.5714 | Val Bal. Acc: 0.5025
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6749 | Val Avg. Loss: 0.7276
# Epoch [10/25] | Train Bal. Acc: 0.6071 | Val Bal. Acc: 0.5581
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6721 | Val Avg. Loss: 0.7392
# Epoch [11/25] | Train Bal. Acc: 0.5857 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6720 | Val Avg. Loss: 0.7422
# Epoch [12/25] | Train Bal. Acc: 0.6095 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6678 | Val Avg. Loss: 0.7450
# Epoch [13/25] | Train Bal. Acc: 0.6095 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6700 | Val Avg. Loss: 0.7486
# Epoch [14/25] | Train Bal. Acc: 0.5976 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6665 | Val Avg. Loss: 0.7566
# Epoch [15/25] | Train Bal. Acc: 0.5865 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6638 | Val Avg. Loss: 0.7590
# Epoch [16/25] | Train Bal. Acc: 0.6103 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6621 | Val Avg. Loss: 0.7606
# Epoch [17/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6610 | Val Avg. Loss: 0.7649
# Epoch [18/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6604 | Val Avg. Loss: 0.7711
# Epoch [19/25] | Train Bal. Acc: 0.6444 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6571 | Val Avg. Loss: 0.7767
# Epoch [20/25] | Train Bal. Acc: 0.6325 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6573 | Val Avg. Loss: 0.7778
# Epoch [21/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6530 | Val Avg. Loss: 0.7793
# Epoch [22/25] | Train Bal. Acc: 0.6556 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6597 | Val Avg. Loss: 0.7816
# Epoch [23/25] | Train Bal. Acc: 0.6333 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6560 | Val Avg. Loss: 0.7850
# Epoch [24/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5354
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6486 | Val Avg. Loss: 0.7878
# Epoch [25/25] | Train Bal. Acc: 0.6667 | Val Bal. Acc: 0.5354
# --------------------
# Bal. Accuracy: 0.6794871794871795
# Avg. Loss:  0.5732030272483826
# [[2 1]
#  [4 9]]
#
# --------------------
# Test Source: Edu2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7088 | Val Avg. Loss: 0.6352
# Epoch [1/25] | Train Bal. Acc: 0.4905 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6948 | Val Avg. Loss: 0.6614
# Epoch [2/25] | Train Bal. Acc: 0.5131 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6955 | Val Avg. Loss: 0.6722
# Epoch [3/25] | Train Bal. Acc: 0.5267 | Val Bal. Acc: 0.4286
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6923 | Val Avg. Loss: 0.6825
# Epoch [4/25] | Train Bal. Acc: 0.5598 | Val Bal. Acc: 0.4048
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6933 | Val Avg. Loss: 0.6922
# Epoch [5/25] | Train Bal. Acc: 0.4977 | Val Bal. Acc: 0.3333
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6968 | Val Avg. Loss: 0.6853
# Epoch [6/25] | Train Bal. Acc: 0.4665 | Val Bal. Acc: 0.4048
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6946 | Val Avg. Loss: 0.6830
# Epoch [7/25] | Train Bal. Acc: 0.5376 | Val Bal. Acc: 0.4286
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6937 | Val Avg. Loss: 0.6784
# Epoch [8/25] | Train Bal. Acc: 0.5249 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6917 | Val Avg. Loss: 0.6760
# Epoch [9/25] | Train Bal. Acc: 0.5340 | Val Bal. Acc: 0.4762
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6923 | Val Avg. Loss: 0.6830
# Epoch [10/25] | Train Bal. Acc: 0.5226 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6911 | Val Avg. Loss: 0.6877
# Epoch [11/25] | Train Bal. Acc: 0.5666 | Val Bal. Acc: 0.4048
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6931 | Val Avg. Loss: 0.6889
# Epoch [12/25] | Train Bal. Acc: 0.4946 | Val Bal. Acc: 0.4048
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6907 | Val Avg. Loss: 0.6917
# Epoch [13/25] | Train Bal. Acc: 0.5362 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6899 | Val Avg. Loss: 0.6870
# Epoch [14/25] | Train Bal. Acc: 0.5466 | Val Bal. Acc: 0.3333
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6916 | Val Avg. Loss: 0.6754
# Epoch [15/25] | Train Bal. Acc: 0.5113 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6916 | Val Avg. Loss: 0.6751
# Epoch [16/25] | Train Bal. Acc: 0.5326 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6870 | Val Avg. Loss: 0.6814
# Epoch [17/25] | Train Bal. Acc: 0.5331 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6877 | Val Avg. Loss: 0.6844
# Epoch [18/25] | Train Bal. Acc: 0.5874 | Val Bal. Acc: 0.4524
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6887 | Val Avg. Loss: 0.6900
# Epoch [19/25] | Train Bal. Acc: 0.5770 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6865 | Val Avg. Loss: 0.6872
# Epoch [20/25] | Train Bal. Acc: 0.5675 | Val Bal. Acc: 0.5714
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6869 | Val Avg. Loss: 0.6958
# Epoch [21/25] | Train Bal. Acc: 0.5788 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6867 | Val Avg. Loss: 0.6972
# Epoch [22/25] | Train Bal. Acc: 0.6241 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6889 | Val Avg. Loss: 0.6998
# Epoch [23/25] | Train Bal. Acc: 0.5598 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6885 | Val Avg. Loss: 0.6994
# Epoch [24/25] | Train Bal. Acc: 0.5711 | Val Bal. Acc: 0.5238
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6874 | Val Avg. Loss: 0.7039
# Epoch [25/25] | Train Bal. Acc: 0.5177 | Val Bal. Acc: 0.5476
# --------------------
# Bal. Accuracy: 0.9545454545454546
# Avg. Loss:  0.6641222238540649
# [[ 1  0]
#  [ 1 10]]
#
# --------------------
# Test Source: Ent5
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6931 | Val Avg. Loss: 0.6189
# Epoch [1/25] | Train Bal. Acc: 0.5273 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6889 | Val Avg. Loss: 0.6090
# Epoch [2/25] | Train Bal. Acc: 0.4368 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6876 | Val Avg. Loss: 0.6169
# Epoch [3/25] | Train Bal. Acc: 0.4982 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6860 | Val Avg. Loss: 0.6222
# Epoch [4/25] | Train Bal. Acc: 0.4855 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6825 | Val Avg. Loss: 0.6237
# Epoch [5/25] | Train Bal. Acc: 0.4936 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6879 | Val Avg. Loss: 0.6399
# Epoch [6/25] | Train Bal. Acc: 0.4845 | Val Bal. Acc: 0.5152
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6808 | Val Avg. Loss: 0.6245
# Epoch [7/25] | Train Bal. Acc: 0.4886 | Val Bal. Acc: 0.5379
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6819 | Val Avg. Loss: 0.6174
# Epoch [8/25] | Train Bal. Acc: 0.5273 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6761 | Val Avg. Loss: 0.6163
# Epoch [9/25] | Train Bal. Acc: 0.5045 | Val Bal. Acc: 0.5379
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6790 | Val Avg. Loss: 0.6141
# Epoch [10/25] | Train Bal. Acc: 0.5373 | Val Bal. Acc: 0.5606
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6777 | Val Avg. Loss: 0.6101
# Epoch [11/25] | Train Bal. Acc: 0.5218 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6739 | Val Avg. Loss: 0.6104
# Epoch [12/25] | Train Bal. Acc: 0.5373 | Val Bal. Acc: 0.5379
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6779 | Val Avg. Loss: 0.6386
# Epoch [13/25] | Train Bal. Acc: 0.5614 | Val Bal. Acc: 0.8030
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6779 | Val Avg. Loss: 0.6401
# Epoch [14/25] | Train Bal. Acc: 0.5127 | Val Bal. Acc: 0.7576
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6682 | Val Avg. Loss: 0.6279
# Epoch [15/25] | Train Bal. Acc: 0.5468 | Val Bal. Acc: 0.7197
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6722 | Val Avg. Loss: 0.6202
# Epoch [16/25] | Train Bal. Acc: 0.5341 | Val Bal. Acc: 0.6364
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6746 | Val Avg. Loss: 0.6288
# Epoch [17/25] | Train Bal. Acc: 0.5227 | Val Bal. Acc: 0.7197
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6735 | Val Avg. Loss: 0.6212
# Epoch [18/25] | Train Bal. Acc: 0.5568 | Val Bal. Acc: 0.7197
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6663 | Val Avg. Loss: 0.6453
# Epoch [19/25] | Train Bal. Acc: 0.6009 | Val Bal. Acc: 0.7348
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6640 | Val Avg. Loss: 0.6405
# Epoch [20/25] | Train Bal. Acc: 0.5582 | Val Bal. Acc: 0.7576
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6703 | Val Avg. Loss: 0.6342
# Epoch [21/25] | Train Bal. Acc: 0.5682 | Val Bal. Acc: 0.7576
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6714 | Val Avg. Loss: 0.6332
# Epoch [22/25] | Train Bal. Acc: 0.5582 | Val Bal. Acc: 0.7576
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6715 | Val Avg. Loss: 0.6211
# Epoch [23/25] | Train Bal. Acc: 0.5695 | Val Bal. Acc: 0.6364
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6731 | Val Avg. Loss: 0.6097
# Epoch [24/25] | Train Bal. Acc: 0.5555 | Val Bal. Acc: 0.6364
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6663 | Val Avg. Loss: 0.6182
# Epoch [25/25] | Train Bal. Acc: 0.5555 | Val Bal. Acc: 0.6364
# --------------------
# Bal. Accuracy: 0.375
# Avg. Loss:  0.692744255065918
# [[0 4]
#  [2 6]]
#
# --------------------
# Test Source: Med15
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6709 | Val Avg. Loss: 0.6340
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6525 | Val Avg. Loss: 0.6346
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6432 | Val Avg. Loss: 0.6396
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6406 | Val Avg. Loss: 0.6471
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6398 | Val Avg. Loss: 0.6578
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6390 | Val Avg. Loss: 0.6654
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6380 | Val Avg. Loss: 0.6729
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6295 | Val Avg. Loss: 0.6795
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6292 | Val Avg. Loss: 0.6817
# Epoch [9/25] | Train Bal. Acc: 0.5147 | Val Bal. Acc: 0.4934
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6215 | Val Avg. Loss: 0.6880
# Epoch [10/25] | Train Bal. Acc: 0.5263 | Val Bal. Acc: 0.4605
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6300 | Val Avg. Loss: 0.6945
# Epoch [11/25] | Train Bal. Acc: 0.4937 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6263 | Val Avg. Loss: 0.6976
# Epoch [12/25] | Train Bal. Acc: 0.5494 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6216 | Val Avg. Loss: 0.6988
# Epoch [13/25] | Train Bal. Acc: 0.5667 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6262 | Val Avg. Loss: 0.7029
# Epoch [14/25] | Train Bal. Acc: 0.5756 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6252 | Val Avg. Loss: 0.7072
# Epoch [15/25] | Train Bal. Acc: 0.5578 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6237 | Val Avg. Loss: 0.7108
# Epoch [16/25] | Train Bal. Acc: 0.5520 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6169 | Val Avg. Loss: 0.7171
# Epoch [17/25] | Train Bal. Acc: 0.5872 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6203 | Val Avg. Loss: 0.7230
# Epoch [18/25] | Train Bal. Acc: 0.5546 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6216 | Val Avg. Loss: 0.7262
# Epoch [19/25] | Train Bal. Acc: 0.5783 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6094 | Val Avg. Loss: 0.7333
# Epoch [20/25] | Train Bal. Acc: 0.5987 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6104 | Val Avg. Loss: 0.7391
# Epoch [21/25] | Train Bal. Acc: 0.6224 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6210 | Val Avg. Loss: 0.7429
# Epoch [22/25] | Train Bal. Acc: 0.6077 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6124 | Val Avg. Loss: 0.7435
# Epoch [23/25] | Train Bal. Acc: 0.5987 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6091 | Val Avg. Loss: 0.7522
# Epoch [24/25] | Train Bal. Acc: 0.6134 | Val Bal. Acc: 0.4342
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6168 | Val Avg. Loss: 0.7517
# Epoch [25/25] | Train Bal. Acc: 0.6282 | Val Bal. Acc: 0.4342
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.8048976203974556
# [[ 0 12]
#  [ 0  5]]
#
# --------------------
# Test Source: Phi3
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7179 | Val Avg. Loss: 0.6961
# Epoch [1/25] | Train Bal. Acc: 0.4958 | Val Bal. Acc: 0.5368
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6650 | Val Avg. Loss: 0.7092
# Epoch [2/25] | Train Bal. Acc: 0.5500 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6443 | Val Avg. Loss: 0.7333
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6328 | Val Avg. Loss: 0.7561
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6326 | Val Avg. Loss: 0.7659
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6303 | Val Avg. Loss: 0.7714
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6320 | Val Avg. Loss: 0.7686
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6352 | Val Avg. Loss: 0.7626
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6274 | Val Avg. Loss: 0.7587
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6288 | Val Avg. Loss: 0.7553
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6260 | Val Avg. Loss: 0.7571
# Epoch [11/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6229 | Val Avg. Loss: 0.7573
# Epoch [12/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6247 | Val Avg. Loss: 0.7603
# Epoch [13/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6269 | Val Avg. Loss: 0.7597
# Epoch [14/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6257 | Val Avg. Loss: 0.7509
# Epoch [15/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6224 | Val Avg. Loss: 0.7527
# Epoch [16/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6288 | Val Avg. Loss: 0.7527
# Epoch [17/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6214 | Val Avg. Loss: 0.7519
# Epoch [18/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6231 | Val Avg. Loss: 0.7452
# Epoch [19/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6248 | Val Avg. Loss: 0.7463
# Epoch [20/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6214 | Val Avg. Loss: 0.7487
# Epoch [21/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6220 | Val Avg. Loss: 0.7526
# Epoch [22/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6249 | Val Avg. Loss: 0.7543
# Epoch [23/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6181 | Val Avg. Loss: 0.7537
# Epoch [24/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6150 | Val Avg. Loss: 0.7534
# Epoch [25/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Bal. Accuracy: 0.625
# Avg. Loss:  0.6919710636138916
# [[5 0]
#  [3 1]]
#
# --------------------
# Test Source: Pol2
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6693 | Val Avg. Loss: 0.7247
# Epoch [1/25] | Train Bal. Acc: 0.4982 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6368 | Val Avg. Loss: 0.7827
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6267 | Val Avg. Loss: 0.8384
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6260 | Val Avg. Loss: 0.8538
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6150 | Val Avg. Loss: 0.8421
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6084 | Val Avg. Loss: 0.8245
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6118 | Val Avg. Loss: 0.8058
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6024 | Val Avg. Loss: 0.8037
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6007 | Val Avg. Loss: 0.8100
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6005 | Val Avg. Loss: 0.7998
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6047 | Val Avg. Loss: 0.7821
# Epoch [11/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.5930 | Val Avg. Loss: 0.7892
# Epoch [12/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.5914 | Val Avg. Loss: 0.7933
# Epoch [13/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6012 | Val Avg. Loss: 0.8019
# Epoch [14/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.5935 | Val Avg. Loss: 0.8072
# Epoch [15/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.5929 | Val Avg. Loss: 0.7949
# Epoch [16/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.5947 | Val Avg. Loss: 0.7950
# Epoch [17/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.5912 | Val Avg. Loss: 0.8015
# Epoch [18/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.5934 | Val Avg. Loss: 0.8090
# Epoch [19/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.5888 | Val Avg. Loss: 0.8067
# Epoch [20/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.5953 | Val Avg. Loss: 0.8124
# Epoch [21/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.5901 | Val Avg. Loss: 0.7966
# Epoch [22/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.5934 | Val Avg. Loss: 0.7977
# Epoch [23/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.5862 | Val Avg. Loss: 0.8088
# Epoch [24/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.5884 | Val Avg. Loss: 0.8057
# Epoch [25/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.690172102716234
# [[ 0  8]
#  [ 0 10]]
#
# --------------------
# Test Source: Pol9
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.7084 | Val Avg. Loss: 0.7646
# Epoch [1/25] | Train Bal. Acc: 0.4556 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6969 | Val Avg. Loss: 0.7329
# Epoch [2/25] | Train Bal. Acc: 0.4889 | Val Bal. Acc: 0.2917
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6956 | Val Avg. Loss: 0.7252
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.2917
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6950 | Val Avg. Loss: 0.7382
# Epoch [4/25] | Train Bal. Acc: 0.4778 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6970 | Val Avg. Loss: 0.7632
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6924 | Val Avg. Loss: 0.7521
# Epoch [6/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6919 | Val Avg. Loss: 0.7313
# Epoch [7/25] | Train Bal. Acc: 0.5444 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6899 | Val Avg. Loss: 0.7404
# Epoch [8/25] | Train Bal. Acc: 0.4778 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6898 | Val Avg. Loss: 0.7473
# Epoch [9/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6935 | Val Avg. Loss: 0.7556
# Epoch [10/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.3542
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6923 | Val Avg. Loss: 0.7363
# Epoch [11/25] | Train Bal. Acc: 0.5111 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6902 | Val Avg. Loss: 0.7382
# Epoch [12/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6903 | Val Avg. Loss: 0.7307
# Epoch [13/25] | Train Bal. Acc: 0.5333 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6891 | Val Avg. Loss: 0.7323
# Epoch [14/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.4167
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6894 | Val Avg. Loss: 0.7426
# Epoch [15/25] | Train Bal. Acc: 0.5333 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6886 | Val Avg. Loss: 0.7398
# Epoch [16/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6872 | Val Avg. Loss: 0.7386
# Epoch [17/25] | Train Bal. Acc: 0.5889 | Val Bal. Acc: 0.3958
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6897 | Val Avg. Loss: 0.7438
# Epoch [18/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6879 | Val Avg. Loss: 0.7630
# Epoch [19/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6890 | Val Avg. Loss: 0.7581
# Epoch [20/25] | Train Bal. Acc: 0.5222 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6844 | Val Avg. Loss: 0.7541
# Epoch [21/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6880 | Val Avg. Loss: 0.7588
# Epoch [22/25] | Train Bal. Acc: 0.5556 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6873 | Val Avg. Loss: 0.7549
# Epoch [23/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6867 | Val Avg. Loss: 0.7578
# Epoch [24/25] | Train Bal. Acc: 0.5778 | Val Bal. Acc: 0.3750
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6865 | Val Avg. Loss: 0.7431
# Epoch [25/25] | Train Bal. Acc: 0.6000 | Val Bal. Acc: 0.2708
# --------------------
# Bal. Accuracy: 0.5636363636363637
# Avg. Loss:  0.7071825265884399
# [[2 3]
#  [3 8]]
#
# --------------------
# Test Source: Tech10
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6959 | Val Avg. Loss: 0.6030
# Epoch [1/25] | Train Bal. Acc: 0.5295 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6922 | Val Avg. Loss: 0.6306
# Epoch [2/25] | Train Bal. Acc: 0.5070 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6912 | Val Avg. Loss: 0.6804
# Epoch [3/25] | Train Bal. Acc: 0.5263 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6903 | Val Avg. Loss: 0.6878
# Epoch [4/25] | Train Bal. Acc: 0.5473 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6901 | Val Avg. Loss: 0.6685
# Epoch [5/25] | Train Bal. Acc: 0.5256 | Val Bal. Acc: 0.5833
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6881 | Val Avg. Loss: 0.6588
# Epoch [6/25] | Train Bal. Acc: 0.5698 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6888 | Val Avg. Loss: 0.6514
# Epoch [7/25] | Train Bal. Acc: 0.5698 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6868 | Val Avg. Loss: 0.6445
# Epoch [8/25] | Train Bal. Acc: 0.5481 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6926 | Val Avg. Loss: 0.6678
# Epoch [9/25] | Train Bal. Acc: 0.5589 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6865 | Val Avg. Loss: 0.6458
# Epoch [10/25] | Train Bal. Acc: 0.5920 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6851 | Val Avg. Loss: 0.6431
# Epoch [11/25] | Train Bal. Acc: 0.5483 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6863 | Val Avg. Loss: 0.6529
# Epoch [12/25] | Train Bal. Acc: 0.5812 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6855 | Val Avg. Loss: 0.6310
# Epoch [13/25] | Train Bal. Acc: 0.5703 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6850 | Val Avg. Loss: 0.6034
# Epoch [14/25] | Train Bal. Acc: 0.5930 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6841 | Val Avg. Loss: 0.6220
# Epoch [15/25] | Train Bal. Acc: 0.6039 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6756 | Val Avg. Loss: 0.6036
# Epoch [16/25] | Train Bal. Acc: 0.5930 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6758 | Val Avg. Loss: 0.6116
# Epoch [17/25] | Train Bal. Acc: 0.6261 | Val Bal. Acc: 0.6667
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6717 | Val Avg. Loss: 0.6471
# Epoch [18/25] | Train Bal. Acc: 0.6147 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6730 | Val Avg. Loss: 0.6519
# Epoch [19/25] | Train Bal. Acc: 0.5923 | Val Bal. Acc: 0.7083
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6747 | Val Avg. Loss: 0.5936
# Epoch [20/25] | Train Bal. Acc: 0.6039 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6740 | Val Avg. Loss: 0.6142
# Epoch [21/25] | Train Bal. Acc: 0.6150 | Val Bal. Acc: 0.6250
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6703 | Val Avg. Loss: 0.5993
# Epoch [22/25] | Train Bal. Acc: 0.6372 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6670 | Val Avg. Loss: 0.5935
# Epoch [23/25] | Train Bal. Acc: 0.6263 | Val Bal. Acc: 0.6458
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6600 | Val Avg. Loss: 0.6103
# Epoch [24/25] | Train Bal. Acc: 0.6261 | Val Bal. Acc: 0.6042
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6601 | Val Avg. Loss: 0.6393
# Epoch [25/25] | Train Bal. Acc: 0.6372 | Val Bal. Acc: 0.5833
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.753384530544281
# [[ 4  0]
#  [11  0]]
#
# --------------------
# Test Source: Tech21
# --------------------
# Epoch [1/25] | Train Avg. Loss: 0.6471 | Val Avg. Loss: 0.7246
# Epoch [1/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [2/25] | Train Avg. Loss: 0.6262 | Val Avg. Loss: 0.7565
# Epoch [2/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [3/25] | Train Avg. Loss: 0.6237 | Val Avg. Loss: 0.7772
# Epoch [3/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [4/25] | Train Avg. Loss: 0.6205 | Val Avg. Loss: 0.7876
# Epoch [4/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [5/25] | Train Avg. Loss: 0.6171 | Val Avg. Loss: 0.7918
# Epoch [5/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [6/25] | Train Avg. Loss: 0.6151 | Val Avg. Loss: 0.7929
# Epoch [6/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [7/25] | Train Avg. Loss: 0.6200 | Val Avg. Loss: 0.7863
# Epoch [7/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [8/25] | Train Avg. Loss: 0.6220 | Val Avg. Loss: 0.7842
# Epoch [8/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [9/25] | Train Avg. Loss: 0.6138 | Val Avg. Loss: 0.7796
# Epoch [9/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [10/25] | Train Avg. Loss: 0.6205 | Val Avg. Loss: 0.7728
# Epoch [10/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [11/25] | Train Avg. Loss: 0.6158 | Val Avg. Loss: 0.7828
# Epoch [11/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [12/25] | Train Avg. Loss: 0.6184 | Val Avg. Loss: 0.7828
# Epoch [12/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [13/25] | Train Avg. Loss: 0.6117 | Val Avg. Loss: 0.7923
# Epoch [13/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [14/25] | Train Avg. Loss: 0.6123 | Val Avg. Loss: 0.7912
# Epoch [14/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [15/25] | Train Avg. Loss: 0.6101 | Val Avg. Loss: 0.7939
# Epoch [15/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [16/25] | Train Avg. Loss: 0.6073 | Val Avg. Loss: 0.7981
# Epoch [16/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [17/25] | Train Avg. Loss: 0.6143 | Val Avg. Loss: 0.8030
# Epoch [17/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [18/25] | Train Avg. Loss: 0.6120 | Val Avg. Loss: 0.7979
# Epoch [18/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [19/25] | Train Avg. Loss: 0.6084 | Val Avg. Loss: 0.7976
# Epoch [19/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [20/25] | Train Avg. Loss: 0.6044 | Val Avg. Loss: 0.7977
# Epoch [20/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [21/25] | Train Avg. Loss: 0.6035 | Val Avg. Loss: 0.7987
# Epoch [21/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [22/25] | Train Avg. Loss: 0.6056 | Val Avg. Loss: 0.7948
# Epoch [22/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [23/25] | Train Avg. Loss: 0.6005 | Val Avg. Loss: 0.7935
# Epoch [23/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [24/25] | Train Avg. Loss: 0.6087 | Val Avg. Loss: 0.7886
# Epoch [24/25] | Train Bal. Acc: 0.5000 | Val Bal. Acc: 0.5000
# --------------------
# Epoch [25/25] | Train Avg. Loss: 0.6051 | Val Avg. Loss: 0.7882
# Epoch [25/25] | Train Bal. Acc: 0.5172 | Val Bal. Acc: 0.5000
# --------------------
# Bal. Accuracy: 0.5
# Avg. Loss:  0.7846033573150635
# [[0 8]
#  [0 3]]
# Accuracy (Balanced): 0.47962962962962963
# Avg. Loss: 0.7024093072398816
#               precision    recall  f1-score   support
#
#            0       0.37      0.26      0.30        54
#            1       0.58      0.70      0.64        80
#
#     accuracy                           0.52       134
#    macro avg       0.48      0.48      0.47       134
# weighted avg       0.50      0.52      0.50       134

# %% [markdown]
# # ATTENTION VISUALIZATIONS

# %%
df_attention = pd.DataFrame(attention_results)
df_attention
# Out:
#         clip_id  true_label  pred_prob  pred_label  \
# 0       Art6_S2           1   0.775464           1
# 1      Art6_S32           1   0.592456           1
# 2      Art6_S36           1   0.464630           0
# 3      Art6_S43           0   0.570605           1
# 4       Art6_S6           0   0.432526           0
# ..          ...         ...        ...         ...
# 129  Tech21_S32           0   0.466931           0
# 130  Tech21_S33           0   0.485831           0
# 131   Tech21_S4           0   0.450864           0
# 132   Tech21_S5           0   0.448451           0
# 133   Tech21_S6           0   0.492783           0
#
#                                              attention  \
# 0    [0.010810693, 0.010810693, 0.010810693, 0.0106...
# 1    [0.037092276, 0.03756151, 0.03756151, 0.029714...
# 2    [0.0014404968, 0.0017070096, 0.002622248, 0.04...
# 3    [0.025344202, 0.02754986, 0.02754986, 0.027549...
# 4    [0.06138381, 0.11856807, 0.104390085, 0.100073...
# ..                                                 ...
# 129   [0.25934383, 0.29744443, 0.22336033, 0.21985142]
# 130  [0.06381255, 0.060843874, 0.06074166, 0.060554...
# 131  [0.19315085, 0.18992439, 0.19201769, 0.2002361...
# 132  [0.2090107, 0.19709332, 0.19530639, 0.19880264...
# 133  [0.06309733, 0.06309733, 0.06308156, 0.0631633...
#
#                                                      X
# 0    [[-0.054545455, 0.0], [-0.054545455, 0.0], [-0...
# 1    [[-0.027272727, 0.0], [-0.054545455, 0.0], [-0...
# 2    [[10.690909, 2.2950819], [11.036364, 4.180328]...
# 3    [[0.12727273, 0.0], [-0.054545455, 0.0], [-0.0...
# 4    [[1.2, 0.0], [-0.054545455, 0.0], [0.21818182,...
# ..                                                 ...
# 129  [[1.0, 0.1875], [1.2372881, 0.140625], [0.1864...
# 130  [[0.050847456, 0.046875], [0.016949153, 0.6562...
# 131  [[-0.050847456, 0.328125], [-0.050847456, 0.53...
# 132  [[0.27118644, 0.0], [-0.050847456, 0.421875], ...
# 133  [[-0.050847456, 0.0], [-0.050847456, 0.0], [-0...
#
# [134 rows x 6 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_attention_heatmap_with_au02_au05(example):
    attention = np.asarray(
        example["attention"].iloc[0],
        dtype=float
    )

    X = np.asarray(
        example["X"].iloc[0],
        dtype=float
    )

    au02 = X[:, 0]
    au05 = X[:, 1]

    # Darstellung beginnt bei Window 1
    windows = np.arange(1, len(attention) + 1)

    if len(attention) != len(au02) or len(attention) != len(au05):
        raise ValueError(
            f"Attention has {len(attention)} windows, "
            f"AU02 has {len(au02)} values and "
            f"AU05 has {len(au05)} values."
        )

    clip_id = example["clip_id"].iloc[0]

    fig, axes = plt.subplots(
        2,
        1,
        figsize=(12, 4),
        sharex=True,
        gridspec_kw={
            "height_ratios": [0.35, 3],
            "hspace": 0.08
        }
    )

    # Attention-Heatmap
    heatmap = axes[0].imshow(
        attention.reshape(1, -1),
        aspect="auto",
        cmap="Blues",
        interpolation="nearest",
        extent=[
            0.5,
            len(attention) + 0.5,
            0,
            1
        ]
    )

    axes[0].set_yticks([])
    axes[0].set_ylabel("Attention")
    axes[0].set_title(
        f"Attention and Action Unit Activity – Clip {clip_id}"
    )

    axes[1].plot(
        windows,
        au02,
        marker="o",
        markersize=3,
        linewidth=1.5,
        color="dimgray",
        label="AU02_r"
    )

    axes[1].plot(
        windows,
        au05,
        marker="o",
        markersize=3,
        linewidth=1.5,
        color="darkgray",
        label="AU05_r"
    )

    axes[1].set_xlabel("Window")
    axes[1].set_ylabel("Normalized AU Value")
    axes[1].grid(alpha=0.3)
    axes[1].legend()

    fig.colorbar(
        heatmap,
        ax=axes,
        label="Attention Weight",
        fraction=0.025,
        pad=0.02
    )

    plt.show()

# %%
def plot_attention_heatmap_with_all_aus(example, au_names):
    attention = np.asarray(
        example["attention"].iloc[0],
        dtype=float
    )

    X = np.asarray(
        example["X"].iloc[0],
        dtype=float
    )

    clip_id = example["clip_id"].iloc[0]
    windows = np.arange(len(attention))

    if X.shape[0] != len(attention):
        raise ValueError(
            f"Attention has {len(attention)} windows, "
            f"but X has {X.shape[0]} windows."
        )

    if X.shape[1] != len(au_names):
        raise ValueError(
            f"X contains {X.shape[1]} features, "
            f"but {len(au_names)} AU names were provided."
        )

    fig, axes = plt.subplots(
        2,
        1,
        figsize=(14, 7),
        sharex=True,
        gridspec_kw={
            "height_ratios": [1, 4]
        }
    )

    # Attention-Heatmap
    heatmap = axes[0].imshow(
        attention.reshape(1, -1),
        aspect="auto",
        cmap="Reds",
        interpolation="nearest",
        extent=[
            -0.5,
            len(attention) - 0.5,
            0,
            1
        ]
    )

    axes[0].set_yticks([])
    axes[0].set_ylabel("Attention")
    axes[0].set_title(
        f"Attention and Action Unit activity – Clip {clip_id}"
    )

    # Alle AUs plotten
    for feature_index, au_name in enumerate(au_names):
        axes[1].plot(
            windows,
            X[:, feature_index],
            label=au_name,
            linewidth=1.5
        )

    axes[1].set_xlabel("Window Index")
    axes[1].set_ylabel("Normalized AU value")
    axes[1].grid(alpha=0.3)

    axes[1].legend(
        loc="upper center",
        bbox_to_anchor=(0.5, -0.18),
        ncol=4
    )

    fig.colorbar(
        heatmap,
        ax=axes,
        label="Attention Weight",
        fraction=0.025,
        pad=0.02
    )

    plt.subplots_adjust(bottom=0.23)
    plt.show()

# %%
def top_windows(example, fps=30):
    attention_weights = np.asarray(
        example["attention"].iloc[0],
        dtype=float
    )

    # Fünf höchste Attention-Werte
    top_indices = np.argsort(attention_weights)[-5:][::-1]

    window_size = 10
    stride = 5

    window_duration = window_size / fps
    stride_duration = stride / fps

    start_times = top_indices * stride_duration
    end_times = start_times + window_duration

    top_attention_windows = pd.DataFrame({
        "window": top_indices + 1,
        "start_time_seconds": start_times,
        "end_time_seconds": end_times,
        "attention_weight": attention_weights[top_indices]
    })

    return top_attention_windows

# %% [markdown]
# # EXAMPLES

# %%
false_positive_ex1 = df_attention[df_attention["clip_id"] == "Pol2_S91"]
false_positive_ex1
# Out:
#      clip_id  true_label  pred_prob  pred_label  \
# 90  Pol2_S91           0     0.9823           1
#
#                                             attention  \
# 90  [0.009961213, 0.0028926695, 0.002143783, 0.002...
#
#                                                     X
# 90  [[0.3482143, 4.2995596], [0.3482143, 1.092511]...

# %%
true_positive_ex1 = df_attention[df_attention["clip_id"] == "Edu2_S77"]
true_positive_ex1
# Out:
#      clip_id  true_label  pred_prob  pred_label  \
# 34  Edu2_S77           1    0.76323           1
#
#                                             attention  \
# 34  [0.07956273, 0.07626228, 0.030181466, 0.020765...
#
#                                                     X
# 34  [[-0.055555556, 5.7166667], [-0.055555556, 5.4...

# %%
true_positive_ex2 = df_attention[df_attention["clip_id"] == "Art6_S2"]
true_positive_ex2
# Out:
#    clip_id  true_label  pred_prob  pred_label  \
# 0  Art6_S2           1   0.775464           1
#
#                                            attention  \
# 0  [0.010810693, 0.010810693, 0.010810693, 0.0106...
#
#                                                    X
# 0  [[-0.054545455, 0.0], [-0.054545455, 0.0], [-0...

# %%
true_negative_ex1 = df_attention[df_attention["clip_id"] == "Tech10_S62"]
true_negative_ex1
# Out:
#         clip_id  true_label  pred_prob  pred_label  \
# 117  Tech10_S62           0   0.365479           0
#
#                                              attention  \
# 117  [0.08779966, 0.04538933, 0.030405236, 0.056395...
#
#                                                      X
# 117  [[-0.08256881, 0.0], [1.0183486, 0.08196721], ...

# %%
false_negative_ex1 = df_attention[df_attention["clip_id"] == "Tech10_S85"]
false_negative_ex1
# Out:
#         clip_id  true_label  pred_prob  pred_label  \
# 121  Tech10_S85           1   0.412882           0
#
#                                              attention  \
# 121  [0.08364877, 0.07945379, 0.03974086, 0.0564076...
#
#                                                      X
# 121  [[-0.08256881, 2.737705], [-0.08256881, 2.6065...

# %% [markdown]
# # VISUALIZING EACH EXAMPLE (Attention Heatmap + AU02)

# %%
top_attention_windows = top_windows(true_positive_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/true_positive_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight
# 0      29            4.666667          5.000000          0.121009
# 1      28            4.500000          4.833333          0.119807
# 2      27            4.333333          4.666667          0.097561
# 3       1            0.000000          0.333333          0.079563
# 4       2            0.166667          0.500000          0.076262

# %%
plot_attention_heatmap_with_au02_au05(true_positive_ex1)

# %%
top_attention_windows = top_windows(true_negative_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/true_negative_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight
# 0      10            1.500000          1.833333          0.145282
# 1      11            1.666667          2.000000          0.130733
# 2       9            1.333333          1.666667          0.098958
# 3      12            1.833333          2.166667          0.095287
# 4      13            2.000000          2.333333          0.090769

# %%
plot_attention_heatmap_with_au02_au05(true_negative_ex1)

# %%
top_attention_windows = top_windows(false_positive_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/false_positive_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight
# 0      25            4.000000          4.333333          0.235458
# 1      24            3.833333          4.166667          0.216160
# 2      21            3.333333          3.666667          0.156625
# 3      22            3.500000          3.833333          0.113912
# 4      23            3.666667          4.000000          0.093075

# %%
plot_attention_heatmap_with_au02_au05(false_positive_ex1)

# %%
top_attention_windows = top_windows(false_negative_ex1)
top_attention_windows.to_csv("../results/attention_heatmaps/false_negative_ex1.csv", float_format="%.4f")
top_attention_windows
# Out:
#    window  start_time_seconds  end_time_seconds  attention_weight
# 0       1            0.000000          0.333333          0.083649
# 1       2            0.166667          0.500000          0.079454
# 2       5            0.666667          1.000000          0.078941
# 3       6            0.833333          1.166667          0.060021
# 4       4            0.500000          0.833333          0.056408

# %%
plot_attention_heatmap_with_au02_au05(false_negative_ex1)

# %%
true_positives = [
    r for r in attention_results
    if r["true_label"] == 1 and r["pred_label"] == 1
]

true_positives_sorted = sorted(
    true_positives,
    key=lambda r: r["pred_prob"],
    reverse=True
)

for r in true_positives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Pol2_S42:  0.9769119620323181
# Pol2_S54:  0.9659664034843445
# Pol2_S52:  0.9461821913719177
# Pol2_S4:  0.9191373586654663
# Bus14_S2:  0.908271074295044
# Tech10_S65:  0.8721665740013123
# Phi3_S177:  0.8692460060119629
# Bus14_S105:  0.8653792142868042
# Phi3_S25:  0.8418115973472595
# Bus14_S109:  0.8221037983894348
# Bus14_S110:  0.8030992150306702
# Bus14_S48:  0.7887046337127686
# Med15_S69:  0.7859412431716919
# Art6_S2:  0.7754642963409424
# Bus14_S5:  0.7743992209434509
# Edu2_S77:  0.7632303237915039
# Edu2_S72:  0.7604174017906189
# Med15_S98:  0.7557972073554993
# Pol2_S125:  0.7276344299316406
# Edu2_S62:  0.7209067344665527
# Med15_S82:  0.6882054805755615
# Bus14_S111:  0.6792470216751099
# Tech10_S19:  0.66943359375
# Tech10_S118:  0.6650283336639404
# Tech10_S80:  0.6577348709106445
# Med15_S68:  0.6524126529693604
# Tech10_S113:  0.6465352177619934
# Ent5_S149:  0.6156825423240662
# Edu2_S78:  0.60770183801651
# Pol2_S20:  0.5960008502006531
# Art6_S32:  0.592456042766571
# Pol2_S81:  0.5892430543899536
# Edu2_S32:  0.5884599089622498
# Bus14_S113:  0.5805518627166748
# Phi3_S5:  0.5767573118209839
# Ent5_S3:  0.5693961977958679
# Ent5_S36:  0.5677534937858582
# Ent5_S61:  0.5508762001991272
# Ent5_S35:  0.5430610775947571
# Edu2_S68:  0.5411861538887024
# Bus14_S18:  0.5409208536148071
# Pol2_S43:  0.5391888618469238
# Phi3_S129:  0.5369596481323242
# Edu2_S37:  0.5275670886039734
# Edu2_S63:  0.5225034952163696
# Art6_S88:  0.5131785273551941
# Pol9_S69:  0.5124568939208984
# Bus14_S98:  0.5114305019378662
# Pol9_S8:  0.5087717175483704
# Pol9_S71:  0.5081943869590759
# Pol9_S101:  0.5080658197402954
# Ent5_S152:  0.5076544880867004
# Edu2_S35:  0.5052490234375
# Pol9_S4:  0.5027620196342468
# Pol9_S65:  0.5017604827880859
# Bus14_S17:  0.5003936886787415

# %%
true_negatives = [
    r for r in attention_results
    if r["true_label"] == 0 and r["pred_label"] == 0
]

true_negatives_sorted = sorted(
    true_negatives,
    key=lambda r: r["pred_prob"],
    reverse=False
)

for r in true_negatives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Tech10_S2:  0.3516102731227875
# Tech10_S62:  0.36547940969467163
# Tech10_S57:  0.37029480934143066
# Phi3_S171:  0.39743566513061523
# Pol2_S49:  0.40669405460357666
# Bus14_S65:  0.41315189003944397
# Med15_S24:  0.4287324845790863
# Pol2_S9:  0.42975398898124695
# Art6_S6:  0.432525634765625
# Med15_S70:  0.4331788122653961
# Med15_S99:  0.4437653720378876
# Tech21_S5:  0.4484514892101288
# Tech21_S4:  0.45086419582366943
# Tech21_S3:  0.45568665862083435
# Tech21_S29:  0.4596910774707794
# Tech21_S32:  0.46693122386932373
# Ent5_S88:  0.4690916836261749
# Pol9_S17:  0.4806079566478729
# Ent5_S24:  0.4844726026058197
# Bus14_S28:  0.48502689599990845
# Tech21_S33:  0.48583072423934937
# Med15_S26:  0.49205681681632996
# Tech21_S30:  0.4925365746021271
# Tech21_S6:  0.4927830696105957
# Pol9_S97:  0.49310460686683655
# Pol9_S55:  0.49334225058555603
# Pol9_S15:  0.49821633100509644
# Pol9_S42:  0.4984937012195587

# %%
false_positives = [
    r for r in attention_results
    if r["true_label"] == 0 and r["pred_label"] == 1
]

false_positives_sorted = sorted(
    false_positives,
    key=lambda r: r["pred_prob"],
    reverse=True
)

for r in false_positives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Pol2_S91:  0.9822999835014343
# Pol2_S90:  0.9682258367538452
# Pol2_S35:  0.962823212146759
# Pol2_S10:  0.9394465684890747
# Med15_S71:  0.8533939123153687
# Art6_S90:  0.8515757918357849
# Med15_S51:  0.8069841265678406
# Pol2_S126:  0.7844874858856201
# Med15_S57:  0.7784597277641296
# Med15_S81:  0.7251477837562561
# Med15_S46:  0.708830714225769
# Med15_S73:  0.6482641696929932
# Art6_S89:  0.6476239562034607
# Med15_S72:  0.6436285376548767
# Edu2_S54:  0.6360548138618469
# Phi3_S108:  0.6115006804466248
# Tech10_S58:  0.5987655520439148
# Bus14_S88:  0.57961505651474
# Art6_S43:  0.570604681968689
# Phi3_S85:  0.5565357208251953
# Phi3_S42:  0.5514718294143677
# Pol2_S93:  0.5504753589630127
# Phi3_S97:  0.5351957082748413
# Med15_S23:  0.5255131125450134
# Ent5_S33:  0.5175248384475708
# Ent5_S19:  0.5142587423324585

# %%
false_negatives = [
    r for r in attention_results
    if r["true_label"] == 1 and r["pred_label"] == 0
]

false_negatives_sorted = sorted(
    false_negatives,
    key=lambda r: r["pred_prob"],
    reverse=False
)

for r in false_negatives_sorted:
    print(f"{r["clip_id"]}:  {r["pred_prob"]}")
# Out:
# Tech10_S54:  0.4030616581439972
# Tech10_S99:  0.407889723777771
# Tech10_S53:  0.4120190143585205
# Tech10_S85:  0.41288185119628906
# Pol2_S21:  0.4193047881126404
# Bus14_S108:  0.4223424792289734
# Bus14_S106:  0.4284384846687317
# Tech10_S84:  0.4291514456272125
# Tech21_S16:  0.4578362703323364
# Tech21_S106:  0.46024200320243835
# Tech21_S105:  0.4628259837627411
# Art6_S36:  0.4646298587322235
# Ent5_S153:  0.4725520610809326
# Pol9_S78:  0.475981742143631
# Tech10_S59:  0.47671645879745483
# Edu2_S34:  0.4768851399421692
# Pol2_S30:  0.4788207411766052
# Med15_S34:  0.4814380705356598
# Edu2_S51:  0.4832465946674347
# Pol9_S52:  0.4837176203727722
# Pol9_S53:  0.4860054850578308
# Ent5_S76:  0.49002593755722046
# Pol9_S84:  0.49464473128318787
# Pol9_S104:  0.4960309863090515
